# %% [markdown]
# <a href="https://colab.research.google.com/github/Serena-G-LEE/25-2_Project/blob/main/openAlex_API_Data_Scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install aiohttp pandas rapidfuzz pyarrow orjson tqdm
# Out:
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (3.13.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (18.1.0)
# Requirement already satisfied: orjson in /usr/local/lib/python3.12/dist-packages (3.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp) (1.22.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp) (3.11)
# Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 41.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.1

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2025_with_authors"
YEAR = 2025
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for '
#
#                                        author_orcids  \
# 0              https://orcid.org/0009-0003-6205-1794
# 1  https://orcid.org/0000-0002-3663-9258;https://...
# 2  https://orcid.org/0000-0001-5693-0109;https://...
# 3  https://orcid.org/0000-0002-5415-3008;https://...
# 4  https://orcid.org/0000-0003-3776-2263;https://...
#
#                                  author_affiliations  \
# 0                         Duksung Women's University
# 1  Pusan National University;Pusan National Unive...
# 2  Duksung Women's University;Shimadzu (Japan);Du...
# 3  Duksung Women's University;Chonnam National Un...
# 4  Seoul National University Hospital;Seoul Natio...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2024_with_authors"
YEAR = 2024
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for '
# 21                       Chungbuk National University
# 22                       Chungnam National University
# === Institution mapping result ===
#                                          query_name institution_id                                        display_name
#                          Duksung Women's University      I65832422                          Duksung Women's University
#                           Seoul National University     I139264467                           Seoul National University
#                                    Korea University      I88761825          Korea University of Science and Technology
#                                   Yonsei University     I193775966                                   Yonsei University
#  Korea Advanced Institute of Science and Technology     I157485424  Korea Advanced Institute of Science and Technology
#                                   Sogang University     I148751991                                   Sogang University
#                             Sungkyunkwan University        I848706                             Sungkyunkwan University
#                                  Hanyang University     I109995039                            Hanyang Cyber University
#         Pohang University of Science and Technology     I123900574         Pohang University of Science and Technology
#         Gwangju Institute of Science and Technology      I39534123         Gwangju Institute of Science and Technology
# Daegu Gyeongbuk Institute of Science and Technology     I193352282 Daegu Gyeongbuk Institute of Science and Technology
#  Ulsan National Institute of Science and Technology      I48566637  Ulsan National Institute of Science and Technology
#                                Chung-Ang University      I67900169                                Chung-Ang University
#                                Kyung Hee University     I160888826                          Kyung Hee Cyber University
#                         Kangwon National University     I165507594                         Kangwon National University
#                       Kyungpook National University      I31419693                       Kyungpook National University
#                      Gyeongsang National University     I189442560                      Gyeongsang National University
#                           Pusan National University       I4921948                           Pusan National University
#                         Chonnam National University     I111277659                         Chonnam National University
#                         Jeonbuk National University      I80611190                         Jeonbuk National University
#                            Jeju National University      I83202590                            Jeju National University
#                        Chungbuk National University     I163753206                        Chungbuk National University
#                        Chungnam National University     I196345858                        Chungnam National University
# [RUN] Fetch top-10000 (year=2024) for Duksung Women's University (Duksung Women's University) → institutions.id=I65832422
# [GET] Duksung Women's University | page=1 cursor=*
# [GET]   -> fetched 134 (rep: 'Attitudes towards artificial intelligence at work: Scale development and validat...')
# [GET]   -> total accumulated: 134 | next_cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDYzNTYzNjUnXSI=
# [GET] Duksung Women's University | page=2 cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDYzNTYzNjUnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Duksung Women's University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2024_with_authors/works_top10000_2024_Duksung_Women's_University.csv (n=134)
# [RUN] Fetch top-10000 (year=2024) for Seoul National University (Seoul National University) → institutions.id=I139264467
# [GET] Seoul National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Worldwide trends in underweight and obesity from 1990 to 2022: a pooled analysis...')
# [GET]   -> total accumulated: 200 | next_cursor=IlsyMiwgOTkuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjIzOTIzNyddIg==
# [GET] Seoul National University | page=2 cursor=IlsyMiwgOTkuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjIzOTIzNyddIg==
# [GET]   -> fetched 200 (rep: 'Effect of Zn addition combined a novel screw twist extrusion technology on the m...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsxNSwgOTkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjMwNjEwMSddIg==
# [GET] Seoul National University | page=3 cursor=IlsxNSwgOTkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MjMwNjEwMSddIg==
# [GET]   -> fetched 200 (rep: 'Structural atlas of human primary microRNAs generated by SHAPE-MaP...')
# [GET]   -> total accumulated: 600 | next_cursor=IlsxMiwgOTguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjY5Mjk4NCddIg==
# [GET] Seoul National University | page=4 cursor=IlsxMiwgOTguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5NjY5Mjk4NCddIg==
# [GET]   -> fetched 200 (rep: 'Revealing the three-dimensional arrangement of polar topology in nanoparticles...')
# [GET]   -> total accumulated: 800 | next_cursor=IlsxMCwgOTcuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5Njc0MDQ2MCddIg==
# [GET] Seoul National University | page=5 cursor=IlsxMCwgOTcuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XND
cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTI1NTMzMTYnXSI=
# [GET]   -> fetched 200 (rep: 'Factors Influencing the Dietary Behavior of Patients with Type 2 Diabetes Mellit...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTkyOTM0NDAnXSI=
# [GET] Chungnam National University | page=11 cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTkyOTM0NDAnXSI=
# [GET]   -> fetched 200 (rep: 'Simulation of natural convection flow for vertical heated rod by using ANSYS/Flu...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDIwMzYyODQnXSI=
# [GET] Chungnam National University | page=12 cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDIwMzYyODQnXSI=
# [GET]   -> fetched 200 (rep: 'Deciphering the coupling state-dependent transcription termination in the<i>Esch...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDQ4NzA1MjUnXSI=
# [GET] Chungnam National University | page=13 cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDQ4NzA1MjUnXSI=
# [GET]   -> fetched 151 (rep: 'The JCMT BISTRO survey: The magnetised evolution of star-forming cores in the op...')
# [GET]   -> total accumulated: 2551 | next_cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MTQ5MTMzNzQnXSI=
# [GET] Chungnam National University | page=14 cursor=IlswLCA2OS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MTQ5MTMzNzQnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Chungnam National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2024_with_authors/works_top10000_2024_Chungnam_National_University.csv (n=2551)
# [DONE] Total rows: 60949
# [DONE] Saved to: /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2024_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W4392882830
# 1  https://openalex.org/W4391750334
# 2  https://openalex.org/W4392627262
# 3  https://openalex.org/W4393992300
# 4  https://openalex.org/W4402824362
#
#                                                title  publication_year  \
# 0  Attitudes towards artificial intelligence at w...              2024
# 1  Viscometry-based prediction of structural prop...              2024
# 2  ANXA2 (annexin A2) is crucial to ATG7-mediated...              2024
# 3  High-set curdlan emulsion gel fortified by tra...              2024
# 4  <scp>EPR</scp> spectroscopy: A versatile tool ...              2024
#
#   publication_date     type  \
# 0       2024-03-15  article
# 1       2024-02-12  article
# 2       2024-01-30  article
# 3       2024-04-05  article
# 4       2024-09-25  article
#
#                                           host_venue  cited_by_count  is_oa  \
# 0  Journal of Occupational and Organizational Psy...              41   True
# 1                                 Food Hydrocolloids              27  False
# 2                                          Autophagy              26  False
# 3                                 Food Hydrocolloids              22  False
# 4            Bulletin of the Korean Chemical Society              21   True
#
#   oa_status language  ...                                           abstract  \
# 0     green       en  ...  Abstract Research suggests that understanding ...
# 1    closed       en  ...                                               None
# 2    closed       en  ...  Triple-negative breast cancer (TNBC) is associ...
# 3    closed       en  ...                                               None
# 4    hybrid       en  ...  Abstract Paramagnetic molecules, such as main‐...
#
#   authors_count                                         author_ids  \
# 0             3                A5100409607;A5065878227;A5048198213
# 1             5  A5061802294;A5102799508;A5012862211;A502605833...
# 2            18  A5109463778;A5076925914;A5071943179;A508273845...
# 3             5  A5102799508;A5061802294;A5046803667;A502605833...
# 4             3                A5108334853;A5100380881;A5079028591
#
#                                         author_names  \
# 0             Jiyoung Park;Sang Eun Woo;JeongJin Kim
# 1  Hyun Woo Choi;Minji Choi;Chaerin Ryoo;Jungwoo ...
# 2  Minsoo Koh;Hyesol Lim;Hao Jin;Minjoo Kim;Yeji ...
# 3  Minji Choi;Hyun Woo Choi;Myeongsu Jo;Jungwoo H...
# 4                Minyoung Ju;Jin Kim;Jeongcheol Shin
#
#                                     author_positions  \
# 0                                  first;middle;last
# 1                    first;middle;middle;middle;last
# 2  first;middle;middle;middle;middle;middle;middl...
# 3                    first;middle;middle;middle;last
# 4                                  first;middle;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0003-4397-9645;https://...
# 1  https://orcid.org/0000-0002-1365-1721;https://...
# 2  https://orcid.org/0000-0003-1262-1675;https://...
# 3  https://orcid.org/0000-0001-6533-3760;https://...
# 4  https://orcid.org/0000-0003-4006-8897;https://...
#
#                                  author_affiliations  \
# 0  Duksung Women's University;Purdue University W...
# 1  Seoul National University;Seoul National Unive...
# 2  Duksung Women's University|Yonsei University;D...
# 3  Seoul National University;Seoul National Unive...
# 4  Duksung Women's University;Sunchon National Un...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2023_with_authors"
YEAR = 2023
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungbuk National University | id=https://openalex.org/I163753206
# [MAP] OK (EN): Chungbuk National University -> Chungbuk National University | institutions.id=I163753206
# [MAP] [23/23] resolving 'Chungnam National University'
# [MAP] Try EN: Chungnam National University
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungnam National University' (relax=False)
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungnam National University | id=https://openalex.org/I196345858
# [MAP] OK (EN): Chungnam National University -> Chungnam National University | institutions.id=I196345858
# [MAP] saved mapping -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2023_with_authors/institutions_mapping.csv
#                                            query_name institution_id  \
# 0                          Duksung Women's University      I65832422
# 1                           Seoul National University     I139264467
# 2                                    Korea University      I88761825
# 3                                   Yonsei University     I193775966
# 4   Korea Advanced Institute of Science and Techno...     I157485424
# 5                                   Sogang University     I148751991
# 6                             Sungkyunkwan University        I848706
# 7                                  Hanyang University     I109995039
# 8         Pohang University of Science and Technology     I123900574
# 9         Gwangju Institute of Science and Technology      I39534123
# 10  Daegu Gyeongbuk Institute of Science and Techn...     I193352282
# 11  Ulsan National Institute of Science and Techno...      I48566637
# 12                               Chung-Ang University      I67900169
# 13                               Kyung Hee University     I160888826
# 14                        Kangwon National University     I165507594
# 15                      Kyungpook National University      I31419693
# 16                     Gyeongsang National University     I189442560
# 17                          Pusan National University       I4921948
# 18                        Chonnam National University     I111277659
# 19                        Jeonbuk National University      I80611190
# 20                           Jeju National University      I83202590
# 21                       Chungbuk National University     I163753206
# 22                       Chungnam National University     I196345858
#
#                                          display_name
# 0                          Duksung Women's University
# 1                           Seoul National University
# 2          Korea University of Science and Technology
# 3                                   Yonsei University
# 4   Korea Advanced Institute of Science and Techno...
# 5                                   Sogang University
# 6                             Sungkyunkwan University
# 7                            Hanyang Cyber University
# 8         Pohang University of Science and Technology
# 9         Gwangju Institute of Science and Technology
# 10  Daegu Gyeongbuk Institute of Science and Techn...
# 11  Ulsan National Institute of Science and Techno...
# 12                               Chung-Ang University
YsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM3Njg4MTAzNSddIg==
# [GET] Seoul National University | page=4 cursor=IlsyNiwgOTguMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM3Njg4MTAzNSddIg==
# [GET]   -> fetched 200 (rep: 'Changes in total cholesterol level and cardiovascular disease risk among type 2 ...')
# [GET]   -> total accumulated: 800 | next_cursor=IlsyMiwgOTguMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDQ3NDQ0NSddIg==
# [GET] Seoul National University | page=5 cursor=IlsyMiwgOTguMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM5MDQ3NDQ0NSddIg==
# [GET]   -> fetched 200 (rep: 'The Wiener Criterion for Nonlocal Dirichlet Problems...')
# [GET]   -> total accumulated: 1000 | next_cursor=IlsxOSwgOTcuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NzA4MDkyMSddIg==
# [GET] Seoul National University | page=6 cursor=IlsxOSwgOTcuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NzA4MDkyMSddIg==
# [GET]   -> fetched 200 (rep: 'RNA Nanomedicine: Delivery Strategies and Applications...')
# [GET]   -> total accumulated: 1200 | next_cursor=IlsxNiwgOTYuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDMyMTE2NTQ0NyddIg==
# [GET] Seoul National University | page=7 cursor=IlsxNiwgOTYuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDMyMTE2NTQ0NyddIg==
# [GET]   -> fetched 200 (rep: 'Improved natural food colorant production in the filamentous fungus Monascus rub...')
# [GET]   -> total accumulated: 1400 | next_cursor=IlsxNSwgOTYuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4OTk5MjI4OCddIg==
# [GET] Seoul National University | page=8 cursor=IlsxNSwgOTYuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4OTk5MjI4OCddIg==
# [GET]   -> fetched 200 (rep: 'Method for collision avoidance based on deep reinforcement learning with path-sp...')
# [GET]   -> total accumulated: 1600 | next_cursor=IlsxMywgOTUuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM3MjMwMDUzNyddIg==
# [GET] Seoul National University | page=9 cursor=IlsxMywgOTUuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM3MjMwMDUzNyddIg==
# [GET]   -> fetched 200 (rep: 'Effects of nitrogen plasma treatments on hydrogen storage capacity of microporou...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlsxMiwgOTUuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NTY1NzUxMyddIg==
# [GET] Seoul National University | page=10 cursor=IlsxMiwgOTUuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4NTY1NzUxMyddIg==
# [GET]   -> fetched 200 (rep: 'Development of a real-time noise estimation model for construction sites...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlsxMSwgOTQuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4MjM5NjM5MSddIg==
# [GET] Seoul National University | page=11 cursor=IlsxMSwgOTQuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM4MjM5NjM5MSddIg==
# [GET]   -> fetched 200 (rep: 'Benefits and harms of normal saline instillation before endotracheal suctioning ...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlsxMCwgOTMuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM2NzMzMzI4MSddIg==
# [GET] Seoul National University | page=12 cursor=IlsxMCwgOTMuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDM2NzMzMzI4MSddIg==
# [GET]   -> fetched 200 (rep: 'Radiologic Imaging of Traumatic Bowel and Mesenteric Injuries: A Comprehensive U...')
# [GET]   -> total accumulated: 2400 | next_cursor=Ils5LCA5Mi4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMjI1MDM4MTknXSI=
# [GET] Seoul National University | page=13 cursor=Ils5LCA5Mi4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMjI1MDM4MTknXSI=
# [GET]   -> fetched 200 (rep: 'Food web dynamics in the mangrove ecosystem of the Pearl River Estuary surrounde...')
# [GET]   -> total accumulated: 2600 | next_cursor=Ils5LCA5Mi4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzODg5MTE2OTYnXSI=
# [GET] Seoul National University | page=14 cursor=Ils5LCA5Mi4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzODg5MTE2OTYnXSI=
# [GET]   -> fetched 200 (rep: 'Inference of Admixture Origins in Indigenous African Cattle...')
# [GET]   -> total accumulated: 2800 | next_cursor=Ils4LCA5MS4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzMjI3NjgwMTAnXSI=
# [GET] Seoul National University | page=15 cursor=Ils4LCA5MS4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQz
# 2              44  False    closed       en  ...
# 3              40  False    closed       en  ...
# 4              36   True    hybrid       en  ...
#
#                                             abstract authors_count  \
# 0  Cancer cells undergo metabolic reprogramming a...             4
# 1  Abstract With artificial intelligence (AI) inc...             3
# 2                                               None             3
# 3                                               None             5
# 4  Many cancers arise from sites of chronic infla...             3
#
#                                           author_ids  \
# 0    A5047462797;A5038662502;A5002243126;A5010982531
# 1                A5085030247;A5100409607;A5061711155
# 2                A5030158170;A5090640494;A5083115378
# 3  A5102799508;A5061802294;A5033946983;A502605833...
# 4                A5074700953;A5100335623;A5083115378
#
#                                         author_names  \
# 0  Chaithanya Chelakkot;Vipin Shankar Chelakkot;Y...
# 1     Federico Magni;Jiyoung Park;Melody Manchi Chao
# 2                     Yeji Hong;Su-Min Nam;Aree Moon
# 3  Minji Choi;Hyun Woo Choi;Haeun Kim;Jungwoo Hah...
# 4               Eun‐Sook Kim;Sun Young Kim;Aree Moon
#
#                   author_positions  \
# 0         first;middle;middle;last
# 1                first;middle;last
# 2                first;middle;last
# 3  first;middle;middle;middle;last
# 4                first;middle;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0002-4548-5510;https://...
# 1  https://orcid.org/0000-0002-3797-8155;https://...
# 2              https://orcid.org/0000-0001-7182-9789
# 3  https://orcid.org/0000-0001-6533-3760;https://...
# 4  https://orcid.org/0009-0003-6205-1794;https://...
#
#                                  author_affiliations  \
# 0  Seoul National University;Cleveland Clinic Ler...
# 1  ETH Zurich;Duksung Women's University;Hong Kon...
# 2  Duksung Women's University;Duksung Women's Uni...
# 3  Seoul National University;Seoul National Unive...
# 4  Duksung Women's University;Duksung Women's Uni...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2022_with_authors"
YEAR = 2022
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungbuk National University | id=https://openalex.org/I163753206
# [MAP] OK (EN): Chungbuk National University -> Chungbuk National University | institutions.id=I163753206
# [MAP] [23/23] resolving 'Chungnam National University'
# [MAP] Try EN: Chungnam National University
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungnam National University' (relax=False)
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungnam National University | id=https://openalex.org/I196345858
# [MAP] OK (EN): Chungnam National University -> Chungnam National University | institutions.id=I196345858
# [MAP] saved mapping -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2022_with_authors/institutions_mapping.csv
#                                            query_name institution_id  \
# 0                          Duksung Women's University      I65832422
# 1                           Seoul National University     I139264467
# 2                                    Korea University      I88761825
# 3                                   Yonsei University     I193775966
# 4   Korea Advanced Institute of Science and Techno...     I157485424
# 5                                   Sogang University     I148751991
# 6                             Sungkyunkwan University        I848706
# 7                                  Hanyang University     I109995039
# 8         Pohang University of Science and Technology     I123900574
# 9         Gwangju Institute of Science and Technology      I39534123
# 10  Daegu Gyeongbuk Institute of Science and Techn...     I193352282
MCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDIyNTI3NDgwNiddIg==
# [GET]   -> fetched 200 (rep: 'Open innovation and multi-homing of delivery platforms: comparative study of Car...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlsxNSwgOTMuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI5MDc5Mjg1NiddIg==
# [GET] Seoul National University | page=12 cursor=IlsxNSwgOTMuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI5MDc5Mjg1NiddIg==
# [GET]   -> fetched 200 (rep: 'Rapid Synthesis of Multifunctional Apatite via the Laser-Induced Hydrothermal Pr...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsxNCwgOTIuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI5Mjc0OTUzNiddIg==
# [GET] Seoul National University | page=13 cursor=IlsxNCwgOTIuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI5Mjc0OTUzNiddIg==
# [GET]   -> fetched 200 (rep: 'Meringue-derived hierarchically porous carbon as an efficient polysulfide regula...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsxMywgOTIuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI4ODA2MDkzOSddIg==
# [GET] Seoul National University | page=14 cursor=IlsxMywgOTIuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI4ODA2MDkzOSddIg==
# [GET]   -> fetched 200 (rep: 'Comparison of Spatial Distributions of Intracluster Light and Dark Matter...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsxMiwgOTEuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI4MzM3MDA3MyddIg==
# [GET] Seoul National University | page=15 cursor=IlsxMiwgOTEuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI4MzM3MDA3MyddIg==
# [GET]   -> fetched 200 (rep: 'Harrison’s rule corroborated for the body size of cleptoparasitic cuckoo bees (H...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsxMSwgOTAuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI4Mjk0NDYyNiddIg==
# [GET] Seoul National University | page=16 cursor=IlsxMSwgOTAuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDI4Mjk0NDYyNiddIg==
# [GET]   -> fetched 200 (rep: 'Effect of Attitude Toward Suicide on Suicidal Behavior: Based on the Korea Natio...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsxMCwgODkuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDIyMDc4NjMwNCddIg==
# [GET] Seoul National University | page=17 cursor=IlsxMCwgODkuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDIyMDc4NjMwNCddIg==
# [GET]   -> fetched 200 (rep: 'Oncolytic Vaccinia Virus Augments T Cell Factor 1-Positive Stem-like CD8+ T Cell...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxMCwgODkuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDMwOTY2OTI2NiddIg==
# [GET] Seoul National University | page=18 cursor=IlsxMCwgODkuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XNDMwOTY2OTI2NiddIg==
# [GET]   -> fetched 200 (rep: 'Automated Detection of Surgical Implants on Plain Knee Radiographs Using a Deep ...')
# [GET]   -> total accumulated: 3600 | next_cursor=Ils5LCA4OC4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyODM3MTI5MzYnXSI=
# [GET] Seoul National University | page=19 cursor=Ils5LCA4OC4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyODM3MTI5MzYnXSI=
# [GET]   -> fetched 200 (rep: 'Implications of Persistent Pain in Patients With Rheumatoid Arthritis Despite Re...')
# [GET]   -> total accumulated: 3800 | next_cursor=Ils4LCA4Ny4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMDY5NDQ0MTUnXSI=
# [GET] Seoul National University | page=20 cursor=Ils4LCA4Ny4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMDY5NDQ0MTUnXSI=
# [HTTP:EXC] HTTPSConnectionPool(host='api.openalex.org', port=443): Read timed out. (read timeout=60) retry 1/5 url=https://api.openalex.org/works
# [GET]   -> fetched 200 (rep: 'Correlation Between Proton Pump Inhibitors and the Complications of Liver Cirrho...')
# [GET]   -> total accumulated: 4000 | next_cursor=Ils4LCA4Ny4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyO
#
#                                        author_orcids  \
# 0              https://orcid.org/0000-0003-2814-6346
# 1  https://orcid.org/0000-0003-4397-9645;https://...
# 2  https://orcid.org/0000-0001-9350-1231;https://...
# 3  https://orcid.org/0000-0002-9809-2921;https://...
# 4  https://orcid.org/0000-0002-8215-9992;https://...
#
#                                  author_affiliations  \
# 0       Duksung Women's University;Anyang University
# 1  Duksung Women's University;Purdue University W...
# 2  University of South Carolina;Indiana Universit...
# 3  Kangdong Sacred Heart Hospital|Hallym Universi...
# 4  Yonsei University;Yonsei University;Yonsei Uni...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2021_with_authors"
YEAR = 2021
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for '
# 20                           Jeju National University
# 21                       Chungbuk National University
# 22                       Chungnam National University
# === Institution mapping result ===
#                                          query_name institution_id                                        display_name
#                          Duksung Women's University      I65832422                          Duksung Women's University
#                           Seoul National University     I139264467                           Seoul National University
#                                    Korea University      I88761825          Korea University of Science and Technology
#                                   Yonsei University     I193775966                                   Yonsei University
#  Korea Advanced Institute of Science and Technology     I157485424  Korea Advanced Institute of Science and Technology
#                                   Sogang University     I148751991                                   Sogang University
#                             Sungkyunkwan University        I848706                             Sungkyunkwan University
#                                  Hanyang University     I109995039                            Hanyang Cyber University
#         Pohang University of Science and Technology     I123900574         Pohang University of Science and Technology
#         Gwangju Institute of Science and Technology      I39534123         Gwangju Institute of Science and Technology
# Daegu Gyeongbuk Institute of Science and Technology     I193352282 Daegu Gyeongbuk Institute of Science and Technology
#  Ulsan National Institute of Science and Technology      I48566637  Ulsan National Institute of Science and Technology
#                                Chung-Ang University      I67900169                                Chung-Ang University
#                                Kyung Hee University     I160888826                          Kyung Hee Cyber University
#                         Kangwon National University     I165507594                         Kangwon National University
#                       Kyungpook National University      I31419693                       Kyungpook National University
#                      Gyeongsang National University     I189442560                      Gyeongsang National University
#                           Pusan National University       I4921948                           Pusan National University
#                         Chonnam National University     I111277659                         Chonnam National University
#                         Jeonbuk National University      I80611190                         Jeonbuk National University
#                            Jeju National University      I83202590                            Jeju National University
#                        Chungbuk National University     I163753206                        Chungbuk National University
#                        Chungnam National University     I196345858                        Chungnam National University
# [RUN] Fetch top-10000 (year=2021) for Duksung Women's University (Duksung Women's University) → institutions.id=I65832422
# [GET] Duksung Women's University | page=1 cursor=*
# [GET]   -> fetched 160 (rep: 'How interactivity and vividness influence consumer virtual reality shopping expe...')
# [GET]   -> total accumulated: 160 | next_cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTM4MzQ5MjAnXSI=
# [GET] Duksung Women's University | page=2 cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTM4MzQ5MjAnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Duksung Women's University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2021_with_authors/works_top10000_2021_Duksung_Women's_University.csv (n=160)
# [RUN] Fetch top-10000 (year=2021) for Seoul National University (Seoul National University) → institutions.id=I139264467
# [GET] Seoul National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Highly accurate protein structure prediction with AlphaFold...')
# [GET]   -> total accumulated: 200 | next_cursor=IlsxMTAsIDk5LjAsIDExMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1czMTk1NTkzOTc2J10i
# [GET] Seoul National University | page=2 cursor=IlsxMTAsIDk5LjAsIDExMCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1czMTk1NTkzOTc2J10i
# [GET]   -> fetched 200 (rep: 'Unveiling the Impact of Fe Incorporation on Intrinsic Performance of Reconstruct...')
# [GET]   -> total accumulated: 400 | next_cursor=Ils3MiwgOTkuMCwgNzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE1Nzk4OTgzNyddIg==
# [GET] Seoul National University | page=3 cursor=Ils3MiwgOTkuMCwgNzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE1Nzk4OTgzNyddIg==
# [GET]   -> fetched 200 (rep: 'Localized Delivery of Theranostic Nanoparticles and High‐Energy Photons using Mi...')
# [GET]   -> total accumulated: 600 | next_cursor=Ils1NSwgOTguMCwgNTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEyMDQ3NjUwMyddIg==
# [GET] Seoul National University | page=4 cursor=Ils1NSwgOTguMCwgNTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEyMDQ3NjUwMyddIg==
# [GET]   -> fetched 200 (rep: 'A few-shot learning approach for database-free vision-based monitoring on constr...')
# [GET]   -> total accumulated: 800 | next_cursor=
MCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE3NjUwNzA4OSddIg==
# [GET] Seoul National University | page=15 cursor=IlsxOCwgOTIuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE3NjUwNzA4OSddIg==
# [GET]   -> fetched 200 (rep: 'Disruption of the astrocyte–neuron interaction is responsible for the impairment...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsxNywgOTEuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE5OTQ4ODg2OCddIg==
# [GET] Seoul National University | page=16 cursor=IlsxNywgOTEuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE5OTQ4ODg2OCddIg==
# [GET]   -> fetched 200 (rep: 'Association Among Local Hemodynamic Parameters Derived From CT Angiography and T...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsxNiwgOTEuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxNDQ1MDAyNyddIg==
# [GET] Seoul National University | page=17 cursor=IlsxNiwgOTEuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxNDQ1MDAyNyddIg==
# [GET]   -> fetched 200 (rep: 'Developing a Climate Change Vulnerability Index for Coastal City Sustainability,...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxNSwgOTAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIwNjc1MzA3OCddIg==
# [GET] Seoul National University | page=18 cursor=IlsxNSwgOTAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIwNjc1MzA3OCddIg==
# [GET]   -> fetched 200 (rep: 'Neural network-based prediction of the long-term time-dependent mechanical behav...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE5NzA5NjQzNSddIg==
# [GET] Seoul National University | page=19 cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE5NzA5NjQzNSddIg==
# [GET]   -> fetched 200 (rep: 'Solving Doppler-Angle Ambiguity of BPSK-MIMO FMCW Radar System...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxMywgODkuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE3NDExNjI2OCddIg==
# [GET] Seoul National University | page=20 cursor=IlsxMywgODkuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE3NDExNjI2OCddIg==
# [GET]   -> fetched 200 (rep: 'Predication of oxygen requirement in COVID-19 patients using dynamic change of i...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxMiwgODguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEzNDA4NDQ1MSddIg==
# [GET] Seoul National University | page=21 cursor=IlsxMiwgODguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEzNDA4NDQ1MSddIg==
# [GET]   -> fetched 200 (rep: 'Contextual risk factors in the use of electric kick scooters: An episode samplin...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEyNjIwMzIwOSddIg==
# [GET] Seoul National University | page=22 cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEyNjIwMzIwOSddIg==
# [GET]   -> fetched 200 (rep: 'Three-dimensional constitutive model for shape-memory polymers considering tempe...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIwOTAwMzg4NSddIg==
# [GET] Seoul National University | page=23 cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIwOTAwMzg4NSddIg==
# [GET]   -> fetched 200 (rep: 'Anxiety and Depression in Patients With Nontuberculous Mycobacterial Pulmonary D...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE2NDQ5MzQ2OSddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE2NDQ5MzQ2OSddIg==
# [GET]   -> fetched 200 (rep: 'Take a sad song and make it better: Spousal activity limitations, caregiving, an...')
# [GET]   -> total accumulated: 4800 | next_cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMx
sICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE3NjYyMTEyNyddIg==
# [GET]   -> fetched 200 (rep: 'Modulation of the Al/Cu<sub>2</sub>O Schottky Barrier Height for p-Type Oxide TF...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsxNiwgOTEuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE4OTkwNzc1NSddIg==
# [GET] Yonsei University | page=16 cursor=IlsxNiwgOTEuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE4OTkwNzc1NSddIg==
# [GET]   -> fetched 200 (rep: 'Does causal reasoning lead to moral reasoning? Consumers' responses to scandaliz...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsxNSwgOTAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIwMDEwODc3OCddIg==
# [GET] Yonsei University | page=17 cursor=IlsxNSwgOTAuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIwMDEwODc3OCddIg==
# [GET]   -> fetched 200 (rep: 'In Vivo Evaluation of Decellularized Human Tooth Scaffold for Dental Tissue Rege...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxMTA3MDQ1MiddIg==
# [GET] Yonsei University | page=18 cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxMTA3MDQ1MiddIg==
# [GET]   -> fetched 200 (rep: 'Wetting properties and morphological behavior of core-shell polymer-based nanopa...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxMywgODkuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxNjY1NTE4MSddIg==
# [GET] Yonsei University | page=19 cursor=IlsxMywgODkuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxNjY1NTE4MSddIg==
# [GET]   -> fetched 200 (rep: 'sEMG-Based Hand Posture Recognition Considering Electrode Shift, Feature Vectors...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxMiwgODguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzIxMTI4NjMzOCddIg==
# ...
# [GET]   -> empty batch (stop).
# [SAVE] Jeonbuk National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2021_with_authors/works_top10000_2021_Jeonbuk_National_University.csv (n=2625)
# [RUN] Fetch top-10000 (year=2021) for Jeju National University (Jeju National University) → institutions.id=I83202590
# [GET] Jeju National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Materials Beyond Conventional Triboelectric Series for Fabrication and Applicati...')
# [GET]   -> total accumulated: 200 | next_cursor=IlsyNCwgOTQuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE4MDk0OTU3MyddIg==
# [GET] Jeju National University | page=2 cursor=IlsyNCwgOTQuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE4MDk0OTU3MyddIg==
# [GET]   -> fetched 200 (rep: 'Next-Generation Bioinformatics Approaches and Resources for Coronavirus Vaccine ...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsxMywgODkuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE2MTQ5ODkyNCddIg==
# [GET] Jeju National University | page=3 cursor=IlsxMywgODkuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzE2MTQ5ODkyNCddIg==
# [GET]   -> fetched 200 (rep: 'Tetracycline-resistant bacteria and ribosomal protection protein genes in soils ...')
# [GET]   -> total accumulated: 600 | next_cursor=Ils3LCA4Mi4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNDA4ODk3NTQnXSI=
# [GET] Jeju National University | page=4 cursor=Ils3LCA4Mi4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNDA4ODk3NTQnXSI=
# [GET]   -> fetched 200 (rep: 'Intent-based networking platform...')
# [GET]   -> total accumulated: 800 | next_cursor=IlszLCA3NC4wLCAzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMyMDcxNTI5ODInXSI=
# [GET] Jeju National University | page=5 cursor=IlszLCA3NC4wLCAzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMyMDcxNTI5ODInXSI=
# [GET]   -> fetched 200 (rep: 'Effect of low-fishmeal diets on some digestive physiological responses of juveni...')
# [GET]   -> total accumulated: 1000 | next_cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxODQ4MjUyOTYnXSI=
# [GET] Jeju National University | page=6 cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzM
4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMjQyMTU1OTMnXSI=
# [GET]   -> fetched 200 (rep: 'Surgical importance of the posterior auricular ligament when harvesting ear cart...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMjEzNTQyNjgnXSI=
# [GET] Chungnam National University | page=13 cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMjEzNTQyNjgnXSI=
# [GET]   -> fetched 200 (rep: 'Experimental visualization of reversible magnesium storage and surface chemistry...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMyMTI4NzEwMjEnXSI=
# [GET] Chungnam National University | page=14 cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMyMTI4NzEwMjEnXSI=
# [GET]   -> fetched 149 (rep: 'Propagating characteristics of mesospheric gravity waves observed by an OI 557.7...')
# [GET]   -> total accumulated: 2749 | next_cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTk3NTc3ODYnXSI=
# [GET] Chungnam National University | page=15 cursor=IlswLCA1Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzOTk3NTc3ODYnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Chungnam National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2021_with_authors/works_top10000_2021_Chungnam_National_University.csv (n=2749)
# [DONE] Total rows: 64756
# [DONE] Saved to: /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2021_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W3177014436
# 1  https://openalex.org/W3208569491
# 2  https://openalex.org/W3139356424
# 3  https://openalex.org/W3185567511
# 4  https://openalex.org/W3201227628
#
#                                                title  publication_year  \
# 0  How interactivity and vividness influence cons...              2021
# 1  A Comparative Study of Rutin and Rutin Glycosi...              2021
# 2  Fibronectin regulates anoikis resistance via c...              2021
# 3  Recent progress and challenges in microbial po...              2021
# 4  Mixed or Segregated: Toward Efficient and Stab...              2021
#
#   publication_date     type                                    host_venue  \
# 0       2021-06-20  article  Journal of Research in Interactive Marketing
# 1       2021-10-27  article                                  Antioxidants
# 2       2021-03-23  article                                Cancer Letters
# 3       2021-07-21   review                        Bioresource Technology
# 4       2021-09-08   review                                     ACS Omega
#
#    cited_by_count  is_oa oa_status language  ...  \
# 0             192  False    closed       en  ...
# 1             124   True      gold       en  ...
# 2             107  False    closed       en  ...
# 3              74  False    closed       en  ...
# 4              62   True      gold       en  ...
#
#                                             abstract authors_count  \
# 0  Purpose The purpose of the study is to investi...             4
# 1  The effects of rutin and rutin glycoside with ...             3
# 2                                               None            14
# 3                                               None             5
# 4  Convenient modulation of bandgap for the mixed...             4
#
#                                           author_ids  \
# 0    A5100360487;A5100416219;A5101894678;A5102740803
# 1                A5066636038;A5038576846;A5113608328
# 2  A5109349079;A5111921858;A5100765070;A508531445...
# 3  A5101448050;A5017278958;A5069333187;A510199774...
# 4    A5052391760;A5112877857;A5102973598;A5030026591
#
#                                         author_names  \
# 0  Jung-Hwan Kim;Minjeong Kim;Minjung Park;Jungmi...
# 1         Sung-Sook Choi;Hye-Ryung Park;Kyung‐Ae Lee
# 2  Hyeong‐jun Han;Jee Young Sung;Su-Hyeon Kim;Un-...
# 3  Jiye Lee;Hyun June Park;Myounghoon Moon;Jin-Su...
# 4   Hyejin Choe;Dohyun Jeon;Seon Joo Lee;Junsang Cho
#
#                                     author_positions  \
# 0                           first;middle;middle;last
# 1                                  first;middle;last
# 2  first;middle;middle;middle;middle;middle;middl...
# 3                    first;middle;middle;middle;last
# 4                           first;middle;middle;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0001-9350-1231;https://...
# 1
# 2  https://orcid.org/0000-0001-9144-689X;https://...
# 3  https://orcid.org/0000-0001-6723-4010;https://...
# 4  https://orcid.org/0000-0002-5307-4471;https://...
#
#                                  author_affiliations  \
# 0  University of South Carolina;Indiana Universit...
# 1  Duksung Women's University;Kyung Hee Universit...
# 2  National Cancer Center;National Cancer Center;...
# 3  Korea Institute of Energy Research;Duksung Wom...
# 4  Duksung Women's University;Korea Research Inst...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2020_with_authors"
YEAR = 2020
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungbuk National University | id=https://openalex.org/I163753206
# [MAP] OK (EN): Chungbuk National University -> Chungbuk National University | institutions.id=I163753206
# [MAP] [23/23] resolving 'Chungnam National University'
# [MAP] Try EN: Chungnam National University
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungnam National University' (relax=False)
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungnam National University | id=https://openalex.org/I196345858
# [MAP] OK (EN): Chungnam National University -> Chungnam National University | institutions.id=I196345858
# [MAP] saved mapping -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2020_with_authors/institutions_mapping.csv
#                                            query_name institution_id  \
# 0                          Duksung Women's University      I65832422
# 1                           Seoul National University     I139264467
# 2                                    Korea University      I88761825
# 3                                   Yonsei University     I193775966
# 4   Korea Advanced Institute of Science and Techno...     I157485424
# 5                                   Sogang University     I148751991
# 6                             Sungkyunkwan University        I848706
# 7                                  Hanyang University     I109995039
# 8         Pohang University of Science and Technology     I123900574
# 9         Gwangju Institute of Science and Technology      I39534123
# 10  Daegu Gyeongbuk Institute of Science and Techn...     I193352282
# 11  Ulsan National Institute of Science and Techno...      I48566637
# 12                               Chung-Ang University      I67900169
# 13                               Kyung Hee University     I160888826
# 14                        Kangwon National University     I165507594
# 15                      Kyungpook National University      I31419693
# 16                     Gyeongsang National University     I189442560
# 17                          Pusan National University       I4921948
# 18                        Chonnam National University     I111277659
# 19                        Jeonbuk National University      I80611190
# 20                           Jeju National University      I83202590
# 21                       Chungbuk National University     I163753206
# 22                       Chungnam National University     I196345858
#
#                                          display_name
# 0                          Duksung Women's University
# 1                           Seoul National University
# 2          Korea University of Science and Technology
# 3                                   Yonsei University
# 4   Korea Advanced Institute of Science and Techno...
# 5                                   Sogang University
# 6                             Sungkyunkwan University
# 7                            Hanyang Cyber University
# 8         Pohang University of Science and Technology
# 9         Gwangju Institute of Science and Technology
# 10  Daegu Gyeongbuk Institute of Science and Techn...
# 11  Ulsan National Institute of Science and Techno...
# 12                               Chung-Ang University
# 13                         Kyung Hee Cyber University
# 14                        Kangwon National University
# 15                      Kyungpook National University
# 16                     Gyeongsang National University
IsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyMDY3MzM5OCddIg==
# [GET] Seoul National University | page=4 cursor=Ils3MiwgOTguMCwgNzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyMDY3MzM5OCddIg==
# [GET]   -> fetched 200 (rep: 'Solvated Ion Intercalation in Graphite: Sodium and Beyond...')
# [GET]   -> total accumulated: 800 | next_cursor=Ils2MSwgOTguMCwgNjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzODkyNjQzNiddIg==
# [GET] Seoul National University | page=5 cursor=Ils2MSwgOTguMCwgNjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzODkyNjQzNiddIg==
# [GET]   -> fetched 200 (rep: 'A Cu<sub>2</sub>O–CuSCN Nanocomposite as a Hole-Transport Material of Perovskite...')
# [GET]   -> total accumulated: 1000 | next_cursor=Ils1MywgOTcuMCwgNTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MzA3MDYxOSddIg==
# [GET] Seoul National University | page=6 cursor=Ils1MywgOTcuMCwgNTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MzA3MDYxOSddIg==
# [GET]   -> fetched 200 (rep: 'Skin Brightening Efficacy of Exosomes Derived from Human Adipose Tissue-Derived ...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils0NiwgOTcuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwNjEzODkxNCddIg==
# [GET] Seoul National University | page=7 cursor=Ils0NiwgOTcuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwNjEzODkxNCddIg==
# [GET]   -> fetched 200 (rep: 'Recent advances in genome editing of stem cells for drug discovery and therapeut...')
# [GET]   -> total accumulated: 1400 | next_cursor=Ils0MSwgOTYuMCwgNDEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyNTkwMzY3NiddIg==
# [GET] Seoul National University | page=8 cursor=Ils0MSwgOTYuMCwgNDEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyNTkwMzY3NiddIg==
# [GET]   -> fetched 200 (rep: 'Public Health Emergency and Crisis Management: Case Study of SARS-CoV-2 Outbreak...')
# [GET]   -> total accumulated: 1600 | next_cursor=IlszNywgOTYuMCwgMzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxMDgwMzg3NyddIg==
# [GET] Seoul National University | page=9 cursor=IlszNywgOTYuMCwgMzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxMDgwMzg3NyddIg==
# [GET]   -> fetched 200 (rep: 'Potential-Dependent Electrochemiluminescence for Selective Molecular Sensing of ...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlszNCwgOTUuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyMzA2ODIzOSddIg==
# [GET] Seoul National University | page=10 cursor=IlszNCwgOTUuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyMzA2ODIzOSddIg==
# [GET]   -> fetched 200 (rep: 'Prognostic perspectives of PD-L1 combined with tumor-infiltrating lymphocytes, E...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlszMSwgOTUuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwMDU4MTc1NiddIg==
# [GET] Seoul National University | page=11 cursor=IlszMSwgOTUuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwMDU4MTc1NiddIg==
# [GET]   -> fetched 200 (rep: 'Single-step plasma-induced hierarchical structures for tunable water adhesion...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNjY4MjY1NCddIg==
# [GET] Seoul National University | page=12 cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNjY4MjY1NCddIg==
# [GET]   -> fetched 200 (rep: 'Atomic‐Distributed Coordination State of Metal‐Phenolic Compounds Enabled Low Te...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsyNywgOTQuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA4NDI2NTQ2NSddIg==
# [GET] Seoul National University | page=13 cursor=IlsyNywgOTQuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA4NDI2NTQ2NSddIg==
# [GET]   -> fetched 200 (rep: 'The Epigenetic Overlap between Obesity and Mood Disorders: A Systematic Review...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsyNSwgOTMuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA4NzM5NDE4NiddIg==
# [GET] Seoul National University | page=14 cursor=IlsyNSwgOTMuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA4NzM5NDE4NiddIg==
# [GET]   -> fetched 200 (rep: 'Budgetary responses to COVID-19: the case of South Korea...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyMywgOTMuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxNjgxNzgwMyddIg==
# [GET] Seoul National University | page=15 cursor=IlsyMywgOTMuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxNjgxNzgwMyddIg==
# [GET]   -> fetched 200 (rep: 'An analysis of the efficiency of the oil refining industry in the OECD countries...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEwMTExMTc0MCddIg==
# [GET] Seoul National University | page=16 cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEwMTExMTc0MCddIg==
# [GET]   -> fetched 200 (rep: 'Chronic Toxoplasma gondii Infection Alleviates Experimental Autoimmune Encephalo...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMCwgOTIuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyMjQ3ODk2NCddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMCwgOTIuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyMjQ3ODk2NCddIg==
# [GET]   -> fetched 200 (rep: 'Effects of reflection and immediate feedback to improve clinical reasoning of me...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxOSwgOTEuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzODYxNzMzNSddIg==
# [GET] Seoul National University | page=18 cursor=IlsxOSwgOTEuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzODYxNzMzNSddIg==
# [GET]   -> fetched 200 (rep: 'Heat-Induced Acceleration of Pozzolanic Reaction Under Restrained Conditions and...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxOCwgOTEuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NzI2NzE1OSddIg==
# [GET] Seoul National University | page=19 cursor=IlsxOCwgOTEuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NzI2NzE1OSddIg==
# [GET]   -> fetched 200 (rep: 'Lipopolysaccharide-induced innate immune responses are exacerbated by Prohibitin...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEwMDYyMjc3NyddIg==
# [GET] Seoul National University | page=20 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEwMDYyMjc3NyddIg==
# [GET]   -> fetched 200 (rep: 'Pseudo metal-organic coordination derived one-step carbonization of non-carboniz...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEwNzg5MDQ4NyddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzEwNzg5MDQ4NyddIg==
# [GET]   -> fetched 200 (rep: 'Islamic Banking Performance: A Bibliometric Review...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDYzMDYwOCddIg==
# [GET] Seoul National University | page=22 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDYzMDYwOCddIg==
# [GET]   -> fetched 200 (rep: 'Water strider females use individual experience to adjust jumping behaviour to t...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MjkyMzMzNSddIg==
# [GET] Seoul National University | page=23 cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MjkyMzMzNSddIg==
# [GET]   -> fetched 200 (rep: 'Direct Visualization of Gap-Plasmon Propagation on a Near-Touching Nanowire Dime...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA0ODUxODAzNiddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA0ODUxODAzNiddIg==
# [GET]   -> fetched 200 (rep: 'No mutagenicity and oral toxicity of winter mushroom powder treated with atmosph...')
# [GET]   -> total accumulated: 4800 | next_cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNzc0ODM1MCddIg==
# [GET] Seoul National University | page=25 cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNzc0ODM1MCddIg==
# [GET]   -> fetched 200 (rep: 'Remote Doping of the Two-Dimensional-Electron-Gas State at the <mml:math xmlns:m...')
# [GET]   -> total accumulated: 5000 | next_cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxNDYzNjUyNiddIg==
# [GET] Seoul National University | page=26 cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxNDYzNjUyNiddIg==
# [GET]   -> fetched 200 (rep: 'Double Kodaira fibrations with small signature...')
# [GET]   -> total accumulated: 5200 | next_cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwMDU2MTkwMSddIg==
# [GET] Seoul National University | page=27 cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwMDU2MTkwMSddIg==
# [GET]   -> fetched 200 (rep: 'Comparison of the Effects of Sufentanil and Fentanyl in Intravenous Patient-Cont...')
# [GET]   -> total accumulated: 5400 | next_cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MzM4MTg3MCddIg==
# [GET] Seoul National University | page=28 cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MzM4MTg3MCddIg==
# [GET]   -> fetched 200 (rep: 'NF-κB disinhibition contributes to dendrite defects in fly models of neurodegene...')
# [GET]   -> total accumulated: 5600 | next_cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMzU5NzgyNzInXSI=
# [GET] Seoul National University | page=29 cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMzU5NzgyNzInXSI=
# [GET]   -> fetched 200 (rep: 'Geometrical influence on Self Heating in Nanowire and Nanosheet FETs using TCAD ...')
# [GET]   -> total accumulated: 5800 | next_cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5OTkwMjg2MTUnXSI=
# [GET] Seoul National University | page=30 cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5OTkwMjg2MTUnXSI=
# [GET]   -> fetched 200 (rep: '<i>POLD1</i> variants leading to reduced polymerase activity can cause hearing l...')
# [GET]   -> total accumulated: 6000 | next_cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwODMxNTY3MzYnXSI=
# [GET] Seoul National University | page=31 cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwODMxNTY3MzYnXSI=
# [GET]   -> fetched 200 (rep: 'Cellular Target Proteome in Breast Cancer Cells of an Oplopane Sesquiterpenoid I...')
# [GET]   -> total accumulated: 6200 | next_cursor=Ils3LCA4My4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMjE5MTEzODYnXSI=
# [GET] Seoul National University | page=32 cursor=Ils3LCA4My4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMjE5MTEzODYnXSI=
# [GET]   -> fetched 200 (rep: 'A generalization of functional clustering for discrete multivariate longitudinal...')
# [GET]   -> total accumulated: 6400 | next_cursor=Ils3LCA4My4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMDM5NjY5NzAnXSI=
# [GET] Seoul National University | page=33 cursor=Ils3LCA4My4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMDM5NjY5NzAnXSI=
# [GET]   -> fetched 200 (rep: 'Developing a predictive model for distinguishing invasive nail unit melanoma fro...')
# [GET]   -> total accumulated: 6600 | next_cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMjg5NDU3MzUnXSI=
# [GET] Seoul National University | page=34 cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMjg5NDU3MzUnXSI=
# [GET]   -> fetched 200 (rep: 'Production of quail (Coturnix japonica) germline chimeras by transfer of Ficoll-...')
# [GET]   -> total accumulated: 6800 | next_cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMx
4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMzU4OTA3NDknXSI=
# [GET]   -> fetched 200 (rep: 'Geometric Analysis of Optimized Range Cell Migration Trajectory for Squint Synth...')
# [GET]   -> total accumulated: 9000 | next_cursor=IlsxLCA2OC4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwOTQ0Mzc2NjInXSI=
# [GET] Seoul National University | page=46 cursor=IlsxLCA2OC4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwOTQ0Mzc2NjInXSI=
# [GET]   -> fetched 200 (rep: 'Abstract PO-059: The genomic landscape of the <i>in situ</i> to invasive ductal ...')
# [GET]   -> total accumulated: 9200 | next_cursor=IlsxLCA2OC4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNjM4NTM1NzMnXSI=
# [GET] Seoul National University | page=47 cursor=IlsxLCA2OC4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNjM4NTM1NzMnXSI=
# [GET]   -> fetched 200 (rep: 'Transmission Onset Distribution of COVID-19 in South Korea...')
# [GET]   -> total accumulated: 9400 | next_cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMDgwMzY3MjQnXSI=
# [GET] Seoul National University | page=48 cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMDgwMzY3MjQnXSI=
# [GET]   -> fetched 200 (rep: 'Corrigendum: Clinical evaluation of ridge augmentation using autogenous tooth bo...')
# [GET]   -> total accumulated: 9600 | next_cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMjkzMTYwNDAnXSI=
# [GET] Seoul National University | page=49 cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMjkzMTYwNDAnXSI=
# [GET]   -> fetched 200 (rep: 'Association between host wing morphology polymorphism and Wolbachia infection in...')
# [GET]   -> total accumulated: 9800 | next_cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwNDYyMDE5NDMnXSI=
# [GET] Seoul National University | page=50 cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwNDYyMDE5NDMnXSI=
# [GET]   -> fetched 200 (rep: 'Optical coherence tomography of the Tokay gecko (<i>Gekko gecko</i>) eye...')
# [GET]   -> reached top-10000; stopping early.
# [SAVE] Seoul National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2020_with_authors/works_top10000_2020_Seoul_National_University.csv (n=10000)
# [RUN] Fetch top-10000 (year=2020) for Korea University (Korea University of Science and Technology) → institutions.id=I88761825
# [GET] Korea University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Rapid Detection of COVID-19 Causative Virus (SARS-CoV-2) in Human Nasopharyngeal...')
# [GET]   -> total accumulated: 200 | next_cursor=Ils1NiwgOTguMCwgNTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA0MjkwNDkyNCddIg==
# [GET] Korea University | page=2 cursor=Ils1NiwgOTguMCwgNTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA0MjkwNDkyNCddIg==
# [GET]   -> fetched 200 (rep: 'Modification of a Nile Red Staining Method for Microplastics Analysis: A Nile Re...')
# [GET]   -> total accumulated: 400 | next_cursor=IlszMywgOTUuMCwgMzMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA0ODU4MjQ5OSddIg==
# [GET] Korea University | page=3 cursor=IlszMywgOTUuMCwgMzMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA0ODU4MjQ5OSddIg==
# [GET]   -> fetched 200 (rep: 'CHIMPS2: survey description and 12CO emission in the Galactic Centre...')
# [GET]   -> total accumulated: 600 | next_cursor=IlsyMywgOTMuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzODAwOTQ4MCddIg==
# [GET] Korea University | page=4 cursor=IlsyMywgOTMuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzODAwOTQ4MCddIg==
# [GET]   -> fetched 200 (rep: 'A novel method for simultaneous measurement of thickness, refractive index, bow,...')
# [GET]   -> total accumulated: 800 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA0Nzk5NTcyNCddIg==
# [GET] Korea University | page=5 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMz
sICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyOTIyNDM5NSddIg==
# [GET] Yonsei University | page=6 cursor=Ils0NywgOTcuMCwgNDcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyOTIyNDM5NSddIg==
# [GET]   -> fetched 200 (rep: 'MRI Assessment of Complete Response to Preoperative Chemoradiation Therapy for R...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils0MSwgOTYuMCwgNDEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNzU1NDAyMSddIg==
# [GET] Yonsei University | page=7 cursor=Ils0MSwgOTYuMCwgNDEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNzU1NDAyMSddIg==
# [GET]   -> fetched 200 (rep: 'Multiexcitonic Triplet Pair Generation in Oligoacene Dendrimers as Amorphous Sol...')
# [GET]   -> total accumulated: 1400 | next_cursor=IlszNiwgOTYuMCwgMzYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwNjMzMDMyNyddIg==
# [GET] Yonsei University | page=8 cursor=IlszNiwgOTYuMCwgMzYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwNjMzMDMyNyddIg==
# [GET]   -> fetched 200 (rep: 'Metabolic flux and functional potential of microbial community in an acidogenic ...')
# [GET]   -> total accumulated: 1600 | next_cursor=IlszMiwgOTUuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwODc1MDAxMyddIg==
# [GET] Yonsei University | page=9 cursor=IlszMiwgOTUuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwODc1MDAxMyddIg==
# [GET]   -> fetched 200 (rep: 'Ladder-like polysilsesquioxanes with antibacterial chains and durable siloxane n...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDEzNjU4MCddIg==
# [GET] Yonsei University | page=10 cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5NDEzNjU4MCddIg==
# [GET]   -> fetched 200 (rep: 'Comparison of Dose Distribution in Regional Lymph Nodes in Whole-Breast Radiothe...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlsyNiwgOTQuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNjMxMjMxMyddIg==
# [GET] Yonsei University | page=11 cursor=IlsyNiwgOTQuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNjMxMjMxMyddIg==
# [GET]   -> fetched 200 (rep: 'Solid oxide fuel cells with zirconia/ceria bilayer electrolytes via roll calende...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlsyNCwgOTMuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA4MTEzMzMwMiddIg==
# [GET] Yonsei University | page=12 cursor=IlsyNCwgOTMuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA4MTEzMzMwMiddIg==
# [GET]   -> fetched 200 (rep: 'Linking political and bureaucratic representation: Does minority representation ...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA4MDQ4NDQ3MCddIg==
# [GET] Yonsei University | page=13 cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA4MDQ4NDQ3MCddIg==
# [GET]   -> fetched 200 (rep: 'Diversity of North Pacific Meridional Mode and Its Distinct Impacts on El Niño‐S...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsyMCwgOTIuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNDA4Mzc2OCddIg==
# [GET] Yonsei University | page=14 cursor=IlsyMCwgOTIuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzNDA4Mzc2OCddIg==
# [GET]   -> fetched 200 (rep: 'Development and Validation of Prediction Model for Risk Reduction of Metabolic S...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsxOSwgOTEuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzExMDQ4ODM3OCddIg==
# [GET] Yonsei University | page=15 cursor=IlsxOSwgOTEuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzExMDQ4ODM3OCddIg==
# [GET]   -> fetched 200 (rep: 'Classification of Wintertime Atmospheric Teleconnection Patterns in the Northern...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzMjk4MzY4OCddIg==
# [GET] Yonsei University | page=16 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAzMjk4MzY4OCddIg==
# [GET]   -> fetched 200 (rep: 'Efficacy and acceptability of pharmacological and non-pharmacological interventi...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MDU0NDUzMyddIg==
# [GET] Yonsei University | page=17 cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MDU0NDUzMyddIg==
# [GET]   -> fetched 200 (rep: 'Mitochondrial diabetes and mitochondrial DNA mutation load in MELAS syndrome...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwNzczNTQ5MSddIg==
# [GET] Yonsei University | page=18 cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAwNzczNTQ5MSddIg==
# [GET]   -> fetched 200 (rep: 'The halo effect of C2C interaction quality in prolonged close-proximity service ...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxODM1NTA1NCddIg==
# [GET] Yonsei University | page=19 cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxODM1NTA1NCddIg==
# [GET]   -> fetched 200 (rep: 'Application of panoramic radiography with a multilayer imaging program for detec...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxNjMxMTI1NSddIg==
# [GET] Yonsei University | page=20 cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxNjMxMTI1NSddIg==
# [GET]   -> fetched 200 (rep: 'Photoacoustic imaging to localize indeterminate pulmonary nodules: A preclinical...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxNTEzNzgwNCddIg==
# [GET] Yonsei University | page=21 cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAxNTEzNzgwNCddIg==
# ...
# [GET]   -> empty batch (stop).
# [SAVE] Jeonbuk National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2020_with_authors/works_top10000_2020_Jeonbuk_National_University.csv (n=2246)
# [RUN] Fetch top-10000 (year=2020) for Jeju National University (Jeju National University) → institutions.id=I83202590
# [GET] Jeju National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Nanocurcumin: A Promising Candidate for Therapeutic Applications...')
# [GET]   -> total accumulated: 200 | next_cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyNTQ2Mjg3NCddIg==
# [GET] Jeju National University | page=2 cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzAyNTQ2Mjg3NCddIg==
# [GET]   -> fetched 200 (rep: 'A Context-Aware Location Recommendation System for Tourists Using Hierarchical L...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MjAyNTk5NiddIg==
# [GET] Jeju National University | page=3 cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5MjAyNTk5NiddIg==
# [GET]   -> fetched 200 (rep: 'Inhibition of oxidative stress induced-cytotoxicity by coptisine in V79-4 Chines...')
# [GET]   -> total accumulated: 600 | next_cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMDk1MjA0NzknXSI=
# [GET] Jeju National University | page=4 cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwMDk1MjA0NzknXSI=
# [GET]   -> fetched 200 (rep: 'Impact of Endoscopists’ Personality Traits on Adenoma and Polyp Detection Rates ...')
# [GET]   -> total accumulated: 800 | next_cursor=IlsyLCA3My4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMjU0MTI2NzYnXSI=
# [GET] Jeju National University | page=5 cursor=IlsyLCA3My4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxMjU0MTI2NzYnXSI=
# [GET]   -> fetched 200 (rep: 'Hand-held Dual-particle Imager Implemented with a Multiplexed Low Sampling-rate ...')
# [GET]   -> total accumulated: 1000 | next_cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQzM
wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwODU1NjU4MjknXSI=
# [GET]   -> fetched 200 (rep: 'External validation of the predictive performance of population pharmacokinetic ...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwODUyOTA0MzMnXSI=
# [GET] Chungnam National University | page=13 cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMwODUyOTA0MzMnXSI=
# [GET]   -> fetched 200 (rep: 'Contact Printing Pressure Uniformization Control System in Roll-to-Roll Process ...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyNTYwNDcwNzQnXSI=
# [GET] Chungnam National University | page=14 cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyNTYwNDcwNzQnXSI=
# [GET]   -> fetched 13 (rep: 'Model-based prediction to evaluate residence time of hyaluronic acid based derma...')
# [GET]   -> total accumulated: 2613 | next_cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDg1MTM0OTYnXSI=
# [GET] Chungnam National University | page=15 cursor=IlswLCA2MC4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDg1MTM0OTYnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Chungnam National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2020_with_authors/works_top10000_2020_Chungnam_National_University.csv (n=2613)
# [DONE] Total rows: 61848
# [DONE] Saved to: /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2020_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W3095726951
# 1  https://openalex.org/W3082772483
# 2  https://openalex.org/W3005776191
# 3  https://openalex.org/W3024968792
# 4  https://openalex.org/W3108559236
#
#                                                title  publication_year  \
# 0  Antimicrobial and Immunomodulatory Effects of ...              2020
# 1  Elucidating the Mechanistic Origins of Photoca...              2020
# 2  Multidimensional Cognitive Behavioral Therapy ...              2020
# 3  The Effects of Perceived Quality of Augmented ...              2020
# 4  Consumer decision-making in a retail store: th...              2020
#
#   publication_date     type  \
# 0       2020-11-04   review
# 1       2020-08-31  article
# 2       2020-02-10  article
# 3       2020-05-15  article
# 4       2020-11-30  article
#
#                                           host_venue  cited_by_count  is_oa  \
# 0          Journal of Microbiology and Biotechnology              64   True
# 1                 ACS Applied Materials & Interfaces              58  False
# 2                           JMIR mhealth and uhealth              55   True
# 3                                        Informatics              52   True
# 4  International Journal of Retail & Distribution...              47  False
#
#   oa_status language  ...                                           abstract  \
# 0    bronze       en  ...                                               None
# 1    closed       en  ...  Solar fuel generation mediated by semiconducto...
# 2      gold       en  ...  Background Developing effective, widely useful...
# 3      gold       en  ...  Augmented reality (AR) enables consumers to br...
# 4    closed       en  ...  Purpose The purpose of the study is to investi...
#
#   authors_count                                         author_ids  \
# 0             2                            A5112388283;A5018446601
# 1             7  A5030026591;A5074609470;A5089646746;A500424741...
# 2             8  A5100580073;A5003266453;A5032571771;A504086106...
# 3             1                                        A5102740803
# 4             4    A5100360487;A5100416219;A5102740803;A5072514254
#
#                                         author_names  \
# 0                        Hyun Jung Lim;Hea Soon Shin
# 1  Junsang Cho;Nuwanthi Suwandaratne;Sara Abdel R...
# 2  Meelim Kim;Young‐In Kim;Yoonjeong Go;Seokoh Le...
# 3                                        Jungmin Yoo
# 4  Jung-Hwan Kim;Minjeong Kim;Jungmin Yoo;Minjung...
#
#                                     author_positions  \
# 0                                         first;last
# 1      first;middle;middle;middle;middle;middle;last
# 2  first;middle;middle;middle;middle;middle;middl...
# 3                                              first
# 4                           first;middle;middle;last
#
#                                        author_orcids  \
# 0
# 1  https://orcid.org/0000-0003-4211-4113;https://...
# 2  https://orcid.org/0000-0002-0507-1727;https://...
# 3              https://orcid.org/0000-0002-8398-955X
# 4  https://orcid.org/0000-0001-9350-1231;https://...
#
#                                  author_affiliations  \
# 0  Duksung Women's University;Duksung Women's Uni...
# 1  Texas A&M University|Duksung Women's Universit...
# 2  Duksung Women's University|Seoul National Univ...
# 3                         Duksung Women's University
# 4  University of South Carolina;Indiana Universit...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2019_with_authors"
YEAR = 2019
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for '
YsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0ODcwMTcwNSddIg==
# [GET]   -> fetched 200 (rep: 'Transverse momentum dependent production cross sections of charged pions, kaons ...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNCwgOTMuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkyMzY2ODQ2MSddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNCwgOTMuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkyMzY2ODQ2MSddIg==
# [GET]   -> fetched 200 (rep: 'Variance of energy residual (VER): An efficient method for planetary gear fault ...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk5NzM5OTI1MyddIg==
# [GET] Seoul National University | page=16 cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk5NzM5OTI1MyddIg==
# [GET]   -> fetched 200 (rep: 'Universality, Scaling, and Collapse in Supercritical Fluids...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMSwgOTIuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NTEwOTk2NCddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMSwgOTIuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NTEwOTk2NCddIg==
# [GET]   -> fetched 200 (rep: 'Endocrine disruption by several aniline derivatives and related mechanisms in a ...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk5NjUzNTEyNyddIg==
# [GET] Seoul National University | page=18 cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk5NjUzNTEyNyddIg==
# [GET]   -> fetched 200 (rep: 'High Molecular Weight Chitosan-Complexed RNA Nanoadjuvant for Effective Cancer I...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkzNzE3NjQ4OCddIg==
# [GET] Seoul National University | page=19 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkzNzE3NjQ4OCddIg==
# [GET]   -> fetched 200 (rep: 'Tumour necrosis factor alpha and interleukin‐5 inhibit olfactory regeneration vi...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk1MjkxNDY3OSddIg==
# [GET] Seoul National University | page=20 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk1MjkxNDY3OSddIg==
# [GET]   -> fetched 200 (rep: 'Twisted and folded Auslander-Reiten quivers and applications to the representati...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NzMzNDg5MSddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NzMzNDg5MSddIg==
# [GET]   -> fetched 200 (rep: 'Epidemiological characteristics of breast cancer in Koreans...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2Njk0ODQ2NiddIg==
# [GET] Seoul National University | page=22 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2Njk0ODQ2NiddIg==
# [GET]   -> fetched 200 (rep: 'Diverse phenotypes and endotypes of fungus balls caused by mixed bacterial colon...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxNCwgODguMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2MzM4NDIxMCddIg==
# [GET] Seoul National University | page=23 cursor=IlsxNCwgODguMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2MzM4NDIxMCddIg==
# [GET]   -> fetched 200 (rep: 'Semiclassical Boltzmann transport theory of few-layer black phosphorus in variou...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk1ODU2MTE1NyddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMj
| next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NDQxODQ2MDEnXSI=
# [GET] Seoul National University | page=46 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NDQxODQ2MDEnXSI=
# [GET]   -> fetched 200 (rep: 'The Application of the Measurement of Heart Rate and Velocity during Training to...')
# [GET]   -> total accumulated: 9200 | next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NTUwODY5OTAnXSI=
# [GET] Seoul National University | page=47 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NTUwODY5OTAnXSI=
# [GET]   -> fetched 200 (rep: 'Hydrothermally prepared reduced graphene oxide free standing film as high curren...')
# [GET]   -> total accumulated: 9400 | next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NzIzOTYzOTQnXSI=
# [GET] Seoul National University | page=48 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NzIzOTYzOTQnXSI=
# [GET]   -> fetched 200 (rep: 'Tumor Heterogeneity Regarding Radiosensitivity, Recurrence Risk, and Immune-Chec...')
# [GET]   -> total accumulated: 9600 | next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5Nzg3OTgzMDQnXSI=
# [GET] Seoul National University | page=49 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5Nzg3OTgzMDQnXSI=
# [GET]   -> fetched 200 (rep: 'Mechanical properties of 3d-printed dental implant guide by sterilization method...')
# [GET]   -> total accumulated: 9800 | next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5OTA0MDAzNTEnXSI=
# [GET] Seoul National University | page=50 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5OTA0MDAzNTEnXSI=
# [GET]   -> fetched 200 (rep: 'Comparison of the difference between income quintiles with the slope index of in...')
# [GET]   -> reached top-10000; stopping early.
# [SAVE] Seoul National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2019_with_authors/works_top10000_2019_Seoul_National_University.csv (n=10000)
# [RUN] Fetch top-10000 (year=2019) for Korea University (Korea University of Science and Technology) → institutions.id=I88761825
# [GET] Korea University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'First M87 Event Horizon Telescope Results. I. The Shadow of the Supermassive Bla...')
# [GET]   -> total accumulated: 200 | next_cursor=Ils1OSwgOTguMCwgNTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk4NTIyMjgyNyddIg==
# [GET] Korea University | page=2 cursor=Ils1OSwgOTguMCwgNTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk4NTIyMjgyNyddIg==
# [GET]   -> fetched 200 (rep: '3-Carene, a Phytoncide from Pine Tree Has a Sleep-enhancing Effect by Targeting ...')
# [GET]   -> total accumulated: 400 | next_cursor=IlszNCwgOTUuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkxMDE3MDMwNCddIg==
# [GET] Korea University | page=3 cursor=IlszNCwgOTUuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkxMDE3MDMwNCddIg==
# [GET]   -> fetched 200 (rep: 'Nafion membranes with a sulfonated organic additive for the use in vanadium redo...')
# [GET]   -> total accumulated: 600 | next_cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk1MzEyMDcwNyddIg==
# [GET] Korea University | page=4 cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk1MzEyMDcwNyddIg==
# [GET]   -> fetched 200 (rep: 'Analysis of plasma metabolic profiling and evaluation of the effect of the intak...')
# [GET]   -> total accumulated: 800 | next_cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk3MjU4Njk0OSddIg==
# [GET] Korea University | page=5 cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk3MjU4Njk0OSddIg==
# [GET]   -> fetched 200 (rep: 'Unconventional hydrogen permeation behavior of Pd/BCC composite membranes and si...')
# [GET]   -> total accumulated: 1000 | next_cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwODI2MDM1NiddIg==
# [GET] Korea University | page=6 cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwODI2MDM1NiddIg==
# [GET]   -> fetched 200 (rep: 'Influence of interface defects on the optical properties of InP/ZnS quantum dots...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NzA4MTQ5OTcnXSI=
# [GET] Korea University | page=7 cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5
MCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NDAxNTA2NCddIg==
# [GET] Yonsei University | page=9 cursor=IlszMiwgOTUuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NDAxNTA2NCddIg==
# [GET]   -> fetched 200 (rep: 'All-2D ReS2 transistors with split gates for logic circuitry...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NTAxNjQyOSddIg==
# [GET] Yonsei University | page=10 cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NTAxNjQyOSddIg==
# [GET]   -> fetched 200 (rep: 'Chemotherapeutic Agent Paclitaxel Mediates Priming of NLRP3 Inflammasome Activat...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk5MzE3MzkzNiddIg==
# [GET] Yonsei University | page=11 cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk5MzE3MzkzNiddIg==
# [GET]   -> fetched 200 (rep: 'Robotic simultaneous resection for colorectal liver metastasis: feasibility for ...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlsyNCwgOTMuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NjA2NDEyNSddIg==
# [GET] Yonsei University | page=12 cursor=IlsyNCwgOTMuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NjA2NDEyNSddIg==
# [GET]   -> fetched 200 (rep: 'Robot-assisted laparoscopic single-port pyeloplasty using the da Vinci SP® syste...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NjM4NTc2MSddIg==
# [GET] Yonsei University | page=13 cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NjM4NTc2MSddIg==
# [GET]   -> fetched 200 (rep: 'Site-specific phosphorylation of Fbxw7 by Cdk5/p25 and its resulting decreased s...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk3Mjk4MDk0NCddIg==
# [GET] Yonsei University | page=14 cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk3Mjk4MDk0NCddIg==
# [GET]   -> fetched 200 (rep: 'Toxic Shock Syndrome Toxin 1-Producing Methicillin-Resistant Staphylococcus aure...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NDg4NjUyNyddIg==
# [GET] Yonsei University | page=15 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NDg4NjUyNyddIg==
# [GET]   -> fetched 200 (rep: 'Adequate protection rather than knee flexion prevents popliteal vascular injury ...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk5NTE1NjMwMCddIg==
# [GET] Yonsei University | page=16 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk5NTE1NjMwMCddIg==
# [GET]   -> fetched 200 (rep: 'Effect of Smartphone Use on Intraocular Pressure...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NjI3MDYzNCddIg==
# [GET] Yonsei University | page=17 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NjI3MDYzNCddIg==
# [GET]   -> fetched 200 (rep: 'Editors' Choice—Control of Si<sub>3</sub>N<sub>4</sub> Etching Kinetics and Sele...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxNCwgODguMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2ODk2Nzk4OCddIg==
# [GET] Yonsei University | page=18 cursor=IlsxNCwgODguMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2ODk2Nzk4OCddIg==
# [GET]   -> fetched 200 (rep: 'Performance Evaluation of a New Automated Chemiluminescent Immunoanalyzer-Based ...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMj
sICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2NjI1NTU2MCddIg==
# [GET]   -> fetched 200 (rep: 'Impact of Organic Manure on Growth, Nutrient Content and Yield of Chilli Pepper ...')
# [GET]   -> total accumulated: 400 | next_cursor=IlszMSwgOTQuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk3NzAyMTg3MyddIg==
# [GET] Chungnam National University | page=3 cursor=IlszMSwgOTQuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk3NzAyMTg3MyddIg==
# [GET]   -> fetched 200 (rep: 'Identification and Expression Analysis of the NAC Gene Family in Coffea canephor...')
# [GET]   -> total accumulated: 600 | next_cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NTkxNzk1OSddIg==
# [GET] Chungnam National University | page=4 cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0NTkxNzk1OSddIg==
# [GET]   -> fetched 200 (rep: '&lt;p&gt;PINK1 mediates spinal cord mitophagy in neuropathic pain&lt;/p&gt;...')
# [GET]   -> total accumulated: 800 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk4MDk3NzUxMyddIg==
# [GET] Chungnam National University | page=5 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk4MDk3NzUxMyddIg==
# [GET]   -> fetched 200 (rep: 'Genomic selection through single-step genomic best linear unbiased prediction im...')
# [GET]   -> total accumulated: 1000 | next_cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0MjcwNzI4MSddIg==
# [GET] Chungnam National University | page=6 cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk0MjcwNzI4MSddIg==
# [GET]   -> fetched 200 (rep: 'Synthesis and application of nitrogen-doped carbon dots as a matrix in matrix-as...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NjQ5NDQxMjAnXSI=
# [GET] Chungnam National University | page=7 cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NjQ5NDQxMjAnXSI=
# [GET]   -> fetched 200 (rep: 'Effects of Turbulence Driving and Sonic Mach Number on the Davis–Chandrasekhar–F...')
# [GET]   -> total accumulated: 1400 | next_cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5OTczNjY4OTYnXSI=
# [GET] Chungnam National University | page=8 cursor=Ils2LCA4MS4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5OTczNjY4OTYnXSI=
# [GET]   -> fetched 200 (rep: 'Hardware Resource Analysis in Distributed Training with Edge Devices...')
# [GET]   -> total accumulated: 1600 | next_cursor=IlszLCA3Ni4wLCAzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NTM0NDgyNTknXSI=
# [GET] Chungnam National University | page=9 cursor=IlszLCA3Ni4wLCAzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NTM0NDgyNTknXSI=
# [GET]   -> fetched 200 (rep: 'Regional ionosphere specification by assimilating ionosonde data into the SAMI2 ...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlsxLCA2OS4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5MzYxMzY5NTknXSI=
# [GET] Chungnam National University | page=10 cursor=IlsxLCA2OS4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5MzYxMzY5NTknXSI=
# [GET]   -> fetched 200 (rep: 'Stabilization of Arsenic in Paddy Soils Using Stabilizers...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NDQ0ODA1NDgnXSI=
# [GET] Chungnam National University | page=11 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NDQ0ODA1NDgnXSI=
# [GET]   -> fetched 200 (rep: 'Performance of TPC based ranging signal for more than 2 services multiplexing...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNzM3NjE4OTYnXSI=
# [GET] Chungnam National University | page=12 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNzM3NjE4OTYnXSI=
# [GET]   -> fetched 56 (rep: 'Clinicopathological profiling of small heterodimer partner, as a negative regula...')
# [GET]   -> total accumulated: 2256 | next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDkyMjE4NTAnXSI=
# [GET] Chungnam National University | page=13 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDkyMjE4NTAnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Chungnam National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2019_with_authors/works_top10000_2019_Chungnam_National_University.csv (n=2256)
# [DONE] Total rows: 57898
# [DONE] Saved to: /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2019_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W2968846733
# 1  https://openalex.org/W2987873067
# 2  https://openalex.org/W2983005260
# 3  https://openalex.org/W2955577995
# 4  https://openalex.org/W2928455896
#
#                                                title  publication_year  \
# 0  Effects of perceived interactivity of augmente...              2019
# 1  Biofilm Formation by Staphylococcus aureus Cli...              2019
# 2  Concentrations of THC, CBD, and CBN in commerc...              2019
# 3  Antitumor and Anti-Invasive Effect of Apigenin...              2019
# 4  Effects of temperature, light, and pH on the s...              2019
#
#   publication_date     type                                   host_venue  \
# 0       2019-08-17  article   Journal of Retailing and Consumer Services
# 1       2019-11-02  article                 Journal of Clinical Medicine
# 2       2019-11-15  article               Forensic Science International
# 3       2019-06-27  article  International Journal of Molecular Sciences
# 4       2019-04-01  article                               Food Chemistry
#
#    cited_by_count  is_oa oa_status language  ...  \
# 0             311  False    closed       en  ...
# 1              99   True      gold       en  ...
# 2              84  False    closed       en  ...
# 3              82   True      gold       en  ...
# 4              80  False    closed       en  ...
#
#                                             abstract authors_count  \
# 0                                               None             2
# 1  Staphylococcus aureus (S. aureus) causes persi...             7
# 2                                               None             9
# 3  Interleukin (IL)-6 plays a crucial role in the...             5
# 4                                               None             8
#
#                                           author_ids  \
# 0                            A5072514254;A5102740803
# 1  A5025786310;A5018827803;A5101948147;A500491728...
# 2  A5020314332;A5101581762;A5020198852;A508393339...
# 3  A5110478953;A5100625726;A5083115378;A506312125...
# 4  A5102958189;A5081989199;A5017686656;A506986092...
#
#                                         author_names  \
# 0                           Minjung Park;Jungmin Yoo
# 1  Harshad Lade;Joon Hyun Park;Sung Hee Chung;In ...
# 2  Eunyoung Jang;Hyo‐Jeong Kim;Seojeong Jang;Jaes...
# 3  Hwan Hee Lee;Joohee Jung;Aree Moon;Hyojeung Ka...
# 4  Dong Zhao;Daeung Yu;Moojoong Kim;Ming‐Yao Gu;S...
#
#                                     author_positions  \
# 0                                         first;last
# 1      first;middle;middle;middle;middle;middle;last
# 2  first;middle;middle;middle;middle;middle;middl...
# 3                    first;middle;middle;middle;last
# 4  first;middle;middle;middle;middle;middle;middl...
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0003-3040-2759;https://...
# 1  https://orcid.org/0000-0002-9809-2921;https://...
# 2  https://orcid.org/0000-0003-3714-6495;https://...
# 3  https://orcid.org/0000-0001-9124-9052;https://...
# 4  https://orcid.org/0000-0002-9018-3191;https://...
#
#                                  author_affiliations  \
# 0  Ewha Womans University;Duksung Women's University
# 1  Kangdong Sacred Heart Hospital|Hallym Universi...
# 2  Duksung Women's University;Duksung Women's Uni...
# 3  Duksung Women's University;Duksung Women's Uni...
# 4  Gangneung–Wonju National University|Korea Univ...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2018_with_authors"
YEAR = 2018
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate:
#                                Chung-Ang University      I67900169                                Chung-Ang University
#                                Kyung Hee University     I160888826                          Kyung Hee Cyber University
#                         Kangwon National University     I165507594                         Kangwon National University
#                       Kyungpook National University      I31419693                       Kyungpook National University
#                      Gyeongsang National University     I189442560                      Gyeongsang National University
#                           Pusan National University       I4921948                           Pusan National University
#                         Chonnam National University     I111277659                         Chonnam National University
#                         Jeonbuk National University      I80611190                         Jeonbuk National University
#                            Jeju National University      I83202590                            Jeju National University
#                        Chungbuk National University     I163753206                        Chungbuk National University
#                        Chungnam National University     I196345858                        Chungnam National University
# [RUN] Fetch top-10000 (year=2018) for Duksung Women's University (Duksung Women's University) → institutions.id=I65832422
# [GET] Duksung Women's University | page=1 cursor=*
# [GET]   -> fetched 98 (rep: 'Sex Differences in Cancer: Epidemiology, Genetics and Therapy...')
# [GET]   -> total accumulated: 98 | next_cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNzY0OTkwNjYnXSI=
# [GET] Duksung Women's University | page=2 cursor=IlswLCA2MS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNzY0OTkwNjYnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Duksung Women's University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2018_with_authors/works_top10000_2018_Duksung_Women's_University.csv (n=98)
# [RUN] Fetch top-10000 (year=2018) for Seoul National University (Seoul National University) → institutions.id=I139264467
# [GET] Seoul National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Proposed minimal standards for the use of genome data for the taxonomy of prokar...')
# [GET]   -> total accumulated: 200 | next_cursor=IlsxNzcsIDEwMC4wLCAxNzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwMzQzNzg2MiddIg==
# [GET] Seoul National University | page=2 cursor=IlsxNzcsIDEwMC4wLCAxNzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwMzQzNzg2MiddIg==
# [GET]   -> fetched 200 (rep: 'Thermodynamic and Kinetic Origins of Ferroelectricity in Fluorite Structure Oxid...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsxMTQsIDk5LjAsIDExNCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyOTY0MDc2MzI4J10i
# [GET] Seoul National University | page=3 cursor=IlsxMTQsIDk5LjAsIDExNCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyOTY0MDc2MzI4J10i
# [GET]   -> fetched 200 (rep: 'Creative destruction of the sharing economy in action: The case of Uber...')
# [GET]   -> total accumulated: 600 | next_cursor=Ils4NywgOTguMCwgODcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg5Njg2NDYwMSddIg==
# [GET] Seoul National University | page=4 cursor=Ils4NywgOTguMCwgODcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg5Njg2NDYwMSddIg==
# [GET]   -> fetched 200 (rep: 'Two-phase cooling using HFE-7100 for polymer electrolyte membrane fuel cell appl...')
# [GET]   -> total accumulated: 800 | next_cursor=Ils3MCwgOTguMCwgNzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5MjA3ODU5MCddIg==
# [GET] Seoul National University | page=5 cursor=Ils3MCwgOTguMCwgNzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5MjA3ODU5MCddIg==
# [GET]   -> fetched 200 (rep: 'Memory Hierarchy for Web Search...')
# [GET]   -> total accumulated: 1000 | next_cursor=Ils2MCwgOTcuMCwgNjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwNTk3MDU0NyddIg==
# [GET] Seoul National University | page=6 cursor=Ils2MCwgOTcuMCwgNjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwNTk3MDU0NyddIg==
# [GET]   -> fetched 200 (rep: 'Synthesis of Arenesulfonyl Fluorides via Sulfuryl Fluoride Incorporation from Ar...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils1MSwgOTcuMCwgNTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5NDI1NDEyOCddIg==
# [GET] Seoul National University | page=7 cursor=Ils1MSwgOTcuMCwgNTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5NDI1NDEyOCddIg==
# [GET]   -> fetched 200 (rep: 'Effect of Mn doping on particulate size and magnetic properties of LaFeO3 nanofi...')
# [GET]   -> total accumulated: 1400 | next_cursor=Ils0NiwgOTYuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwNjA4NjE4OSddIg==
# [GET] Seoul National University | page=8 cursor=Ils0NiwgOTYuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwNjA4NjE4OSddIg==
# [GET]   -> fetched 200 (rep: 'Corrosion performance of high pressure die-cast Al-Si-Mg-Zn alloys in 3.5 wt% Na...')
# [GET]   -> total accumulated: 1600 | next_cursor=Ils0MSwgOTYuMCwgNDEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5OTQ0MDY1MCddIg==
# [GET] Seoul National University | page=9 cursor=Ils0MSwgOTYuMCwgNDEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5OTQ0MDY1MCddIg==
# [GET]   -> fetched 200 (rep: 'Chromatin Remodeling BAF155 Subunit Regulates the Genesis of Basal Progenitors i...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlszNywgOTUuMCwgMzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg5NzM2NzI5OCddIg==
# [GET] Seoul National University | page=10 cursor=IlszNywgOTUuMCwgMzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg5NzM2NzI5OCddIg==
# [GET]   -> fetched 200 (rep: 'Ankylosing spondylitis: A novel risk factor for atrial fibrillation — A nationwi...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlszMywgOTQuMCwgMzMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4NDkzNTI5NyddIg==
# [GET] Seoul National University | page=11 cursor=IlszMywgOTQuMCwgMzMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4NDkzNTI5NyddIg==
# [GET]   -> fetched 200 (rep: 'Memory-Efficient and Accurate Sampling for Counting Local Triangles in Graph Str...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlszMSwgOTQuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg4NDY5NTc1NCddIg==
# [GET] Seoul National University | page=12 cursor=IlszMSwgOTQuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg4NDY5NTc1NCddIg==
# [GET]   -> fetched 200 (rep: 'Effects of bisphenol analogs on thyroid endocrine system and possible interactio...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwMTgxMjAwMSddIg==
# [GET] Seoul National University | page=13 cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwMTgxMjAwMSddIg==
# [GET]   -> fetched 200 (rep: 'Multiple scattering correction factor estimation for aethalometer aerosol absorp...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwNjYyMjQ4MCddIg==
# [GET] Seoul National University | page=14 cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwNjYyMjQ4MCddIg==
# [GET]   -> fetched 200 (rep: 'TPA: Fast, Scalable, and Accurate Method for Approximate Random Walk with Restar...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNCwgOTIuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5MTk4MzMyOSddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNCwgOTIuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5MTk4MzMyOSddIg==
# [GET]   -> fetched 200 (rep: 'Influence of A-site cation on the thermal stability of metal halide perovskite p...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4ODM1MjY0NSddIg==
# [GET] Seoul National University | page=16 cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4ODM1MjY0NSddIg==
# [GET]   -> fetched 200 (rep: 'The transcriptome of early chicken embryos reveals signaling pathways governing ...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg4NjU0MTYzNSddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg4NjU0MTYzNSddIg==
# [GET]   -> fetched 200 (rep: 'Agreement Between Parent Proxy Reports and Self-Reports of Adolescent Emotional ...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxOSwgOTAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4NDA5NDA2OSddIg==
# [GET] Seoul National University | page=18 cursor=IlsxOSwgOTAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4NDA5NDA2OSddIg==
# [GET]   -> fetched 200 (rep: 'Surface-Modified Spinel LiNi0.5Mn1.5O4 for Li-Ion Batteries...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjgwMDU4NDI5NyddIg==
# [GET] Seoul National University | page=19 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjgwMDU4NDI5NyddIg==
# [GET]   -> fetched 200 (rep: 'Glomerular crescents are associated with worse graft outcome in allograft IgA ne...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg4NjYwMTUwOCddIg==
# [GET] Seoul National University | page=20 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg4NjYwMTUwOCddIg==
# [GET]   -> fetched 200 (rep: 'Protocol for the first clinical trial to investigate safety and efficacy of corn...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg5Nzc1MDA1OSddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjg5Nzc1MDA1OSddIg==
# [GET]   -> fetched 200 (rep: 'Effect of pulse width modulation-controlled LED light on the polymerization of d...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwNjExODg3NSddIg==
# [GET] Seoul National University | page=22 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwNjExODg3NSddIg==
# [GET]   -> fetched 200 (rep: 'First-principles study on the negative- <mml:math xmlns:mml="http://www.w3.org/1...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxMywgODcuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5MjA5NDAyOCddIg==
# [GET] Seoul National University | page=23 cursor=IlsxMywgODcuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5MjA5NDAyOCddIg==
# [GET]   -> fetched 200 (rep: 'Scenario-Based Assessment of User Needs for Point-of-Care Robots...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5MjY0MzI4NiddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc5MjY0MzI4NiddIg==
# [GET]   -> fetched 200 (rep: 'Competition between the centrifugal and strato-rotational instabilities in the s...')
# [GET]   -> total accumulated: 4800 | next_cursor=IlsxMSwgODYuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4OTc5MzE3MSddIg==
# [GET] Seoul National University | page=25 cursor=IlsxMSwgODYuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4OTc5MzE3MSddIg==
# [GET]   -> fetched 200 (rep: 'Carbon‐Nanosheet Based Large‐Area Electrochemical Capacitor that is Flexible, Fo...')
# [GET]   -> total accumulated: 5000 | next_cursor=IlsxMCwgODUuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4NTExMDM5MCddIg==
# [GET] Seoul National University | page=26 cursor=IlsxMCwgODUuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc4NTExMDM5MCddIg==
# [GET]   -> fetched 200 (rep: 'New gap-filling and partitioning technique for H&amp;lt;sub&amp;gt;2&amp;lt;/sub...')
# [GET]   -> total accumulated: 5200 | next_cursor=IlsxMCwgODUuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjkwMjgxODcyNSddIg==
# [GET] Seoul National University | page=27 cursor=IlsxMCwgODUuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMj
content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2018_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W2810454451
# 1  https://openalex.org/W2897911253
# 2  https://openalex.org/W2794212562
# 3  https://openalex.org/W2783837782
# 4  https://openalex.org/W2809889057
#
#                                                title  publication_year  \
# 0  Sex Differences in Cancer: Epidemiology, Genet...              2018
# 1  Biowaste-to-bioenergy using biological methods...              2018
# 2  Creative destruction of the sharing economy in...              2018
# 3  A Scenario-Based Cognitive Behavioral Therapy ...              2018
# 4  Crosstalk between cancer cells and endothelial...              2018
#
#   publication_date     type  \
# 0       2018-06-27   review
# 1       2018-10-10  article
# 2       2018-03-20  article
# 3       2018-01-11  article
# 4       2018-06-30   review
#
#                                           host_venue  cited_by_count  is_oa  \
# 0                        Biomolecules & Therapeutics             293   True
# 1                   Energy Conversion and Management             269  False
# 2  Transportation Research Part A Policy and Prac...             113  False
# 3                  Telemedicine Journal and e-Health              82  False
# 4                     Archives of Pharmacal Research              78  False
#
#   oa_status language  ...                                           abstract  \
# 0     green       en  ...  Growing evidence shows sex-specific difference...
# 1    closed       en  ...                                               None
# 2    closed       en  ...                                               None
# 3    closed       en  ...  While self-administered mobile app-based cogni...
# 4    closed       en  ...                                               None
#
#   authors_count                                       author_ids  \
# 0             3              A5105519402;A5076925914;A5083115378
# 1             3              A5082323415;A5003249495;A5026721642
# 2             3              A5100655034;A5025283796;A5091261738
# 3             4  A5005773862;A5100417355;A5069646864;A5068174685
# 4             2                          A5034950429;A5083115378
#
#                                      author_names          author_positions  \
# 0                 Hae-In Kim;Hyesol Lim;Aree Moon         first;middle;last
# 1  Shashi Kant Bhatia;Hwang‐Soo Joo;Yung‐Hun Yang         first;middle;last
# 2          Ki‐Bum Kim;Chulwoo Baek;Jeong‐Dong Lee         first;middle;last
# 3    Ji‐Won Hur;Boram Kim;Dasom Park;Sungwon Choi  first;middle;middle;last
# 4                         Hyojeong Choi;Aree Moon                first;last
#
#                                        author_orcids  \
# 0              https://orcid.org/0009-0008-4844-3587
# 1  https://orcid.org/0000-0002-7688-6069;https://...
# 2  https://orcid.org/0000-0003-1392-5021;https://...
# 3  https://orcid.org/0000-0002-1939-7365;https://...
# 4
#
#                                  author_affiliations  \
# 0  Duksung Women's University;Duksung Women's Uni...
# 1  Konkuk University;Duksung Women's University;K...
# 2  Seoul National University;Duksung Women's Univ...
# 3  Chung-Ang University;Duksung Women's Universit...
# 4  Duksung Women's University;Duksung Women's Uni...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2017_with_authors"
YEAR = 2017
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungbuk National University | id=https://openalex.org/I163753206
# [MAP] OK (EN): Chungbuk National University -> Chungbuk National University | institutions.id=I163753206
# [MAP] [23/23] resolving 'Chungnam National University'
# [MAP] Try EN: Chungnam National University
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungnam National University' (relax=False)
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungnam National University | id=https://openalex.org/I196345858
# [MAP] OK (EN): Chungnam National University -> Chungnam National University | institutions.id=I196345858
# [MAP] saved mapping -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_
sICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2NjU0ODMzMiddIg==
# [GET]   -> fetched 200 (rep: 'Evaluation of wind pressure acting on multi-span greenhouses using CFD technique...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlszOCwgOTUuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2NTU0NTExOSddIg==
# [GET] Seoul National University | page=10 cursor=IlszOCwgOTUuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2NTU0NTExOSddIg==
# [GET]   -> fetched 200 (rep: 'Transglutaminase 2 mediates UV-induced skin inflammation by enhancing inflammato...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlszNSwgOTUuMCwgMzUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2NjE5NDEwOSddIg==
# [GET] Seoul National University | page=11 cursor=IlszNSwgOTUuMCwgMzUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2NjE5NDEwOSddIg==
# [GET]   -> fetched 200 (rep: 'Long-Term Effects of <i>Helicobacter pylori</i> Eradication on Metachronous Gast...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlszMiwgOTQuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2MDYwMTY0NSddIg==
# [GET] Seoul National University | page=12 cursor=IlszMiwgOTQuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2MDYwMTY0NSddIg==
# [GET]   -> fetched 200 (rep: 'Analysis of thin-walled beam-shell structures for concept modeling based on high...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsyOSwgOTMuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjYyMTA5MTIzNyddIg==
# [GET] Seoul National University | page=13 cursor=IlsyOSwgOTMuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjYyMTA5MTIzNyddIg==
# [GET]   -> fetched 200 (rep: 'Efficacy of PLGA microparticle-encapsulated formalin-killed Aeromonas hydrophila...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc1OTI3NDY4NiddIg==
# [GET] Seoul National University | page=14 cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc1OTI3NDY4NiddIg==
# [GET]   -> fetched 200 (rep: 'Pharmacological use of a novel scaffold, anomeric N,N-diarylamino tetrahydropyra...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNSwgOTIuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2NTI4MzQ3MiddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNSwgOTIuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc2NTI4MzQ3MiddIg==
# [GET]   -> fetched 200 (rep: 'Comparison between the Prebolus T1 Measurement and the Fixed T1 Value in Dynamic...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc1MTU2NTc0NCddIg==
# [GET] Seoul National University | page=16 cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc1MTU2NTc0NCddIg==
# [GET]   -> fetched 200 (rep: 'Teaching and Learning Science in Authoritative Classrooms: Teachers’ Power and S...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjczODQ5Nzg3NCddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjczODQ5Nzg3NCddIg==
# [GET]   -> fetched 200 (rep: 'Highly Selective Catalytic Hydrogenation and Etherification of 5-Hydroxymethyl-2...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2MzAwMzQ5MCddIg==
# [GET] Seoul National University | page=18 cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk2MzAwMzQ5MCddIg==
# [GET]   -> fetched 200 (rep: 'Inhibitory Effects of Flavonoids from Spatholobus suberectus on Sortase A and So...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc1OTM3NDg5MSddIg==
# [GET] Seoul National University | page=19 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc1OTM3NDg5MSddIg==
# [GET]   -> fetched 200 (rep: 'First Report of <i>Tomato spotted wilt virus</i> Infecting Soybean in Korea...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU3MTE1MjA1NSddIg==
# [GET] Seoul National University | page=20 cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU3MTE1MjA1NSddIg==
# [GET]   -> fetched 200 (rep: 'Detecting particles of dark matter...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjYyNDk2NDE1NyddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjYyNDk2NDE1NyddIg==
# [GET]   -> fetched 200 (rep: 'Scutellaria baicalensis Georgi induces caspase-dependent apoptosis via mitogen a...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxNCwgODguMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc0NjE5MzQ1OCddIg==
# [GET] Seoul National University | page=22 cursor=IlsxNCwgODguMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc0NjE5MzQ1OCddIg==
# [GET]   -> fetched 200 (rep: 'Isolation and Characterization of Chicken Primordial Germ Cells and Their Applic...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc0MTI0MDAzMCddIg==
# [GET] Seoul National University | page=23 cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjc0MTI0MDAzMCddIg==
# [GET]   -> fetched 200 (rep: 'Autonomous lane keeping based on approximate Q-learning...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjczMDM0ODc3MiddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjczMDM0ODc3MiddIg==
# [GET]   -> fetched 200 (rep: 'Questioning unexpected CRISPR off-target mutations in vivo...')
# [GET]   -> total accumulated: 4800 | next_cursor=IlsxMSwgODYuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjY1NTkyMDA4MSddIg==
# [GET] Seoul National University | page=25 cursor=IlsxMSwgODYuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjY1NTkyMDA4MSddIg==
# [GET]   -> fetched 200 (rep: 'Improvement of shear strength, wood failure percentage and wet delamination of c...')
# [GET]   -> total accumulated: 5000 | next_cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjYyMjU4NDI1NCddIg==
# [GET] Seoul National University | page=26 cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjYyMjU4NDI1NCddIg==
# [GET]   -> fetched 200 (rep: 'Adverse Events With Sustained-Release Donepezil in Alzheimer Disease...')
# [GET]   -> total accumulated: 5200 | next_cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI2MDE3NzI0NTYnXSI=
# [GET] Seoul National University | page=27 cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI2MDE3NzI0NTYnXSI=
# [GET]   -> fetched 200 (rep: 'Host Cell Nuclear Localization of Shigella flexneri Effector OspF Is Facilitated...')
# [GET]   -> total accumulated: 5400 | next_cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI1ODU0MTI5MjUnXSI=
# [GET] Seoul National University | page=28 cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI1ODU0MTI5MjUnXSI=
# [GET]   -> fetched 200 (rep: 'Tubular B7-1 expression parallels proteinuria levels, but not clinical outcomes ...')
# [GET]   -> total accumulated: 5600 | next_cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3NzU1Mjg4NTMnXSI=
# [GET] Seoul National University | page=29 cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3NzU1Mjg4NTMnXSI=
# [GET]   -> fetched 200 (rep: 'The Power of Simultaneous Multi-frequency Observations for mm-VLBI: Beyond Frequ...')
# [GET]   -> total accumulated: 5800 | next_cursor=Ils3LCA4My4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3
MCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjczNjc5NDgzOCddIg==
# [GET]   -> fetched 200 (rep: 'Prevalence of Self-Perceived Snoring and Apnea and Their Association with Daytim...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils3LCA4My4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3MzQ0MDY4MDgnXSI=
# [GET] Chungnam National University | page=7 cursor=Ils3LCA4My4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3MzQ0MDY4MDgnXSI=
# [GET]   -> fetched 200 (rep: 'Regulation of cardiac Ca2+ and ion channels by shear mechanotransduction...')
# [GET]   -> total accumulated: 1400 | next_cursor=Ils0LCA3OS4wLCA0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI1NjgyNzQ4OTUnXSI=
# [GET] Chungnam National University | page=8 cursor=Ils0LCA3OS4wLCA0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI1NjgyNzQ4OTUnXSI=
# [GET]   -> fetched 200 (rep: 'Parametric analysis and optimized torque characteristics of a coaxial magnetic g...')
# [GET]   -> total accumulated: 1600 | next_cursor=IlsyLCA3NC4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3MzYxNjU5NDknXSI=
# [GET] Chungnam National University | page=9 cursor=IlsyLCA3NC4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3MzYxNjU5NDknXSI=
# [GET]   -> fetched 200 (rep: 'A Structural Analysis on the Creativity, Self-Leadership, Self-Determination, Ca...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlsxLCA3MS4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI4ODU1NzE0MzMnXSI=
# [GET] Chungnam National University | page=10 cursor=IlsxLCA3MS4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI4ODU1NzE0MzMnXSI=
# [GET]   -> fetched 200 (rep: 'Erratum to: Symptom clusters during palliative chemotherapy and their influence ...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlswLCA2My4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3NjYzOTc4MjAnXSI=
# [GET] Chungnam National University | page=11 cursor=IlswLCA2My4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI3NjYzOTc4MjAnXSI=
# [GET]   -> fetched 138 (rep: 'Area-level Socioeconomic Deprivation Affect Individual Cancer Mortality in Korea...')
# [GET]   -> total accumulated: 2138 | next_cursor=IlswLCA2My4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDg1MTM0NzEnXSI=
# [GET] Chungnam National University | page=12 cursor=IlswLCA2My4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQ0MDg1MTM0NzEnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Chungnam National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2017_with_authors/works_top10000_2017_Chungnam_National_University.csv (n=2138)
# [DONE] Total rows: 52661
# [DONE] Saved to: /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2017_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W2604154346
# 1  https://openalex.org/W2746615960
# 2  https://openalex.org/W2747068989
# 3  https://openalex.org/W2767815049
# 4  https://openalex.org/W2735321801
#
#                                                title  publication_year  \
# 0  Psychometric properties of the Turkish version...              2017
# 1  The persistency and volatility of the firm R&a...              2017
# 2  Sources of social support, job satisfaction, a...              2017
# 3  DJ-1 controls bone homeostasis through the reg...              2017
# 4  Programmed Cell Death 1 (PD-1) and Cytotoxic T...              2017
#
#   publication_date     type                                   host_venue  \
# 0       2017-01-02  article   Psychiatry and Clinical Psychopharmacology
# 1       2017-08-14  article                              Research Policy
# 2       2017-08-18  article                   The Social Science Journal
# 3       2017-11-09  article                        Nature Communications
# 4       2017-07-13   review  International Journal of Molecular Sciences
#
#    cited_by_count  is_oa oa_status language  ...  \
# 0             117   True      gold       en  ...
# 1              96  False    closed       en  ...
# 2              96  False    closed       en  ...
# 3              96   True      gold       en  ...
# 4              95   True      gold       en  ...
#
#                                             abstract authors_count  \
# 0  Objective: The shortage of cross-culturally va...             9
# 1                                               None             3
# 2  Although literature has suggested a link betwe...             2
# 3  Receptor activator of NF-kB ligand (RANKL) gen...            14
# 4  Virus-specific cluster of differentiation 8 (C...             4
#
#                                           author_ids  \
# 0  A5089545346;A5009201584;A5073661627;A504587486...
# 1                A5004478892;A5025283796;A5091261738
# 2                            A5075950841;A5048198293
# 3  A5043210533;A5071611789;A5029720644;A501791781...
# 4    A5010214504;A5063121258;A5023697227;A5067074791
#
#                                         author_names  \
# 0  Vahdet Görmez;Ayşe Kılınçaslan;Abdurrahman Cah...
# 1            Taewon Kang;Chulwoo Baek;Jeong‐Dong Lee
# 2                            Jongil Yuh;Sungsil Choi
# 3  Hyuk Soon Kim;Seung Taek Nam;Se Hwan Mun;Sun‐K...
# 4   Hyosun Cho;Hyojeung Kang;Hwan Lee;Chang Wook Kim
#
#                                     author_positions  \
# 0  first;middle;middle;middle;middle;middle;middl...
# 1                                  first;middle;last
# 2                                         first;last
# 3  first;middle;middle;middle;middle;middle;middl...
# 4                           first;middle;middle;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0002-2704-9520;https://...
# 1  https://orcid.org/0000-0001-5388-1604;https://...
# 2              https://orcid.org/0000-0001-7482-4182
# 3  https://orcid.org/0000-0002-0566-0142;https://...
# 4  https://orcid.org/0000-0001-9131-5742;https://...
#
#                                  author_affiliations  \
# 0  Bezmiâlem Vakıf Üniversitesi;Istanbul Universi...
# 1  Seoul National University;Duksung Women's Univ...
# 2  Duksung Women's University;Duksung Women's Uni...
# 3  Konkuk University;Konkuk University;Konkuk Uni...
# 4  Duksung Women's University;Kyungpook National ...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2016_with_authors"
YEAR = 2016
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungbuk National University | id=https://openalex.org/I163753206
# [MAP] OK (EN): Chungbuk National University -> Chungbuk National University | institutions.id=I163753206
# [MAP] [23/23] resolving 'Chungnam National University'
# [MAP] Try EN: Chungnam National University
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungnam National University' (relax=False)
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungnam National University | id=https://openalex.org/I196345858
# [MAP] OK (EN): Chungnam National University -> Chungnam National University | institutions.id=I196345858
# [MAP] saved mapping -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2016_with_authors/institutions_mapping.csv
#                                            query_name institution_id  \
# 0                          Duksung Women's University      I65832422
# 1                           Seoul National University     I139264467
# 2                                    Korea University      I88761825
# 3                                   Yonsei University     I193775966
# 4   Korea Advanced Institute of Science and Techno...     I157485424
# 5                                   Sogang University     I148751991
# 6                             Sungkyunkwan University        I848706
# 7                                  Hanyang University     I109995039
# 8         Pohang University of Science and Technology     I123900574
# 9         Gwangju Institute of Science and Technology      I39534123
# 10  Daegu Gyeongbuk Institute of Science and Techn...     I193352282
# 11  Ulsan National Institute of Science and Techno...      I48566637
# 12                               Chung-Ang University      I67900169
# 13                               Kyung Hee University     I160888826
# 14                        Kangwon National University     I165507594
# 15                      Kyungpook National University      I31419693
# 16                     Gyeongsang National University     I189442560
# 17                          Pusan National University       I4921948
MCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzA5ODkxMzcwNCddIg==
# [GET]   -> fetched 200 (rep: 'Estimation of Poverty Transition Matrices with Noisy Data...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQ3NTEzNzI4MCddIg==
# [GET] Seoul National University | page=13 cursor=IlsyOSwgOTQuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQ3NTEzNzI4MCddIg==
# [GET]   -> fetched 200 (rep: 'Online Scheme for Multiple Camera Multiple Target Tracking Based on Multiple Hyp...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU2NjM1MTQ1NiddIg==
# [GET] Seoul National University | page=14 cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU2NjM1MTQ1NiddIg==
# [GET]   -> fetched 200 (rep: 'Carbon Isotopomer Analysis with Non-Unifom Sampling HSQC NMR for Cell Extract an...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNSwgOTMuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU2NTU1NTY4NSddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNSwgOTMuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU2NTU1NTY4NSddIg==
# [GET]   -> fetched 200 (rep: 'Comparison of the Atomic Layer Deposition of Tantalum Oxide Thin Films Using Ta(...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU2MDIzMzEzOSddIg==
# [GET] Seoul National University | page=16 cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU2MDIzMzEzOSddIg==
# [GET]   -> fetched 200 (rep: 'Authigenic Nd isotope record of North Pacific Intermediate Water formation and b...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMSwgOTIuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxMzYzNjk2MSddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMSwgOTIuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxMzYzNjk2MSddIg==
# [GET]   -> fetched 200 (rep: 'Future perspectives of sustainable manufacturing and applications based on resea...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxOSwgOTEuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI5NDg4OTcxNSddIg==
# [GET] Seoul National University | page=18 cursor=IlsxOSwgOTEuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI5NDg4OTcxNSddIg==
# [GET]   -> fetched 200 (rep: 'Osteoporotic Fracture Risk Assessment Using Bone Mineral Density in Korean: A Co...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxOCwgOTEuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUzMzcxOTgxMSddIg==
# [GET] Seoul National University | page=19 cursor=IlsxOCwgOTEuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUzMzcxOTgxMSddIg==
# [GET]   -> fetched 200 (rep: 'On the number of users served in MIMO-NOMA cellular networks...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI3MDg2NzMzNSddIg==
# [GET] Seoul National University | page=20 cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI3MDg2NzMzNSddIg==
# [GET]   -> fetched 200 (rep: 'Microtube Light-Emitting Diode Arrays with Metal Cores...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxMDQ3NTY5NyddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxMDQ3NTY5NyddIg==
# [GET]   -> fetched 200 (rep: 'Prevalence of Soil-Transmitted Helminths and Molecular Clarification of Hookworm...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU1NDUzMzQzMiddIg==
# [GET] Seoul National University | page=22 cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU1NDUzMzQzMiddIg==
# [GET]   -> fetched 200 (rep: 'A method to directly derive taste heterogeneity of travellers’ route choice in p...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxMiwgODguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI1Mzk3MDQzNiddIg==
# [GET] Seoul National University | page=23 cursor=IlsxMiwgODguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI1Mzk3MDQzNiddIg==
# [GET]   -> fetched 200 (rep: 'Penetration and exchange kinetics of primary alkyl amines applied to reactive po...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMwMjQxMzExOSddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMwMjQxMzExOSddIg==
# [GET]   -> fetched 200 (rep: 'Methodological Quality Appraisal of 27 Korean Guidelines Using a Scoring Guide B...')
# [GET]   -> total accumulated: 4800 | next_cursor=IlsxMCwgODcuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMwODI3NDg3NSddIg==
# [GET] Seoul National University | page=25 cursor=IlsxMCwgODcuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMwODI3NDg3NSddIg==
# [GET]   -> fetched 200 (rep: 'Enhancement of fracture toughness in organic/inorganic hybrid nanolaminates with...')
# [GET]   -> total accumulated: 5000 | next_cursor=Ils5LCA4Ni4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzNDM3MDIxMDcnXSI=
# [GET] Seoul National University | page=26 cursor=Ils5LCA4Ni4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzNDM3MDIxMDcnXSI=
# [GET]   -> fetched 200 (rep: 'Non-Contact Measurement of Thermophysical Properties of Fe, Fe–C, and Fe–C–Mn Al...')
# [GET]   -> total accumulated: 5200 | next_cursor=Ils4LCA4NS4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzMzUxMjA2MDYnXSI=
# [GET] Seoul National University | page=27 cursor=Ils4LCA4NS4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzMzUxMjA2MDYnXSI=
# [GET]   -> fetched 200 (rep: 'The Clinical Stages of Sporadic Creutzfeldt-Jakob Disease with Met/Met Genotype ...')
# [GET]   -> total accumulated: 5400 | next_cursor=Ils3LCA4NC4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzMDczMzU4ODEnXSI=
# [GET] Seoul National University | page=28 cursor=Ils3LCA4NC4wLCA3LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzMDczMzU4ODEnXSI=
# [GET]   -> fetched 200 (rep: 'Integrating Epitaxial-Like Pb(Zr,Ti)O3 Thin-Film into Silicon for Next-Generatio...')
# [GET]   -> total accumulated: 5600 | next_cursor=Ils2LCA4My4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIyOTA1NjA0MjcnXSI=
# [GET] Seoul National University | page=29 cursor=Ils2LCA4My4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIyOTA1NjA0MjcnXSI=
# [GET]   -> fetched 200 (rep: 'Morphological features and lipopolysaccharide attachment of coliphages specific ...')
# [GET]   -> total accumulated: 5800 | next_cursor=Ils2LCA4My4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI1NTcxODEzNjgnXSI=
# [GET] Seoul National University | page=30 cursor=Ils2LCA4My4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI1NTcxODEzNjgnXSI=
# [GET]   -> fetched 200 (rep: 'Cyclic Voltammetry on CeCl3 in LiCl-KCl Eutectic Using W and Bi Coated Electrode...')
# [GET]   -> total accumulated: 6000 | next_cursor=Ils1LCA4Mi4wLCA1LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI
sICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxOTI4NTU3OSddIg==
# [GET]   -> fetched 200 (rep: 'Perioperative and short‐term outcomes of Retzius‐sparing robot‐assisted laparosc...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlsyOCwgOTQuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxMjIxMTM0OCddIg==
# [GET] Yonsei University | page=10 cursor=IlsyOCwgOTQuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxMjIxMTM0OCddIg==
# [GET]   -> fetched 200 (rep: 'Generalized formulation for shear resistance on Y-type perfobond rib shear conne...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlsyNSwgOTMuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU0OTA3NjY4MiddIg==
# [GET] Yonsei University | page=11 cursor=IlsyNSwgOTMuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU0OTA3NjY4MiddIg==
# [GET]   -> fetched 200 (rep: 'Altered intrinsic brain activity after chemotherapy in patients with gastric can...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjM0NjU4NzA5OCddIg==
# [GET] Yonsei University | page=12 cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjM0NjU4NzA5OCddIg==
# [GET]   -> fetched 200 (rep: 'Visual Presence: Viewing Geometry Visual Information of UHD S3D Entertainment...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQxNDA5NTA5MCddIg==
# [GET] Yonsei University | page=13 cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQxNDA5NTA5MCddIg==
# [GET]   -> fetched 200 (rep: 'Development and Characterization of PCE-to-Ethene Dechlorinating Microcosms with...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsxOCwgOTEuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQwNTg3NDUxMiddIg==
# [GET] Yonsei University | page=14 cursor=IlsxOCwgOTEuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQwNTg3NDUxMiddIg==
# [GET]   -> fetched 200 (rep: 'Cell Type Preference of a Novel Human Derived Cell-Permeable Peptide dNP2 and TA...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjM0MDU2ODM0MyddIg==
# [GET] Yonsei University | page=15 cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjM0MDU2ODM0MyddIg==
# [GET]   -> fetched 200 (rep: 'Depression in the Family of Patients With Dementia in Korea...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU1ODkzNzk2MSddIg==
# [GET] Yonsei University | page=16 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU1ODkzNzk2MSddIg==
# [GET]   -> fetched 200 (rep: 'An analytic expansion method for the valuation of double-barrier options under a...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjM5NDUwMjQxMCddIg==
# [GET] Yonsei University | page=17 cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjM5NDUwMjQxMCddIg==
# [GET]   -> fetched 200 (rep: 'Abdominal Aortic Calcification in Living Kidney Donors...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxMiwgODguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxMDQwOTYyMSddIg==
# [GET] Yonsei University | page=18 cursor=IlsxMiwgODguMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjUxMDQwOTYyMSddIg==
# [GET]   -> fetched 200 (rep: 'Tumor characteristics associated with malignant large bowel obstruction in stage...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjU2MDI2Nzk5MiddIg==
# [GET] Yonsei University | page=19 cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XM
# 3  Sooyeon Suh;Hae-Chung Yang;Nan Hee Kim;Ji Hee ...
# 4                         Tae Eun Guon;Ha Sook Chung
#
#                                     author_positions  \
# 0                                         first;last
# 1  first;middle;middle;middle;middle;middle;middl...
# 2                    first;middle;middle;middle;last
# 3      first;middle;middle;middle;middle;middle;last
# 4                                         first;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0002-8398-955X;https://...
# 1  https://orcid.org/0000-0002-3548-9681;https://...
# 2  https://orcid.org/0000-0002-8133-6440;https://...
# 3  https://orcid.org/0000-0003-0644-8634;https://...
# 4              https://orcid.org/0000-0001-9983-6489
#
#                                  author_affiliations  \
# 0  Duksung Women's University;Ewha Womans University
# 1  Boston University;Claremont McKenna College;Th...
# 2  Duksung Women's University;University of Hawai...
# 3  Sungshin Women's University|Palo Alto Universi...
# 4  Duksung Women's University;Duksung Women's Uni...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2015_with_authors"
YEAR = 2015
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungbuk National University | id=https://openalex.org/I163753206
# [MAP] OK (EN): Chungbuk National University -> Chungbuk National University | institutions.id=I163753206
# [MAP] [23/23] resolving 'Chungnam National University'
# [MAP] Try EN: Chungnam National University
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungnam National University' (relax=False)
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungnam National University | id=https://openalex.org/I196345858
# [MAP] OK (EN): Chungnam National University -> Chungnam National University | institutions.id=I196345858
# [MAP] saved mapping -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2015_with_authors/institutions_mapping.csv
#                                            query_name institution_id  \
# 0                          Duksung Women's University      I65832422
# 1                           Seoul National University     I139264467
# 2                                    Korea University      I88761825
# 3                                   Yonsei University     I193775966
# 4   Korea Advanced Institute of Science and Techno...     I157485424
# 5                                   Sogang University     I148751991
# 6                             Sungkyunkwan University        I848706
# 7                                  Hanyang University     I109995039
# 8         Pohang University of Science and Technology     I123900574
# 9         Gwangju Institute of Science and Technology      I39534123
# 10  Daegu Gyeongbuk Institute of Science and Techn...     I193352282
# 11  Ulsan National Institute of Science and Techno...      I48566637
# 12                               Chung-Ang University      I67900169
# 13                               Kyung Hee University     I160888826
# 14                        Kangwon National University     I165507594
# 15                      Kyungpook National University      I31419693
# 16                     Gyeongsang National University     I189442560
# 17                          Pusan National University       I4921948
# 18                        Chonnam National University     I111277659
# 19                        Jeonbuk National University      I80611190
# 20                           Jeju National University      I83202590
# 21                       Chungbuk National University     I163753206
# 22                       Chungnam National University     I196345858
#
#                                          display_name
# 0                          Duksung Women's University
# 1                           Seoul National University
# 2          Korea University of Science and Technology
# 3                                   Yonsei University
# 4   Korea Advanced Institute of Science and Techno...
# 5                                   Sogang University
# 6                             Sungkyunkwan University
# 7                            Hanyang Cyber University
# 8         Pohang University of Science and Technology
# 9         Gwangju Institute of Science and Technology
# 10  Daegu Gyeongbuk Institute of Science and Techn...
ksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjIwOTczMTUzMyddIg==
# [GET] Seoul National University | page=14 cursor=IlsyOSwgOTMuMCwgMjksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjIwOTczMTUzMyddIg==
# [GET]   -> fetched 200 (rep: 'Decrease of 5hmC in gastric cancers is associated with<i>TET1</i>silencing due t...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNiwgOTMuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk1MDEyMTc5MCddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNiwgOTMuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk1MDEyMTc5MCddIg==
# [GET]   -> fetched 200 (rep: 'Membership representation for detecting block-diagonal structure in low-rank or ...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyNSwgOTMuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XOTUxODg1NjE4J10i
# [GET] Seoul National University | page=16 cursor=IlsyNSwgOTMuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XOTUxODg1NjE4J10i
# [GET]   -> fetched 200 (rep: 'Effect of surfactant, HCl and NH3 treatments on the regeneration of waste activa...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQ2MjE3ODI1NyddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjQ2MjE3ODI1NyddIg==
# [GET]   -> fetched 200 (rep: 'Three-qubit entanglement witnesses with the full spanning properties...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE2NTgwODIzMyddIg==
# [GET] Seoul National University | page=18 cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE2NTgwODIzMyddIg==
# [GET]   -> fetched 200 (rep: 'Microenvironmental Interaction Between Hypoxia and Endothelial Cells Controls th...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxOSwgOTEuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU5MDUwMDM5NSddIg==
# [GET] Seoul National University | page=19 cursor=IlsxOSwgOTEuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU5MDUwMDM5NSddIg==
# [GET]   -> fetched 200 (rep: 'Pulmonary Nodule Detection in Patients with a Primary Malignancy Using Hybrid PE...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI4ODg0NDIyNiddIg==
# [GET] Seoul National University | page=20 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjI4ODg0NDIyNiddIg==
# [GET]   -> fetched 200 (rep: 'Assessment of carbon nanotube dispersion and mechanical property of epoxy nanoco...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTczOTA0NjQzNCddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTczOTA0NjQzNCddIg==
# [GET]   -> fetched 200 (rep: 'Dehydrodiconiferyl alcohol (DHCA) modulates the differentiation of Th17 and Th1 ...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NTgwNTg5NyddIg==
# [GET] Seoul National University | page=22 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NTgwNTg5NyddIg==
# [GET]   -> fetched 200 (rep: 'Sublingual Immunization of Trivalent Human Papillomavirus DNA Vaccine in Baculov...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XM
| next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI0Nzc4MDI2MDYnXSI=
# [GET] Seoul National University | page=45 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI0Nzc4MDI2MDYnXSI=
# [GET]   -> fetched 200 (rep: 'Effect of Sidewall Configurations on Hypersonic Intake Performance...')
# [GET]   -> total accumulated: 9000 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI2MTA2ODYzMDQnXSI=
# [GET] Seoul National University | page=46 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI2MTA2ODYzMDQnXSI=
# [GET]   -> fetched 200 (rep: 'Synrtgistic effects of nanotopography and surface matrix patterning on contact g...')
# [GET]   -> total accumulated: 9200 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNDY2MjIxOTgnXSI=
# [GET] Seoul National University | page=47 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNDY2MjIxOTgnXSI=
# [GET]   -> fetched 192 (rep: 'SP141&lt;break /&gt;THE DECREMENT OF HEMOGLOBIN CONCENTRATION WITH ANGIOTENSIN I...')
# [GET]   -> total accumulated: 9392 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk5NzU4MzM4MiddIg==
# [GET] Seoul National University | page=48 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk5NzU4MzM4MiddIg==
# [GET]   -> empty batch (stop).
# [SAVE] Seoul National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2015_with_authors/works_top10000_2015_Seoul_National_University.csv (n=9392)
# [RUN] Fetch top-10000 (year=2015) for Korea University (Korea University of Science and Technology) → institutions.id=I88761825
# [GET] Korea University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Surface Plasmon Resonance: A Versatile Technique for Biosensor Applications...')
# [GET]   -> total accumulated: 200 | next_cursor=Ils1NCwgOTcuMCwgNTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk1OTM4MDA0OCddIg==
# [GET] Korea University | page=2 cursor=Ils1NCwgOTcuMCwgNTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk1OTM4MDA0OCddIg==
# [GET]   -> fetched 200 (rep: 'Ginkgetin inhibits the growth of <scp>DU</scp>−145 prostate cancer cells through...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzNjgzODgzMyddIg==
# [GET] Korea University | page=3 cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzNjgzODgzMyddIg==
# [GET]   -> fetched 200 (rep: 'Compact, lightweight, and highly efficient circular heat sink design for high-en...')
# [GET]   -> total accumulated: 600 | next_cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XOTEyMjQ2MTg5J10i
# [GET] Korea University | page=4 cursor=IlsxNiwgOTAuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XOTEyMjQ2MTg5J10i
# [GET]   -> fetched 200 (rep: 'Deposition and characterization of E-paint on magnesium alloys...')
# [GET]   -> total accumulated: 800 | next_cursor=Ils5LCA4Ni4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxMTIwMDAyMCddIg==
# [GET] Korea University | page=5 cursor=Ils5LCA4Ni4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxMTIwMDAyMCddIg==
# [GET]   -> fetched 200 (rep: 'Synthesis and biological evaluation of picolinamides and thiazole-2-carboxamides...')
# [GET]   -> total accumulated: 1000 | next_cursor=Ils0LCA4MC4wLCA0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI0OTAxODAxMTEnXSI=
# [GET] Korea University | page=6 cursor=Ils0LCA4MC4wLCA0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI0OTAxODAxMTEnXSI=
# [GET]   -> fetched 200 (rep: 'Microstructural and Ferroelectric Properties of Bi&lt;sub&gt;0.5&lt;/sub&gt;(Na,...')
# [GET]   -> total accumulated: 1200 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzE5NzY1OTg3NTknXSI=
# [GET] Korea University | page=7 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzE5NzY1OTg3NTknXSI=
# [GET]   -> fetched 134 (rep: 'Temperature-dependent structural behavior of mixed-metal hydroxides in air...')
# [GET]   -> total accumulated: 1334 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk0ODI2MDk0NCddIg==
# [GET] Korea University | page=8 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk0ODI2MDk0NCddIg==
# [GET]   -> empty batch (stop).
# [SAVE] Korea University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_
ursor=IlsxLCA3My4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIzMzE2ODQwNjInXSI=
# [GET]   -> fetched 200 (rep: 'Phylogenetic Groups and Virulence Factors of <i>Escherichia coli</i> Causing Uri...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIyNDcyNDA3NDUnXSI=
# [GET] Chungnam National University | page=11 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIyNDcyNDA3NDUnXSI=
# [GET]   -> fetched 200 (rep: 'Development of stretchable strain sensor using elastic fibrous membrane coated w...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyNDQ2NTA2MTUnXSI=
# [GET] Chungnam National University | page=12 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyNDQ2NTA2MTUnXSI=
# [GET]   -> fetched 23 (rep: 'Faculty Opinions recommendation of Amino-terminal arginylation targets endoplasm...')
# [GET]   -> total accumulated: 2223 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzc4MTc5NjIzMCddIg==
# [GET] Chungnam National University | page=13 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzc4MTc5NjIzMCddIg==
# [GET]   -> empty batch (stop).
# [SAVE] Chungnam National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2015_with_authors/works_top10000_2015_Chungnam_National_University.csv (n=2223)
# [DONE] Total rows: 53070
# [DONE] Saved to: /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2015_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W2132922452
# 1  https://openalex.org/W2019507092
# 2  https://openalex.org/W2036439337
# 3  https://openalex.org/W2206531137
# 4  https://openalex.org/W2230175145
#
#                                                title  publication_year  \
# 0  A microengineered pathophysiological model of ...              2015
# 1  Irisin, a Novel Myokine, Regulates Glucose Upt...              2015
# 2  RViz: a toolkit for real domain data visualiza...              2015
# 3  Mutual Authentication Scheme in Secure Interne...              2015
# 4  Natural Products for Chemoprevention of Breast...              2015
#
#   publication_date     type                    host_venue  cited_by_count  \
# 0       2015-01-01  article                 Lab on a Chip             214
# 1       2015-04-01  article       Molecular Endocrinology             193
# 2       2015-04-15  article     Telecommunication Systems             165
# 3       2015-12-24  article                       Sensors             142
# 4       2015-12-30   review  Journal of Cancer Prevention             133
#
#    is_oa oa_status language  ...  \
# 0   True     green       en  ...
# 1   True    bronze       en  ...
# 2  False    closed       en  ...
# 3   True      gold       en  ...
# 4   True      gold       en  ...
#
#                                             abstract authors_count  \
# 0  A mounting body of evidence in cancer research...            10
# 1  Irisin is a novel myokine produced by skeletal...            13
# 2                                               None             4
# 3  The Internet of Things (IoT), which can be reg...             2
# 4  Breast cancer is the primary cause of cancer d...             2
#
#                                           author_ids  \
# 0  A5107006393;A5011047099;A5072839636;A502742460...
# 1  A5100743829;A5110004190;A5052092637;A503170196...
# 2    A5001183035;A5100402780;A5061685064;A5053313621
# 3                            A5032079311;A5110295646
# 4                            A5065134845;A5083115378
#
#                                         author_names  \
# 0  Yoon‐Seok Choi;Eunjeh Hyun;Jeongyun Seo;Cassid...
# 1  Hye Jeong Lee;Jung Ok Lee;Nami Kim;Joong Kwan ...
# 2  Hyeong Ryeol Kam;Sung-Ho Lee;Taejung Park;Chan...
# 3                              Namje Park;Namhi Kang
# 4                                 EunYi Ko;Aree Moon
#
#                                     author_positions  \
# 0  first;middle;middle;middle;middle;middle;middl...
# 1  first;middle;middle;middle;middle;middle;middl...
# 2                           first;middle;middle;last
# 3                                         first;last
# 4                                         first;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0003-4794-4263;https://...
# 1  https://orcid.org/0000-0003-4535-9511;https://...
# 2  https://orcid.org/0000-0001-9114-2319;https://...
# 3              https://orcid.org/0000-0003-4434-8933
# 4
#
#                                  author_affiliations  \
# 0  Government of the Republic of Korea|Seoul Nati...
# 1  Korea University;Korea University;Korea Univer...
# 2  Korea University;Duksung Women's University;Ko...
# 3  Jeju National University;Duksung Women's Unive...
# 4  Duksung Women's University;Duksung Women's Uni...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2014_with_authors"
YEAR = 2014
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for '
#                           Seoul National University     I139264467                           Seoul National University
#                                    Korea University      I88761825          Korea University of Science and Technology
#                                   Yonsei University     I193775966                                   Yonsei University
#  Korea Advanced Institute of Science and Technology     I157485424  Korea Advanced Institute of Science and Technology
#                                   Sogang University     I148751991                                   Sogang University
#                             Sungkyunkwan University        I848706                             Sungkyunkwan University
#                                  Hanyang University     I109995039                            Hanyang Cyber University
#         Pohang University of Science and Technology     I123900574         Pohang University of Science and Technology
#         Gwangju Institute of Science and Technology      I39534123         Gwangju Institute of Science and Technology
# Daegu Gyeongbuk Institute of Science and Technology     I193352282 Daegu Gyeongbuk Institute of Science and Technology
#  Ulsan National Institute of Science and Technology      I48566637  Ulsan National Institute of Science and Technology
#                                Chung-Ang University      I67900169                                Chung-Ang University
#                                Kyung Hee University     I160888826                          Kyung Hee Cyber University
#                         Kangwon National University     I165507594                         Kangwon National University
#                       Kyungpook National University      I31419693                       Kyungpook National University
#                      Gyeongsang National University     I189442560                      Gyeongsang National University
#                           Pusan National University       I4921948                           Pusan National University
#                         Chonnam National University     I111277659                         Chonnam National University
#                         Jeonbuk National University      I80611190                         Jeonbuk National University
#                            Jeju National University      I83202590                            Jeju National University
#                        Chungbuk National University     I163753206                        Chungbuk National University
#                        Chungnam National University     I196345858                        Chungnam National University
# [RUN] Fetch top-10000 (year=2014) for Duksung Women's University (Duksung Women's University) → institutions.id=I65832422
# [GET] Duksung Women's University | page=1 cursor=*
# [GET]   -> fetched 114 (rep: 'Neuropilin-1 functions as a VEGFR2 co-receptor to guide developmental angiogenes...')
# [GET]   -> total accumulated: 114 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMzkwODIxNDMnXSI=
# [GET] Duksung Women's University | page=2 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzQyMzkwODIxNDMnXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Duksung Women's University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2014_with_authors/works_top10000_2014_Duksung_Women's_University.csv (n=114)
# [RUN] Fetch top-10000 (year=2014) for Seoul National University (Seoul National University) → institutions.id=I139264467
# [GET] Seoul National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Towards a taxonomic coherence between average nucleotide identity and 16S rRNA g...')
# [GET]   -> total accumulated: 200 | next_cursor=IlsxNzQsIDk5LjAsIDE3NCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDkyMDI0ODcxJ10i
# [GET] Seoul National University | page=2 cursor=IlsxNzQsIDk5LjAsIDE3NCwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDkyMDI0ODcxJ10i
# [GET]   -> fetched 200 (rep: 'A Self-Reducible and Alcohol-Soluble Copper-Based Metal–Organic Decomposition In...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsxMTksIDk5LjAsIDExOSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMzI1NDIwMjQ1J10i
# [GET] Seoul National University | page=3 cursor=IlsxMTksIDk5LjAsIDExOSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMzI1NDIwMjQ1J10i
# [GET]   -> fetched 200 (rep: 'Dynamics and control of quadrotor with robotic manipulator...')
# [GET]   -> total accumulated: 600 | next_cursor=Ils5NSwgOTguMCwgOTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk4MTc3NTEwNCddIg==
# [GET] Seoul National University | page=4 cursor=Ils5NSwgOTguMCwgOTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk4MTc3NTEwNCddIg==
# [GET]   -> fetched 200 (rep: 'Highly Efficient Copper–Zinc–Tin–Selenide (CZTSe) Solar Cells by Electrodepositi...')
# [GET]   -> total accumulated: 800 | next_cursor=Ils4MCwgOTguMCwgODAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk1MDIyMTg0NiddIg==
# [GET] Seoul National University | page=5 cursor=Ils4MCwgOTguMCwgODAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjk1MDIyMTg0NiddIg==
# [GET]   -> fetched 200 (rep: 'miR-124 Negatively Regulates Osteogenic Differentiation and In vivo Bone Formati...')
# [GET]   -> total accumulated: 1000 | next_cursor=Ils2NywgOTcuMCwgNjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA0MzA4MzgzNSddIg==
# [GET] Seoul National University | page=6 cursor=Ils2NywgOTcuMCwgNjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA0MzA4MzgzNSddIg==
# [GET]   -> fetched 200 (rep: 'Heat transfer and film cooling effectiveness on the squealer tip of a turbine bl...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils1OCwgOTcuMCwgNTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMxNjY4MzY0MyddIg==
# [GET] Seoul National University | page=7 cursor=Ils1OCwgOTcuMCwgNTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMxNjY4MzY0MyddIg==
# [GET]   -> fetched 200 (rep: 'Development of an Engineered Bioluminescent Reporter Phage for the Sensitive Det...')
# [GET]   -> total accumulated: 1400 | next_cursor=Ils1MCwgOTYuMCwgNTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU0MDY1MDI3NCddIg==
# [GET] Seoul National University | page=8 cursor=Ils1MCwgOTYuMCwgNTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU0MDY1MDI3NCddIg==
# [GET]   -> fetched 200 (rep: 'The Molecular Mechanism Underlying the Proliferating and Preconditioning Effect ...')
# [GET]   -> total accumulated: 1600 | next_cursor=Ils0NiwgOTYuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE1MTQ3NTU3MCddIg==
# [GET] Seoul National University | page=9 cursor=Ils0NiwgOTYuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE1MTQ3NTU3MCddIg==
# [GET]   -> fetched 200 (rep: 'Long-term prognosis of clinically early IgA nephropathy is not always favorable...')
# [GET]   -> total accumulated: 1800 | next_cursor=Ils0MiwgOTUuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwMTMxOTIwMCddIg==
# [GET] Seoul National University | page=10 cursor=Ils0MiwgOTUuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwMTMxOTIwMCddIg==
# [GET]   -> fetched 200 (rep: 'Vitamin C treatment of mouse bone marrow-derived dendritic cells enhanced CD8+ m...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlszOCwgOTUuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk4OTczMzQzNyddIg==
# [GET] Seoul National University | page=11 cursor=IlszOCwgOTUuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk4OTczMzQzNyddIg==
# [GET]   -> fetched 200 (rep: 'ADRM1 gene amplification is a candidate driver for metastatic gastric cancers...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlszNSwgOTQuMCwgMzUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxMzA2Mzk2NSddIg==
# [GET] Seoul National University | page=12 cursor=IlszNSwgOTQuMCwgMzUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxMzA2Mzk2NSddIg==
# [GET]   -> fetched 200 (rep: 'Identification and Trust in Public Organizations: A communicative approach...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlszMiwgOTQuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk5OTUwMzUxMSddIg==
# [GET] Seoul National University | page=13 cursor=IlszMiwgOTQuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk5OTUwMzUxMSddIg==
# [GET]   -> fetched 200 (rep: 'Fabrication of an ultrafine-grained structure by a compositional pinning techniq...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlszMCwgOTQuMCwgMzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzMjI5NDI1OCddIg==
# [GET] Seoul National University | page=14 cursor=IlszMCwgOTQuMCwgMzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzMjI5NDI1OCddIg==
# [GET]   -> fetched 200 (rep: 'Electrorheological activity generation by graphene oxide coating on low-dielectr...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTkwNDg4MjQ1MyddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTkwNDg4MjQ1MyddIg==
# [GET]   -> fetched 200 (rep: 'Predicting structural change of lignin macromolecules before and after heat trea...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyNSwgOTIuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyNjU4MjExOSddIg==
# [GET] Seoul National University | page=16 cursor=IlsyNSwgOTIuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyNjU4MjExOSddIg==
# [GET]   -> fetched 200 (rep: 'Tumor-suppressive effect of a telomerase-derived peptide by inhibiting hypoxia-i...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyMTQ1NzkxMyddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMywgOTIuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyMTQ1NzkxMyddIg==
# [GET]   -> fetched 200 (rep: 'Ultrasonographic severity scoring of non-immune hydrops: a predictor of perinata...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU4NjYyNDg2MCddIg==
# [GET] Seoul National University | page=18 cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU4NjYyNDg2MCddIg==
# [GET]   -> fetched 200 (rep: 'Petrofabrics of olivine in a rift axis and rift shoulder and their implications ...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3MDIwODk2NyddIg==
# [GET] Seoul National University | page=19 cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3MDIwODk2NyddIg==
# [GET]   -> fetched 200 (rep: 'Spatially Controlled Graphitization of Reduced Graphene Oxide Films via a Green ...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTUxNjA0NTg4MiddIg==
# [GET] Seoul National University | page=20 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTUxNjA0NTg4MiddIg==
# [GET]   -> fetched 200 (rep: 'Effect of crosslinking reaction on the electromagnetic interference shielding of...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA2ODM1NTgzNiddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA2ODM1NTgzNiddIg==
# [GET]   -> fetched 200 (rep: 'Awareness of the adverse effects associated with prophylactic corticosteroid use...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk0NzY4ODUzMiddIg==
# [GET] Seoul National University | page=22 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk0NzY4ODUzMiddIg==
# [GET]   -> fetched 200 (rep: 'The Kunming CalFit study: Modeling dietary behavioral patterns using smartphone ...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyMDk0MDY2MiddIg==
# [GET] Seoul National University | page=23 cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyMDk0MDY2MiddIg==
# [GET]   -> fetched 200 (rep: 'Senescing Human Bone-Marrow-Derived Clonal Mesenchymal Stem Cells Have Altered L...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzMTc3ODc5OCddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzMTc3ODc5OCddIg==
# [GET]   -> fetched 200 (rep: 'False-Positive Reactions Against HLA Class II Molecules Detected in Luminex Sing...')
# [GET]   -> total accumulated: 4800 | next_cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMT
cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk5NDk1NzMwNSddIg==
# [GET]   -> empty batch (stop).
# [SAVE] Seoul National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2014_with_authors/works_top10000_2014_Seoul_National_University.csv (n=9100)
# [RUN] Fetch top-10000 (year=2014) for Korea University (Korea University of Science and Technology) → institutions.id=I88761825
# [GET] Korea University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Porous Anodic Aluminum Oxide: Anodization and Templated Synthesis of Functional ...')
# [GET]   -> total accumulated: 200 | next_cursor=IlszOCwgOTUuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA5Mjg3NDQzMCddIg==
# [GET] Korea University | page=2 cursor=IlszOCwgOTUuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA5Mjg3NDQzMCddIg==
# [GET]   -> fetched 200 (rep: 'Violapyrones H and I, New Cytotoxic Compounds Isolated from Streptomyces sp. Ass...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3Njk4MDM5MyddIg==
# [GET] Korea University | page=3 cursor=IlsxNywgOTAuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3Njk4MDM5MyddIg==
# [GET]   -> fetched 200 (rep: 'Ethanolic Extract of Taheebo Attenuates Increase in Body Weight and Fatty Liver ...')
# [GET]   -> total accumulated: 600 | next_cursor=Ils2LCA4My4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIyNDE0NjY1MjMnXSI=
# [GET] Korea University | page=4 cursor=Ils2LCA4My4wLCA2LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIyNDE0NjY1MjMnXSI=
# [GET]   -> fetched 200 (rep: 'Evaluation of Raingauge Network using Area Average Rainfall Estimation and the E...')
# [GET]   -> total accumulated: 800 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwMDg3MjM0NDknXSI=
# [GET] Korea University | page=5 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwMDg3MjM0NDknXSI=
# [GET]   -> fetched 102 (rep: 'Dopamine Transporter Inhibition by Organic Ions &amp; their Effects on GBR12909 ...')
# [GET]   -> total accumulated: 902 | next_cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzYzODk2ODU2NyddIg==
# [GET] Korea University | page=6 cursor=IlswLCA2Ni4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzYzODk2ODU2NyddIg==
# [GET]   -> empty batch (stop).
# [SAVE] Korea University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2014_with_authors/works_top10000_2014_Korea_University.csv (n=902)
# [RUN] Fetch top-10000 (year=2014) for Yonsei University (Yonsei University) → institutions.id=I193775966
# [GET] Yonsei University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Global, regional, and national prevalence of overweight and obesity in children ...')
# [GET]   -> total accumulated: 200 | next_cursor=IlsxMzMsIDk5LjAsIDEzMywgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDkyNzkyODE2J10i
# [GET] Yonsei University | page=2 cursor=IlsxMzMsIDk5LjAsIDEzMywgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDkyNzkyODE2J10i
# [GET]   -> fetched 200 (rep: 'Right sizes of nano- and microstructures for high-performance and rigid bulk the...')
# [GET]   -> total accumulated: 400 | next_cursor=Ils4NywgOTguMCwgODcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE0MDAyNDE1NCddIg==
# [GET] Yonsei University | page=3 cursor=Ils4NywgOTguMCwgODcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE0MDAyNDE1NCddIg==
# [GET]   -> fetched 200 (rep: 'Robotic Total Thyroidectomy with Modified Radical Neck Dissection via Unilateral...')
# [GET]   -> total accumulated: 600 | next_cursor=Ils2NiwgOTcuMCwgNjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwMTMyMjc1NSddIg==
# [GET] Yonsei University | page=4 cursor=Ils2NiwgOTcuMCwgNjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwMTMyMjc1NSddIg==
# [GET]   -> fetched 200 (rep: 'Parallel vs. Sequential Cascading MEP Coordination Strategies: A Pharmaceutical ...')
# [GET]   -> total accumulated: 800 | next_cursor=Ils1NSwgOTcuMCwgNTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA2MzI2NDUyMiddIg==
# [GET] Yonsei University | page=5 cursor=Ils1NSwgOTcuMCwgNTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA2MzI2NDUyMiddIg==
# [GET]   -> fetched 200 (rep: 'Feasibility of a robot-assisted thoracoscopic lymphadenectomy along the recurren...')
# [GET]   -> total accumulated: 1000 | next_cursor=Ils0NiwgOTYuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2Njc4NzAzNyddIg==
# [GET] Yonsei University | page=6 cursor=Ils0NiwgOTYuMCwgNDYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2Njc4NzAzNyddIg==
# [GET]   -> fetched 200 (rep: 'The pathophysiological role of dendritic cell subsets in psoriasis...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils0MCwgOTUuMCwgNDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NjM5NDUzMiddIg==
# [GET] Yonsei University | page=7 cursor=Ils0MCwgOTUuMCwgNDAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NjM5NDUzMiddIg==
# [GET]   -> fetched 200 (rep: 'Discovering the structure of mathematical problem solving...')
# [GET]   -> total accumulated: 1400 | next_cursor=IlszNCwgOTQuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3Nzg0NjY5NCddIg==
# [GET] Yonsei University | page=8 cursor=IlszNCwgOTQuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3Nzg0NjY5NCddIg==
# [GET]   -> fetched 200 (rep: 'Instability of 24-hour intraocular pressure fluctuation in healthy young subject...')
# [GET]   -> total accumulated: 1600 | next_cursor=IlszMSwgOTQuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwNjYzOTI0NyddIg==
# [GET] Yonsei University | page=9 cursor=IlszMSwgOTQuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwNjYzOTI0NyddIg==
# [GET]   -> fetched 200 (rep: 'Verification of the usability of a navigation method in dental implant surgery: ...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU3NDgxMzE4NyddIg==
# [GET] Yonsei University | page=10 cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU3NDgxMzE4NyddIg==
# [GET]   -> fetched 200 (rep: 'Observation of<mml:math xmlns:mml="http://www.w3.org/1998/Math/MathML" display="...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlsyNCwgOTIuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTkxMDEwMDE3J10i
# [GET] Yonsei University | page=11 cursor=IlsyNCwgOTIuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTkxMDEwMDE3J10i
# [GET]   -> fetched 200 (rep: 'Real-Time Elastography in the Evaluation of Diffuse Thyroid Disease: A Study Bas...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA0MzgxODA4MyddIg==
# [GET] Yonsei University | page=12 cursor=IlsyMiwgOTIuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA0MzgxODA4MyddIg==
# [GET]   -> fetched 200 (rep: 'Safety Evaluation of Freehand Lateral Mass Screw Fixation in the Subaxial Cervic...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE2MDUxNzUyNiddIg==
# [GET] Yonsei University | page=13 cursor=IlsyMCwgOTEuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE2MDUxNzUyNiddIg==
# [GET]   -> fetched 200 (rep: 'Monoclonal Antibody Targeting of the Cell Surface Molecule TM4SF5 Inhibits the G...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE1NDc4OTMzNiddIg==
# [GET] Yonsei University | page=14 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE1NDc4OTMzNiddIg==
# [GET]   -> fetched 200 (rep: 'Evaluating the Utility of Rapid Point-of-Care Potassium Testing for the Early Id...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzMTQ4MzkxNiddIg==
# [GET] Yonsei University | page=15 cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzMTQ4MzkxNiddIg==
# [GET]   -> fetched 200 (rep: 'Neurophysiologic Correlates of Sonication Treatment in Patients with Essential T...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsxNCwgODkuMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMj
wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk5NjUzMzYxJ10i
# [GET]   -> empty batch (stop).
# [SAVE] Chungnam National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2014_with_authors/works_top10000_2014_Chungnam_National_University.csv (n=2104)
# [DONE] Total rows: 51047
# [DONE] Saved to: /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2014_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W2156018831
# 1  https://openalex.org/W1980361000
# 2  https://openalex.org/W2157098018
# 3  https://openalex.org/W2051756570
# 4  https://openalex.org/W2143680134
#
#                                                title  publication_year  \
# 0  Neuropilin-1 functions as a VEGFR2 co-receptor...              2014
# 1  Human Tumor Xenograft Models for Preclinical A...              2014
# 2  The Development and Psychometric Investigation...              2014
# 3  Endothelium-derived Relaxing Factors of Small ...              2014
# 4               Self-Expressiveness in Sport Tourism              2014
#
#   publication_date     type                         host_venue  \
# 0       2014-09-22  article                              eLife
# 1       2014-03-31  article             Toxicological Research
# 2       2014-01-14  article  Journal of Interpersonal Violence
# 3       2014-09-30   review             Toxicological Research
# 4       2014-05-19  article         Journal of Travel Research
#
#    cited_by_count  is_oa oa_status language  ...  \
# 0             137   True      gold       en  ...
# 1             134   True    bronze       en  ...
# 2             115  False    closed       en  ...
# 3             110   True    bronze       en  ...
# 4              82  False    closed       en  ...
#
#                                             abstract authors_count  \
# 0  During development, tissue repair, and tumor g...            10
# 1                                               None             1
# 2  Accurate assessment of cyberbullying is essent...             5
# 3                                               None             1
# 4  This study develops and tests a model of self-...             5
#
#                                           author_ids  \
# 0  A5045726685;A5083496533;A5012056698;A504671838...
# 1                                        A5100625726
# 2  A5090348990;A5039183276;A5090372662;A504587486...
# 3                                        A5012379871
# 4  A5037969281;A5089454855;A5014183639;A501889468...
#
#                                         author_names  \
# 0  Maria V. Gelfand;Nellwyn Hagan;Aleksandra Tata...
# 1                                        Joohee Jung
# 2  Regan W. Stewart;Christopher F. Drescher;Danie...
# 3                                       Kyu‐Tae Kang
# 4  Michael Bošnjak;Carroll A. Brown;Dong‐Jin Lee;...
#
#                                     author_positions  \
# 0  first;middle;middle;middle;middle;middle;middl...
# 1                                              first
# 2                    first;middle;middle;middle;last
# 3                                              first
# 4                    first;middle;middle;middle;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0003-3270-0485;https://...
# 1              https://orcid.org/0000-0001-9124-9052
# 2  https://orcid.org/0000-0002-0994-2227;https://...
# 3              https://orcid.org/0000-0001-5163-0262
# 4  https://orcid.org/0000-0002-1431-8461;https://...
#
#                                  author_affiliations  \
# 0  Harvard University;Harvard University;Harvard ...
# 1                         Duksung Women's University
# 2  University of Mississippi;University of Missis...
# 3                         Duksung Women's University
# 4  Free University of Bozen-Bolzano;Western Carol...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2013_with_authors"
YEAR = 2013
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate:
IsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyNzI3NTM4MyddIg==
# [GET] Seoul National University | page=8 cursor=Ils1MiwgOTYuMCwgNTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyNzI3NTM4MyddIg==
# [GET]   -> fetched 200 (rep: 'Korean Risk Assessment Model for Breast Cancer Risk Prediction...')
# [GET]   -> total accumulated: 1600 | next_cursor=Ils0NywgOTYuMCwgNDcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEyNzUyNjYxNyddIg==
# [GET] Seoul National University | page=9 cursor=Ils0NywgOTYuMCwgNDcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEyNzUyNjYxNyddIg==
# [GET]   -> fetched 200 (rep: 'A scalable lock manager for multicores...')
# [GET]   -> total accumulated: 1800 | next_cursor=Ils0MiwgOTUuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3MDIwNzc3OCddIg==
# [GET] Seoul National University | page=10 cursor=Ils0MiwgOTUuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3MDIwNzc3OCddIg==
# [GET]   -> fetched 200 (rep: 'Multicenter phase II study of everolimus in patients with metastatic or recurren...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlszOSwgOTUuMCwgMzksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMyMjE3OTM2MyddIg==
# [GET] Seoul National University | page=11 cursor=IlszOSwgOTUuMCwgMzksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMyMjE3OTM2MyddIg==
# [GET]   -> fetched 200 (rep: 'Determining the Effect of DNA Methylation on Gene Expression in Cancer Cells...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlszNSwgOTQuMCwgMzUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2ODQ1ODcyNiddIg==
# [GET] Seoul National University | page=12 cursor=IlszNSwgOTQuMCwgMzUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2ODQ1ODcyNiddIg==
# [GET]   -> fetched 200 (rep: 'Molecular epidemiology and phylogenetic analysis of porcine epidemic diarrhea vi...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlszMiwgOTQuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2OTEyNzA2MiddIg==
# [GET] Seoul National University | page=13 cursor=IlszMiwgOTQuMCwgMzIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2OTEyNzA2MiddIg==
# [GET]   -> fetched 200 (rep: 'Radiosurgery for central neurocytoma: long-term outcome and failure pattern...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlszMCwgOTMuMCwgMzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE2NTAzODI0MCddIg==
# [GET] Seoul National University | page=14 cursor=IlszMCwgOTMuMCwgMzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE2NTAzODI0MCddIg==
# [GET]   -> fetched 200 (rep: 'Who Succeeds at Dental School? Factors Predicting Students’ Academic Performance...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAzODU4MzExNSddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNywgOTMuMCwgMjcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAzODU4MzExNSddIg==
# [GET]   -> fetched 200 (rep: 'Subsets of microsatellite-unstable colorectal cancers exhibit discordance betwee...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyNSwgOTIuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3OTU0NDAwOSddIg==
# [GET] Seoul National University | page=16 cursor=IlsyNSwgOTIuMCwgMjUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3OTU0NDAwOSddIg==
# [GET]   -> fetched 200 (rep: 'Comparative analysis using K-mer and K-flank patterns provides evidence for CpG ...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMywgOTEuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwMjk2NDk5OSddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMywgOTEuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwMjk2NDk5OSddIg==
# [GET]   -> fetched 200 (rep: 'Association between childhood adversities and adulthood depressive symptoms in S...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NzI5NzI5MCddIg==
# [GET] Seoul National University | page=18 cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NzI5NzI5MCddIg==
# [GET]   -> fetched 200 (rep: 'Diversity and evolution of ABC proteins in basidiomycetes...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxOSwgOTAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwNTE1NDYwNyddIg==
# [GET] Seoul National University | page=19 cursor=IlsxOSwgOTAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwNTE1NDYwNyddIg==
# [GET]   -> fetched 200 (rep: 'Tailoring nanobranches in three-dimensional hierarchical rutile heterostructures...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE0NDExMzQzOCddIg==
# [GET] Seoul National University | page=20 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE0NDExMzQzOCddIg==
# [GET]   -> fetched 200 (rep: 'Genetic variants and signatures of selective sweep of Hanwoo population (Korean ...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwNjM0MjEzOCddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwNjM0MjEzOCddIg==
# [GET]   -> fetched 200 (rep: 'Involvement of extracellular and intracellular enzymes of<i>Ceriporia</i>sp. ZLY...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMyNjczMTczNyddIg==
# [GET] Seoul National University | page=22 cursor=IlsxNSwgODkuMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMyNjczMTczNyddIg==
# [GET]   -> fetched 200 (rep: 'Role of Electrical Conductivity of Spinning Solution on Enhancement of Electrosp...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwMTk4NDY2NyddIg==
# [GET] Seoul National University | page=23 cursor=IlsxMywgODguMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwMTk4NDY2NyddIg==
# [GET]   -> fetched 200 (rep: 'Risk assessment of wave run-up height and armor stability of inclined coastal st...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA2OTQ3NDY4MCddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA2OTQ3NDY4MCddIg==
# [GET]   -> fetched 200 (rep: 'Atmospheric Dispersion and Deposition of Radionuclides (&amp;lt;sup&amp;gt;137&a...')
# [GET]   -> total accumulated: 4800 | next_cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEyMTQ2MjgyOCddIg==
# [GET] Seoul National University | page=25 cursor=IlsxMSwgODcuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEyMTQ2MjgyOCddIg==
# [GET]   -> fetched 200 (rep: 'Rhinitis Patients With Sputum Eosinophilia Show Decreased Lung Function in the A...')
# [GET]   -> total accumulated: 5000 | next_cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzODg5MTI4MSddIg==
# [GET] Seoul National University | page=26 cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzODg5MTI4MSddIg==
# [GET]   -> fetched 200 (rep: 'The Influence of Cognitive Coping on Hope, Depression and Satisfaction with Life...')
# [GET]   -> total accumulated: 5200 | next_cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxNTc0NjI2MjAnXSI=
# [GET] Seoul National University | page=27 cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxNTc0NjI2MjAnXSI=
# [GET]   -> fetched 200 (rep: 'Highly Reliable Multiple-Channel IGZO Thin-Film Transistors Employing Asymmetric...')
# [GET]   -> total accumulated: 5400 | next_cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIx
4wLCAzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzE3NzI2ODQ2OSddIg==
# [GET] Chungnam National University | page=8 cursor=IlszLCA3OC4wLCAzLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzE3NzI2ODQ2OSddIg==
# [GET]   -> fetched 200 (rep: 'Deposition of β-SiC by a LPCVD Method and the Effect of the Crystallographic Ori...')
# [GET]   -> total accumulated: 1600 | next_cursor=IlsyLCA3Ni4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNzYyMzUwMTcnXSI=
# [GET] Chungnam National University | page=9 cursor=IlsyLCA3Ni4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNzYyMzUwMTcnXSI=
# [GET]   -> fetched 200 (rep: 'Herbicidal efficacy of benzobicyclon-mixtures and carfentrazone-ethyl-mixtures i...')
# [GET]   -> total accumulated: 1800 | next_cursor=IlsxLCA3Mi4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxMTkyNDA5NzInXSI=
# [GET] Chungnam National University | page=10 cursor=IlsxLCA3Mi4wLCAxLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxMTkyNDA5NzInXSI=
# [GET]   -> fetched 200 (rep: 'Real-Time Algorithm for Relative Position Estimation Between Person and Robot Us...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwMzcyMDE4ODknXSI=
# [GET] Chungnam National University | page=11 cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwMzcyMDE4ODknXSI=
# [GET]   -> fetched 200 (rep: 'Study of the Annals of Joseon Dynasty for Developing Systematic Conservation Sch...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NTE3NTY1NzMnXSI=
# [GET] Chungnam National University | page=12 cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzI5NTE3NTY1NzMnXSI=
# [GET]   -> fetched 32 (rep: 'ChemInform Abstract: Synthesis of 2‐Styrylbenzoxazole Derivatives by the Reactio...')
# [GET]   -> total accumulated: 2232 | next_cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk0MDQ3MDk1NiddIg==
# [GET] Chungnam National University | page=13 cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk0MDQ3MDk1NiddIg==
# [GET]   -> empty batch (stop).
# [SAVE] Chungnam National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2013_with_authors/works_top10000_2013_Chungnam_National_University.csv (n=2232)
# [DONE] Total rows: 49168
# [DONE] Saved to: /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2013_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W1968493165
# 1  https://openalex.org/W2105414208
# 2  https://openalex.org/W2015706279
# 3  https://openalex.org/W2087330966
# 4  https://openalex.org/W2007313876
#
#                                                title  publication_year  \
# 0  Pif1 helicase and Polδ promote recombination-c...              2013
# 1  <scp>BLH</scp>1 and <scp>KNAT</scp>3 modulate ...              2013
# 2  The antioxidant activity of daidzein metabolit...              2013
# 3  Inflammatory and microenvironmental factors in...              2013
# 4  2-Hydroxychalcone and xanthohumol inhibit inva...              2013
#
#   publication_date     type                       host_venue  cited_by_count  \
# 0       2013-09-10  article                           Nature             300
# 1       2013-05-11  article                The Plant Journal             120
# 2       2013-10-23  article       Molecular Medicine Reports              95
# 3       2013-11-12   review   Archives of Pharmacal Research              90
# 4       2013-04-03  article  Chemico-Biological Interactions              78
#
#    is_oa oa_status language  ...  \
# 0   True     green       en  ...
# 1  False    closed       en  ...
# 2   True    bronze       en  ...
# 3  False    closed       en  ...
# 4  False    closed       en  ...
#
#                                             abstract authors_count  \
# 0                                               None            11
# 1  The signal transduction pathway governed by th...             6
# 2  Daidzein and its glycoside form daidzin, are k...             2
# 3                                               None             2
# 4                                               None             3
#
#                                           author_ids  \
# 0  A5015042419;A5005189404;A5101871800;A508735167...
# 1  A5043050739;A5045288847;A5078991413;A510149432...
# 2                            A5089574455;A5100664725
# 3                            A5110901763;A5083115378
# 4                A5100335623;A5103159070;A5083115378
#
#                                         author_names  \
# 0  Marenda A. Wilson;Youngho Kwon;Yuanyuan Xu;Woo...
# 1  Dachan Kim;Young‐hyun Cho;Hojin Ryu;Yoonhee Ki...
# 2                         Eun Jeong Choi;Gun‐Hee Kim
# 3                                 Mina Ham;Aree Moon
# 4                 Sun Young Kim;Ik‐Soo Lee;Aree Moon
#
#                                     author_positions  \
# 0  first;middle;middle;middle;middle;middle;middl...
# 1             first;middle;middle;middle;middle;last
# 2                                         first;last
# 3                                         first;last
# 4                                  first;middle;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0003-1610-1044;https://...
# 1  https://orcid.org/0000-0001-5196-8482;https://...
# 2  https://orcid.org/0000-0002-7698-3424;https://...
# 3
# 4  https://orcid.org/0000-0002-5994-8889;https://...
#
#                                  author_affiliations  \
# 0  Baylor College of Medicine;Yale University;Yal...
# 1  Pohang University of Science and Technology;Po...
# 2  Duksung Women's University;Duksung Women's Uni...
# 3  Duksung Women's University;Duksung Women's Uni...
# 4  Duksung Women's University;Chonnam National Un...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2012_with_authors"
YEAR = 2012
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungbuk National University' (relax=False)
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungbuk National University | id=https://openalex.org/I163753206
# [MAP] OK (EN): Chungbuk National University -> Chungbuk National University | institutions.id=I163753206
# [MAP] [23/23] resolving 'Chungnam National University'
# [MAP] Try EN: Chungnam National University
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chungnam National University' (relax=False)
# [MAP]   -> searching: 'Chungnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chungnam National University | id=https://openalex.org/I196345858
# [MAP] OK (EN): Chungnam National University -> Chungnam National University | institutions.id=I196345858
# [MAP] saved mapping -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2012_with_authors/institutions_mapping.csv
#                                            query_name institution_id  \
# 0                          Duksung Women's University      I65832422
# 1                           Seoul National University     I139264467
# 2                                    Korea University      I88761825
# 3                                   Yonsei University     I193775966
# 4   Korea Advanced Institute of Science and Techno...     I157485424
# 5                                   Sogang University     I148751991
# 6                             Sungkyunkwan University        I848706
# 7                                  Hanyang University     I109995039
# 8         Pohang University of Science and Technology     I123900574
# 9         Gwangju Institute of Science and Technology      I39534123
# 10  Daegu Gyeongbuk Institute of Science and Techn...     I193352282
# 11  Ulsan National Institute of Science and Techno...      I48566637
# 12                               Chung-Ang University      I67900169
# 13                               Kyung Hee University     I160888826
# 14                        Kangwon National University     I165507594
# 15                      Kyungpook National University      I31419693
# 16                     Gyeongsang National University     I189442560
# 17                          Pusan National University       I4921948
# 18                        Chonnam National University     I111277659
# 19                        Jeonbuk National University      I80611190
# 20                           Jeju National University      I83202590
# 21                       Chungbuk National University     I163753206
# 22                       Chungnam National University     I196345858
#
#                                          display_name
# 0                          Duksung Women's University
# 1                           Seoul National University
# 2          Korea University of Science and Technology
# 3                                   Yonsei University
# 4   Korea Advanced Institute of Science and Techno...
# 5                                   Sogang University
# 6                             Sungkyunkwan University
# 7                            Hanyang Cyber University
# 8         Pohang University of Science and Technology
# 9         Gwangju Institute of Science and Technology
')
# [GET]   -> total accumulated: 600 | next_cursor=IlsxMDEsIDk4LjAsIDEwMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMTI1Njc2NTk1J10i
# [GET] Seoul National University | page=4 cursor=IlsxMDEsIDk4LjAsIDEwMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMTI1Njc2NTk1J10i
# [GET]   -> fetched 200 (rep: 'First muon-neutrino disappearance study with an off-axis beam...')
# [GET]   -> total accumulated: 800 | next_cursor=Ils4NCwgOTguMCwgODQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NzM3NDgwNyddIg==
# [GET] Seoul National University | page=5 cursor=Ils4NCwgOTguMCwgODQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NzM3NDgwNyddIg==
# [GET]   -> fetched 200 (rep: 'Changes in the association between summer temperature and mortality in Seoul, So...')
# [GET]   -> total accumulated: 1000 | next_cursor=Ils3MSwgOTcuMCwgNzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMzMDY1NzM4OSddIg==
# [GET] Seoul National University | page=6 cursor=Ils3MSwgOTcuMCwgNzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjMzMDY1NzM4OSddIg==
# [GET]   -> fetched 200 (rep: 'Decadal changes in surface air temperature variability and cold surge characteri...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils2MCwgOTcuMCwgNjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEyODExOTc5MiddIg==
# [GET] Seoul National University | page=7 cursor=Ils2MCwgOTcuMCwgNjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEyODExOTc5MiddIg==
# [GET]   -> fetched 200 (rep: 'Wang-Landau Monte Carlo-Based Tracking Methods for Abrupt Motions...')
# [GET]   -> total accumulated: 1400 | next_cursor=Ils1MiwgOTYuMCwgNTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3MTAwNDQyNSddIg==
# [GET] Seoul National University | page=8 cursor=Ils1MiwgOTYuMCwgNTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3MTAwNDQyNSddIg==
# [GET]   -> fetched 200 (rep: 'Clinical Characteristics and Prognostic Factors of Primary Pulmonary Vein Stenos...')
# [GET]   -> total accumulated: 1600 | next_cursor=Ils0NywgOTUuMCwgNDcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxMzk2OTc2NyddIg==
# [GET] Seoul National University | page=9 cursor=Ils0NywgOTUuMCwgNDcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxMzk2OTc2NyddIg==
# [GET]   -> fetched 200 (rep: 'COMPARATIVE ANALYSIS OF MACULAR MICROSTRUCTURE BY SPECTRAL-DOMAIN OPTICAL COHERE...')
# [GET]   -> total accumulated: 1800 | next_cursor=Ils0MiwgOTUuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NzA0ODEyOSddIg==
# [GET] Seoul National University | page=10 cursor=Ils0MiwgOTUuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA1NzA0ODEyOSddIg==
# [GET]   -> fetched 200 (rep: 'Key Value Drivers of Startup Companies in the New Media Industry—The Case of Onl...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlszOCwgOTQuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3MDY2Nzc3NCddIg==
# [GET] Seoul National University | page=11 cursor=IlszOCwgOTQuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3MDY2Nzc3NCddIg==
# [GET]   -> fetched 200 (rep: 'Protective Effect of Processed Panax ginseng, Sun Ginseng on UVB-irradiated Huma...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlszNCwgOTQuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk4NjQ2OTEwMyddIg==
# [GET] Seoul National University | page=12 cursor=IlszNCwgOTQuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk4NjQ2OTEwMyddIg==
# [GET]   -> fetched 200 (rep: 'Investigation on the dissolution of Mn ions from LiMn<sub>2</sub>O<sub>4</sub> c...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlszMSwgOTMuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTY1Nzk3NjQzNyddIg==
# [GET] Seoul National University | page=13 cursor=IlszMSwgOTMuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTY1Nzk3NjQzNyddIg==
# [GET]   -> fetched 200 (rep: 'Comparison of disseminated intravascular coagulation in trauma with coagulopathy...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsyOCwgOTMuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3MTYxMTc5MSddIg==
# [GET] Seoul National University | page=14 cursor=IlsyOCwgOTMuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3MTYxMTc5MSddIg==
# [GET]   -> fetched 200 (rep: 'MODIFIED GRAVITY SPINS UP GALACTIC HALOS...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNiwgOTIuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA2OTE1ODUyNSddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNiwgOTIuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA2OTE1ODUyNSddIg==
# [GET]   -> fetched 200 (rep: 'Efficacy of thiolated eudragit microspheres as an oral vaccine delivery system t...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyNCwgOTIuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEyNzU5MTMzMiddIg==
# [GET] Seoul National University | page=16 cursor=IlsyNCwgOTIuMCwgMjQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEyNzU5MTMzMiddIg==
# [GET]   -> fetched 200 (rep: 'Production of Biohydrogen by Aqueous Phase Reforming of Polyols over Platinum Ca...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMiwgOTEuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE2NzcxMjM0NiddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMiwgOTEuMCwgMjIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE2NzcxMjM0NiddIg==
# [GET]   -> fetched 200 (rep: 'Social discrimination by quantitative assessment of immunogenetic similarity...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsyMCwgOTAuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwNzM1NDY4MiddIg==
# [GET] Seoul National University | page=18 cursor=IlsyMCwgOTAuMCwgMjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwNzM1NDY4MiddIg==
# [GET]   -> fetched 200 (rep: 'Surface dependent thermal evolution of the nanostructures in ultra-thin copper(i...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3NDk0NTQ5NiddIg==
# [GET] Seoul National University | page=19 cursor=IlsxOCwgOTAuMCwgMTgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3NDk0NTQ5NiddIg==
# [GET]   -> fetched 200 (rep: 'Evaluation of Near-Infrared Pasteurization in Controlling Escherichia coli O157:...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwMjkxMTc3NSddIg==
# [GET] Seoul National University | page=20 cursor=IlsxNiwgODkuMCwgMTYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwMjkxMTc3NSddIg==
# [GET]   -> fetched 200 (rep: 'Guest-dependent host structures and host-induced guest assemblies...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNSwgODguMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwMzk5MDk3OSddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNSwgODguMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEwMzk5MDk3OSddIg==
# [GET]   -> fetched 200 (rep: 'Short-term variability of microphytobenthic primary production associated with i...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxMywgODcuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU2MTczNDgyOSddIg==
# [GET] Seoul National University | page=22 cursor=IlsxMywgODcuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU2MTczNDgyOSddIg==
# [GET]   -> fetched 200 (rep: 'Counting Small Hypointense Spots Confounds the Quantification of Functional Isle...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxMiwgODcuMCwgMTIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMj
content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2012_with_authors
#                         openalex_id  \
# 0  https://openalex.org/W2030519527
# 1  https://openalex.org/W2039107480
# 2  https://openalex.org/W2150172235
# 3  https://openalex.org/W2096616783
# 4  https://openalex.org/W1989962582
#
#                                                title  publication_year  \
# 0  Comparison of the chemical compositions and nu...              2012
# 1     Drug-Induced Nephrotoxicity and Its Biomarkers              2012
# 2  In vitro evaluation of biomarkers for cisplati...              2012
# 3  Polymeric Nanoparticles Containing Taxanes Enh...              2012
# 4  Acupuncture for Shoulder Pain After Stroke: A ...              2012
#
#   publication_date     type  \
# 0       2012-01-01  article
# 1       2012-05-31   review
# 2       2012-12-31  article
# 3       2012-07-14  article
# 4       2012-08-27   review
#
#                                           host_venue  cited_by_count  is_oa  \
# 0                    Nutrition Research and Practice             271   True
# 1                        Biomolecules & Therapeutics             266   True
# 2                                 Toxicology Letters              83  False
# 3  International Journal of Radiation Oncology*Bi...              70  False
# 4  The Journal of Alternative and Complementary M...              62   True
#
#   oa_status language  ...                                           abstract  \
# 0     green       en  ...  Pumpkins have considerable variation in nutrie...
# 1    bronze       en  ...  Nephrotoxicity occurs when kidney-specific det...
# 2    closed       en  ...                                               None
# 3    closed       en  ...                                               None
# 4     green       en  ...  Objectives: Shoulder pain, for which acupunctu...
#
#   authors_count                                         author_ids  \
# 0             5  A5100755756;A5100462734;A5085103874;A501235157...
# 1             2                            A5100335616;A5083115378
# 2             7  A5075428572;A5100335623;A5052433739;A502603837...
# 3            10  A5111781835;A5100323621;A5108194390;A510202223...
# 4             7  A5101499115;A5049870193;A5112771029;A510280976...
#
#                                         author_names  \
# 0  Mi Young Kim;Eun Jin Kim;Young‐Nam Kim;Changsu...
# 1                            Sun Young Kim;Aree Moon
# 2  So-Jung Sohn;Sun Young Kim;Hyung Sik Kim;Young...
# 3  Joohee Jung;Sung Jin Park;Hye Kyung Chung;Hye-...
# 4  Jung Ah Lee;Si‐Woon Park;Pil Woo Hwang;Sung Mi...
#
#                                     author_positions  \
# 0                    first;middle;middle;middle;last
# 1                                         first;last
# 2      first;middle;middle;middle;middle;middle;last
# 3  first;middle;middle;middle;middle;middle;middl...
# 4      first;middle;middle;middle;middle;middle;last
#
#                                        author_orcids  \
# 0  https://orcid.org/0000-0002-1202-2245;https://...
# 1              https://orcid.org/0000-0002-1180-0367
# 2  https://orcid.org/0000-0002-5994-8889;https://...
# 3  https://orcid.org/0000-0002-7340-7835;https://...
# 4  https://orcid.org/0000-0002-5837-3008;https://...
#
#                                  author_affiliations  \
# 0  Chung-Ang University;Chung-Ang University;Duks...
# 1                         Duksung Women's University
# 2  Duksung Women's University;Duksung Women's Uni...
# 3  Duksung Women's University|University of Ulsan...
# 4  National Rehabilitation Center;National Rehabi...
#
#                    query_name                display_name institution_id
# 0  Duksung Women's University  Duksung Women's University      I65832422
# 1  Duksung Women's University  Duksung Women's University      I65832422
# 2  Duksung Women's University  Duksung Women's University      I65832422
# 3  Duksung Women's University  Duksung Women's University      I65832422
# 4  Duksung Women's University  Duksung Women's University      I65832422
#
# [5 rows x 21 columns]

# %%
# Colab 1-cell script (institutions.id only, year=2025, top-500 by citations)
# Adds authorship fields + abstract reconstruction + verbose prints

import os, time, requests, pandas as pd

# ===================== 사용자 설정 =====================
SAVE_DIR = "/content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2011_with_authors"
YEAR = 2011
TOP_K = 10000        # 기관별 최대 10000편
PER_PAGE = 200     # OpenAlex 최대 권장
SLEEP = 0.2        # 요청 간 대기(429 예방)
RETRY = 5          # 재시도 횟수
TIMEOUT = 60       # 요청 타임아웃(초)

# 대상 14개(덕성여대 포함)
TARGET_UNIVS = [
    "Duksung Women's University",
    "Seoul National University",
    "Korea University",
    "Yonsei University",
    "Korea Advanced Institute of Science and Technology",  # KAIST
    "Sogang University",
    "Sungkyunkwan University",
    "Hanyang University",
    "Pohang University of Science and Technology", #POSTECH
    "Gwangju Institute of Science and Technology", #GIST
    "Daegu Gyeongbuk Institute of Science and Technology", #DGIST
    "Ulsan National Institute of Science and Technology",   #UNIST
    "Chung-Ang University",
    "Kyung Hee University",
    "Kangwon National University",
    "Kyungpook National University",
    "Gyeongsang National University",
    "Pusan National University",
    "Chonnam National University",
    "Jeonbuk National University",
    "Jeju National University",
    "Chungbuk National University",
    "Chungnam National University"
]

# 매칭 실패 대비 간단 별칭
ALT_NAMES = {
    "Duksung Women's University": ["덕성여자대학교", "덕성여대"],
    "Seoul National University": ["서울대학교", "서울대", "SNU"],
    "Korea University": ["고려대학교", "고려대", "KU"],
    "Yonsei University": ["연세대학교", "연세대"],
    "Korea Advanced Institute of Science and Technology": ["한국과학기술원", "KAIST"],
    "Sogang University": ["서강대학교", "서강대"],
    "Sungkyunkwan University": ["성균관대학교", "성균관대"],
    "Hanyang Unviersity": ["한양대학교", "한양대"],
    "Pohang University of Science and Technology": ["포항공과대학교", "포항공대", "POSTECH"],
    "Gwangju Institute of Science and Technology": ["광주과학기술원", "GIST"],
    "Daegu Gyeongbuk Institute of Science and Technology": ["대구경북과학기술원", "DGIST"],
    "Ulsan National Institute of Science and Technology": ["울산과학기술원", "UNIST"],
    "Chung-Ang University": ["중앙대학교", "중앙대", "Chungang University"],
    "Kyung Hee University": ["경희대학교", "경희대", "Kyunghee University"],
    "Kangwon National University": ["강원대학교", "강원대", "KNU"],
    "Kyungpook National University": ["경북대학교", "경북대"],
    "Gyeongsang National University": ["경상국립대학교", "경상대"],
    "Pusan National University": ["부산대학교", "부산대"],
    "Chonnam National University": ["전남대학교", "전남대"],
    "Jeonbuk National University": ["전북대학교", "전북대"],
    "Jeju National University": ["제주대학교", "제주대"],
    "Chungbuk National University": ["충북대학교", "충북대"],
    "Chungnam National University": ["충남대학교", "충남대"]
}

os.makedirs(SAVE_DIR, exist_ok=True)

# ===================== 공통 유틸 =====================
def http_get(url, params, retry=RETRY, backoff=1.4, timeout=TIMEOUT):
    for i in range(retry):
        try:
            r = requests.get(url, params=params, timeout=timeout)
            if r.status_code == 200:
                return r
            print(f"[HTTP:{r.status_code}] retry {i+1}/{retry} url={url} params={params}")
            time.sleep((backoff ** i) + 0.2)
        except requests.RequestException as e:
            print(f"[HTTP:EXC] {e} retry {i+1}/{retry} url={url}")
            time.sleep((backoff ** i) + 0.2)
    print("[HTTP] giving up after retries.")
    return None

def reconstruct_abstract(inv_idx: dict | None) -> str | None:
    """
    OpenAlex abstract_inverted_index(토큰 -> 위치 리스트)를 실제 텍스트로 복원.
    """
    if not inv_idx:
        return None
    try:
        max_pos = max(p for positions in inv_idx.values() for p in positions)
        words = [""] * (max_pos + 1)
        for token, positions in inv_idx.items():
            for p in positions:
                words[p] = token
        text = " ".join(w for w in words if w is not None)
        return " ".join(text.split())
    except Exception as e:
        print(f"[ABSTRACT] reconstruction failed: {e}")
        return None

# ===================== (1) 기관명 → institutions.id =====================
def search_institution_top1(name: str, relax=False):
    """
    institutions 검색은 'search'를 사용. 페이지 크기는 'per-page' 하이픈 표기.
    기본: KR + education 필터, top1
    relax=True면 type 필터 제거(KR만)로 재시도.
    """
    url = "https://api.openalex.org/institutions"
    flt = "country_code:KR,type:education" if not relax else "country_code:KR"
    params = {
        "search": name,
        "filter": flt,
        "per-page": 1
    }
    print(f"[MAP]   -> searching: '{name}' | filter='{flt}'")
    r = http_get(url, params)
    if not r:
        print(f"[MAP]   -> no response for '{name}'")
        return None
    items = r.json().get("results", [])
    if items:
        cand = items[0]
        print(f"[MAP]   -> candidate: {cand.get('display_name')} | id={cand.get('id')}")
        return cand
    print(f"[MAP]   -> no candidates for '{name}' (relax={relax})")
    return None

def resolve_institution_id(qname: str):
    print(f"[MAP] Try EN: {qname}")
    res = search_institution_top1(qname)
    if not res:
        res = search_institution_top1(qname, relax=True)
    if res and res.get("id"):
        inst_id = res["id"].split("/")[-1]
        print(f"[MAP] OK (EN): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
        return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}

    for alt in ALT_NAMES.get(qname, []):
        print(f"[MAP] Try ALT: {qname} -> '{alt}'")
        res = search_institution_top1(alt)
        if not res:
            res = search_institution_top1(alt, relax=True)
        if res and res.get("id"):
            inst_id = res["id"].split("/")[-1]
            print(f"[MAP] OK (ALT): {qname} -> {res.get('display_name')} | institutions.id={inst_id}")
            return {"query_name": qname, "institution_id": inst_id, "display_name": res.get("display_name")}
    print(f"[MAP] FAIL: {qname} (could not resolve institutions.id)")
    return {"query_name": qname, "institution_id": None, "display_name": None}

def build_institution_map(names):
    print("[MAP] ==== start institution mapping ====")
    rows = []
    for idx, nm in enumerate(names, 1):
        print(f"[MAP] [{idx}/{len(names)}] resolving '{nm}'")
        info = resolve_institution_id(nm)
        rows.append(info)
        time.sleep(SLEEP)
    df = pd.DataFrame(rows)
    out = os.path.join(SAVE_DIR, "institutions_mapping.csv")
    df.to_csv(out, index=False, encoding="utf-8")
    print(f"[MAP] saved mapping -> {out}")
    print(df)
    return df

# ===================== (2) 2025 상위 500편 수집 + 초록/저자 =====================
def extract_authors(authorships: list | None):
    """
    authorships 리스트에서 저자 관련 필드 평탄화.
    - author_ids: A... 꼬리만 추출
    - author_names: display_name
    - author_positions: first/middle/last
    - author_orcids: 0000-0002-...
    - author_affiliations: 저자별 기관 display_name들을 '|'로 묶고, 저자 간은 ';'로 연결
    """
    if not authorships:
        return {
            "authors_count": 0,
            "author_ids": None,
            "author_names": None,
            "author_positions": None,
            "author_orcids": None,
            "author_affiliations": None,
        }
    ids, names, poss, orcids, affs = [], [], [], [], []
    for a in authorships:
        author = a.get("author") or {}
        aid = author.get("id") or ""
        aid_tail = aid.split("/")[-1] if aid else None
        ids.append(aid_tail)
        names.append(author.get("display_name"))
        poss.append(a.get("author_position"))
        # orcid 위치가 author.orcid 또는 author.ids.orcid로 있을 수 있음
        orcid = author.get("orcid")
        if not orcid:
            orcid = (author.get("ids") or {}).get("orcid")
        orcids.append(orcid)

        insts = a.get("institutions") or []
        inst_names = [ (inst or {}).get("display_name") for inst in insts if inst ]
        affs.append("|".join([n for n in inst_names if n]))

    return {
        "authors_count": len(names),
        "author_ids": ";".join([x for x in ids if x]),
        "author_names": ";".join([x for x in names if x]),
        "author_positions": ";".join([x for x in poss if x]),
        "author_orcids": ";".join([x for x in orcids if x]),
        "author_affiliations": ";".join([x for x in affs if x]),
    }

def fetch_topk_works_for_institution(inst_id: str, qname: str, dname: str, year: int = YEAR, topk: int = TOP_K):
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"institutions.id:{inst_id},publication_year:{year}",
        "per-page": PER_PAGE,          # 하이픈 표기
        "cursor": "*",
        "sort": "cited_by_count:desc"
    }
    out = []
    page = 0
    while True:
        page += 1
        print(f"[GET] {qname} | page={page} cursor={params.get('cursor')}")
        r = http_get(url, params)
        if not r:
            print(f"[GET]   -> no response (stop).")
            break

        j = r.json()
        batch = j.get("results", [])
        if not batch:
            print(f"[GET]   -> empty batch (stop).")
            break

        rep_title = (batch[0].get("title") or "")[:80]
        print(f"[GET]   -> fetched {len(batch)} (rep: '{rep_title}...')")

        for w in batch:
            abstract_text = reconstruct_abstract(w.get("abstract_inverted_index"))
            auth = extract_authors(w.get("authorships"))

            out.append({
                "openalex_id": w.get("id"),
                "title": w.get("title"),
                "publication_year": w.get("publication_year"),
                "publication_date": w.get("publication_date"),
                "type": w.get("type"),
                "host_venue": ((w.get("primary_location") or {}).get("source") or {}).get("display_name"),
                "cited_by_count": w.get("cited_by_count"),
                "is_oa": (w.get("open_access") or {}).get("is_oa"),
                "oa_status": (w.get("open_access") or {}).get("oa_status"),
                "language": w.get("language"),
                "doi": (w.get("ids") or {}).get("doi") or w.get("doi"),
                "abstract": abstract_text,
                **auth,
            })
            if len(out) >= topk:
                print(f"[GET]   -> reached top-{topk}; stopping early.")
                return out[:topk]

        nxt = j.get("meta", {}).get("next_cursor")
        total = len(out)
        print(f"[GET]   -> total accumulated: {total} | next_cursor={nxt}")
        if not nxt:
            print("[GET]   -> no next_cursor; finished.")
            break
        params["cursor"] = nxt
        time.sleep(SLEEP)
    return out[:topk]

# ===================== (3) 실행(매핑 → 수집 → 저장) =====================
inst_map = build_institution_map(TARGET_UNIVS)
print("=== Institution mapping result ===")
print(inst_map.to_string(index=False))

all_dfs = []
for _, row in inst_map.iterrows():
    inst_id = row["institution_id"]
    qname   = row["query_name"]
    dname   = row["display_name"]
    if not inst_id:
        print(f"[SKIP] No institutions.id for '{qname}'")
        continue

    print(f"[RUN] Fetch top-{TOP_K} (year={YEAR}) for {qname} ({dname}) → institutions.id={inst_id}")
    works = fetch_topk_works_for_institution(inst_id, qname, dname, year=YEAR, topk=TOP_K)
    df_inst = pd.DataFrame(works)
    df_inst["query_name"] = qname
    df_inst["display_name"] = dname
    df_inst["institution_id"] = inst_id

    safe = qname.replace("/", "_").replace(" ", "_")
    path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_{safe}.csv")
    df_inst.to_csv(path, index=False, encoding="utf-8")
    print(f"[SAVE] {qname} -> {path} (n={len(df_inst)})")
    all_dfs.append(df_inst)
    time.sleep(0.4)

df_all = pd.concat(all_dfs, ignore_index=True) if all_dfs else pd.DataFrame()
all_path = os.path.join(SAVE_DIR, f"works_top{TOP_K}_{YEAR}_ALL.csv")
df_all.to_csv(all_path, index=False, encoding="utf-8")
print(f"[DONE] Total rows: {len(df_all)}")
print(f"[DONE] Saved to: {SAVE_DIR}")

# 미리보기
df_all.head()
# Out:
# [MAP] ==== start institution mapping ====
# [MAP] [1/23] resolving 'Duksung Women's University'
# [MAP] Try EN: Duksung Women's University
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Duksung Women's University' (relax=False)
# [MAP]   -> searching: 'Duksung Women's University' | filter='country_code:KR'
# [MAP]   -> candidate: Duksung Women's University | id=https://openalex.org/I65832422
# [MAP] OK (EN): Duksung Women's University -> Duksung Women's University | institutions.id=I65832422
# [MAP] [2/23] resolving 'Seoul National University'
# [MAP] Try EN: Seoul National University
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Seoul National University' (relax=False)
# [MAP]   -> searching: 'Seoul National University' | filter='country_code:KR'
# [MAP]   -> candidate: Seoul National University | id=https://openalex.org/I139264467
# [MAP] OK (EN): Seoul National University -> Seoul National University | institutions.id=I139264467
# [MAP] [3/23] resolving 'Korea University'
# [MAP] Try EN: Korea University
# [MAP]   -> searching: 'Korea University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Korea University of Science and Technology | id=https://openalex.org/I88761825
# [MAP] OK (EN): Korea University -> Korea University of Science and Technology | institutions.id=I88761825
# [MAP] [4/23] resolving 'Yonsei University'
# [MAP] Try EN: Yonsei University
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Yonsei University' (relax=False)
# [MAP]   -> searching: 'Yonsei University' | filter='country_code:KR'
# [MAP]   -> candidate: Yonsei University | id=https://openalex.org/I193775966
# [MAP] OK (EN): Yonsei University -> Yonsei University | institutions.id=I193775966
# [MAP] [5/23] resolving 'Korea Advanced Institute of Science and Technology'
# [MAP] Try EN: Korea Advanced Institute of Science and Technology
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Korea Advanced Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Korea Advanced Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Korea Advanced Institute of Science and Technology | id=https://openalex.org/I157485424
# [MAP] OK (EN): Korea Advanced Institute of Science and Technology -> Korea Advanced Institute of Science and Technology | institutions.id=I157485424
# [MAP] [6/23] resolving 'Sogang University'
# [MAP] Try EN: Sogang University
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sogang University' (relax=False)
# [MAP]   -> searching: 'Sogang University' | filter='country_code:KR'
# [MAP]   -> candidate: Sogang University | id=https://openalex.org/I148751991
# [MAP] OK (EN): Sogang University -> Sogang University | institutions.id=I148751991
# [MAP] [7/23] resolving 'Sungkyunkwan University'
# [MAP] Try EN: Sungkyunkwan University
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Sungkyunkwan University' (relax=False)
# [MAP]   -> searching: 'Sungkyunkwan University' | filter='country_code:KR'
# [MAP]   -> candidate: Sungkyunkwan University | id=https://openalex.org/I848706
# [MAP] OK (EN): Sungkyunkwan University -> Sungkyunkwan University | institutions.id=I848706
# [MAP] [8/23] resolving 'Hanyang University'
# [MAP] Try EN: Hanyang University
# [MAP]   -> searching: 'Hanyang University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Hanyang Cyber University | id=https://openalex.org/I109995039
# [MAP] OK (EN): Hanyang University -> Hanyang Cyber University | institutions.id=I109995039
# [MAP] [9/23] resolving 'Pohang University of Science and Technology'
# [MAP] Try EN: Pohang University of Science and Technology
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pohang University of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Pohang University of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Pohang University of Science and Technology | id=https://openalex.org/I123900574
# [MAP] OK (EN): Pohang University of Science and Technology -> Pohang University of Science and Technology | institutions.id=I123900574
# [MAP] [10/23] resolving 'Gwangju Institute of Science and Technology'
# [MAP] Try EN: Gwangju Institute of Science and Technology
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gwangju Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Gwangju Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Gwangju Institute of Science and Technology | id=https://openalex.org/I39534123
# [MAP] OK (EN): Gwangju Institute of Science and Technology -> Gwangju Institute of Science and Technology | institutions.id=I39534123
# [MAP] [11/23] resolving 'Daegu Gyeongbuk Institute of Science and Technology'
# [MAP] Try EN: Daegu Gyeongbuk Institute of Science and Technology
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Daegu Gyeongbuk Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Daegu Gyeongbuk Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Daegu Gyeongbuk Institute of Science and Technology | id=https://openalex.org/I193352282
# [MAP] OK (EN): Daegu Gyeongbuk Institute of Science and Technology -> Daegu Gyeongbuk Institute of Science and Technology | institutions.id=I193352282
# [MAP] [12/23] resolving 'Ulsan National Institute of Science and Technology'
# [MAP] Try EN: Ulsan National Institute of Science and Technology
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Ulsan National Institute of Science and Technology' (relax=False)
# [MAP]   -> searching: 'Ulsan National Institute of Science and Technology' | filter='country_code:KR'
# [MAP]   -> candidate: Ulsan National Institute of Science and Technology | id=https://openalex.org/I48566637
# [MAP] OK (EN): Ulsan National Institute of Science and Technology -> Ulsan National Institute of Science and Technology | institutions.id=I48566637
# [MAP] [13/23] resolving 'Chung-Ang University'
# [MAP] Try EN: Chung-Ang University
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chung-Ang University' (relax=False)
# [MAP]   -> searching: 'Chung-Ang University' | filter='country_code:KR'
# [MAP]   -> candidate: Chung-Ang University | id=https://openalex.org/I67900169
# [MAP] OK (EN): Chung-Ang University -> Chung-Ang University | institutions.id=I67900169
# [MAP] [14/23] resolving 'Kyung Hee University'
# [MAP] Try EN: Kyung Hee University
# [MAP]   -> searching: 'Kyung Hee University' | filter='country_code:KR,type:education'
# [MAP]   -> candidate: Kyung Hee Cyber University | id=https://openalex.org/I160888826
# [MAP] OK (EN): Kyung Hee University -> Kyung Hee Cyber University | institutions.id=I160888826
# [MAP] [15/23] resolving 'Kangwon National University'
# [MAP] Try EN: Kangwon National University
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kangwon National University' (relax=False)
# [MAP]   -> searching: 'Kangwon National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kangwon National University | id=https://openalex.org/I165507594
# [MAP] OK (EN): Kangwon National University -> Kangwon National University | institutions.id=I165507594
# [MAP] [16/23] resolving 'Kyungpook National University'
# [MAP] Try EN: Kyungpook National University
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Kyungpook National University' (relax=False)
# [MAP]   -> searching: 'Kyungpook National University' | filter='country_code:KR'
# [MAP]   -> candidate: Kyungpook National University | id=https://openalex.org/I31419693
# [MAP] OK (EN): Kyungpook National University -> Kyungpook National University | institutions.id=I31419693
# [MAP] [17/23] resolving 'Gyeongsang National University'
# [MAP] Try EN: Gyeongsang National University
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Gyeongsang National University' (relax=False)
# [MAP]   -> searching: 'Gyeongsang National University' | filter='country_code:KR'
# [MAP]   -> candidate: Gyeongsang National University | id=https://openalex.org/I189442560
# [MAP] OK (EN): Gyeongsang National University -> Gyeongsang National University | institutions.id=I189442560
# [MAP] [18/23] resolving 'Pusan National University'
# [MAP] Try EN: Pusan National University
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Pusan National University' (relax=False)
# [MAP]   -> searching: 'Pusan National University' | filter='country_code:KR'
# [MAP]   -> candidate: Pusan National University | id=https://openalex.org/I4921948
# [MAP] OK (EN): Pusan National University -> Pusan National University | institutions.id=I4921948
# [MAP] [19/23] resolving 'Chonnam National University'
# [MAP] Try EN: Chonnam National University
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Chonnam National University' (relax=False)
# [MAP]   -> searching: 'Chonnam National University' | filter='country_code:KR'
# [MAP]   -> candidate: Chonnam National University | id=https://openalex.org/I111277659
# [MAP] OK (EN): Chonnam National University -> Chonnam National University | institutions.id=I111277659
# [MAP] [20/23] resolving 'Jeonbuk National University'
# [MAP] Try EN: Jeonbuk National University
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeonbuk National University' (relax=False)
# [MAP]   -> searching: 'Jeonbuk National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeonbuk National University | id=https://openalex.org/I80611190
# [MAP] OK (EN): Jeonbuk National University -> Jeonbuk National University | institutions.id=I80611190
# [MAP] [21/23] resolving 'Jeju National University'
# [MAP] Try EN: Jeju National University
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for 'Jeju National University' (relax=False)
# [MAP]   -> searching: 'Jeju National University' | filter='country_code:KR'
# [MAP]   -> candidate: Jeju National University | id=https://openalex.org/I83202590
# [MAP] OK (EN): Jeju National University -> Jeju National University | institutions.id=I83202590
# [MAP] [22/23] resolving 'Chungbuk National University'
# [MAP] Try EN: Chungbuk National University
# [MAP]   -> searching: 'Chungbuk National University' | filter='country_code:KR,type:education'
# [MAP]   -> no candidates for '
#         Gwangju Institute of Science and Technology      I39534123         Gwangju Institute of Science and Technology
# Daegu Gyeongbuk Institute of Science and Technology     I193352282 Daegu Gyeongbuk Institute of Science and Technology
#  Ulsan National Institute of Science and Technology      I48566637  Ulsan National Institute of Science and Technology
#                                Chung-Ang University      I67900169                                Chung-Ang University
#                                Kyung Hee University     I160888826                          Kyung Hee Cyber University
#                         Kangwon National University     I165507594                         Kangwon National University
#                       Kyungpook National University      I31419693                       Kyungpook National University
#                      Gyeongsang National University     I189442560                      Gyeongsang National University
#                           Pusan National University       I4921948                           Pusan National University
#                         Chonnam National University     I111277659                         Chonnam National University
#                         Jeonbuk National University      I80611190                         Jeonbuk National University
#                            Jeju National University      I83202590                            Jeju National University
#                        Chungbuk National University     I163753206                        Chungbuk National University
#                        Chungnam National University     I196345858                        Chungnam National University
# [RUN] Fetch top-10000 (year=2011) for Duksung Women's University (Duksung Women's University) → institutions.id=I65832422
# [GET] Duksung Women's University | page=1 cursor=*
# [GET]   -> fetched 97 (rep: 'Preclinical Development of the Novel Chk1 Inhibitor SCH900776 in Combination wit...')
# [GET]   -> total accumulated: 97 | next_cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNzY4NzkwMDknXSI=
# [GET] Duksung Women's University | page=2 cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzMxNzY4NzkwMDknXSI=
# [GET]   -> empty batch (stop).
# [SAVE] Duksung Women's University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2011_with_authors/works_top10000_2011_Duksung_Women's_University.csv (n=97)
# [RUN] Fetch top-10000 (year=2011) for Seoul National University (Seoul National University) → institutions.id=I139264467
# [GET] Seoul National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Introducing EzTaxon-e: a prokaryotic 16S rRNA gene sequence database with phylot...')
# [GET]   -> total accumulated: 200 | next_cursor=IlsxOTcsIDk5LjAsIDE5NywgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDY1OTk3OTkzJ10i
# [GET] Seoul National University | page=2 cursor=IlsxOTcsIDk5LjAsIDE5NywgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDY1OTk3OTkzJ10i
# [GET]   -> fetched 200 (rep: 'Quality of roof-harvested rainwater – Comparison of different roofing materials...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsxMzEsIDk5LjAsIDEzMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMTQyMDIyNjk2J10i
# [GET] Seoul National University | page=3 cursor=IlsxMzEsIDk5LjAsIDEzMSwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMTQyMDIyNjk2J10i
# [GET]   -> fetched 200 (rep: 'Sixty-five gene-based risk score classifier predicts overall survival in hepatoc...')
# [GET]   -> total accumulated: 600 | next_cursor=IlsxMDIsIDk4LjAsIDEwMiwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDg0OTE4MTg0J10i
# [GET] Seoul National University | page=4 cursor=IlsxMDIsIDk4LjAsIDEwMiwgJ2h0dHBzOi8vb3BlbmFsZXgub3JnL1cyMDg0OTE4MTg0J10i
# [GET]   -> fetched 200 (rep: 'Comparative Analyses of DNA Methylation and Sequence Evolution Using Nasonia Gen...')
# [GET]   -> total accumulated: 800 | next_cursor=Ils4MiwgOTguMCwgODIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2NzYwNjEzMiddIg==
# [GET] Seoul National University | page=5 cursor=Ils4MiwgOTguMCwgODIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2NzYwNjEzMiddIg==
# [GET]   -> fetched 200 (rep: 'The role of optics in future high radix switch design...')
# [GET]   -> total accumulated: 1000 | next_cursor=Ils3MCwgOTcuMCwgNzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzI4MjU3ODQ1J10i
# [GET] Seoul National University | page=6 cursor=Ils3MCwgOTcuMCwgNzAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMzI4MjU3ODQ1J10i
# [GET]   -> fetched 200 (rep: 'Epidemiology and clinical features of pediatric psoriasis in tertiary referral p...')
# [GET]   -> total accumulated: 1200 | next_cursor=Ils2MCwgOTYuMCwgNjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3MDk0NTQyNiddIg==
# [GET] Seoul National University | page=7 cursor=Ils2MCwgOTYuMCwgNjAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk3MDk0NTQyNiddIg==
# [GET]   -> fetched 200 (rep: 'Hepatocellular nodules in liver cirrhosis: MR evaluation...')
# [GET]   -> total accumulated: 1400 | next_cursor=Ils1NCwgOTYuMCwgNTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE3MTM4NjM5NiddIg==
# [GET] Seoul National University | page=8 cursor=Ils1NCwgOTYuMCwgNTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE3MTM4NjM5NiddIg==
# [GET]   -> fetched 200 (rep: 'Phase-Selective Growth of Assembled FeSe<sub>2</sub> Nanorods from Organometalli...')
# [GET]   -> total accumulated: 1600 | next_cursor=Ils0NywgOTUuMCwgNDcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxNDQ4NTgxOSddIg==
# [GET] Seoul National University | page=9 cursor=Ils0NywgOTUuMCwgNDcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxNDQ4NTgxOSddIg==
# [GET]   -> fetched 200 (rep: 'Comparative analysis of pepper and tomato reveals euchromatin expansion of peppe...')
# [GET]   -> total accumulated: 1800 | next_cursor=Ils0MiwgOTUuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA0NjI3MTk0MyddIg==
# [GET] Seoul National University | page=10 cursor=Ils0MiwgOTUuMCwgNDIsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA0NjI3MTk0MyddIg==
# [GET]   -> fetched 200 (rep: 'Estimating canopy cover from color digital camera image of rice field...')
# [GET]   -> total accumulated: 2000 | next_cursor=IlszOCwgOTQuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA5MTg4Nzc3NiddIg==
# [GET] Seoul National University | page=11 cursor=IlszOCwgOTQuMCwgMzgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA5MTg4Nzc3NiddIg==
# [GET]   -> fetched 200 (rep: 'Design of the roll stabilization controller, using fin stabilizers and pod prope...')
# [GET]   -> total accumulated: 2200 | next_cursor=IlszNCwgOTQuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxNjQ3Mzg2NCddIg==
# [GET] Seoul National University | page=12 cursor=IlszNCwgOTQuMCwgMzQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxNjQ3Mzg2NCddIg==
# [GET]   -> fetched 200 (rep: 'Cross-linked hyaluronic acid-based flexible cell delivery system: Application fo...')
# [GET]   -> total accumulated: 2400 | next_cursor=IlszMSwgOTMuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxNzYyNTYzOSddIg==
# [GET] Seoul National University | page=13 cursor=IlszMSwgOTMuMCwgMzEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxNzYyNTYzOSddIg==
# [GET]   -> fetched 200 (rep: 'A sensitive diagnostic assay of rheumatoid arthritis using three-dimensional ZnO...')
# [GET]   -> total accumulated: 2600 | next_cursor=IlsyOCwgOTIuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk4MjY3MjEwNyddIg==
# [GET] Seoul National University | page=14 cursor=IlsyOCwgOTIuMCwgMjgsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk4MjY3MjEwNyddIg==
# [GET]   -> fetched 200 (rep: 'The effects of plant growth regulators, activated charcoal, and AgNO3 on microsp...')
# [GET]   -> total accumulated: 2800 | next_cursor=IlsyNiwgOTIuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3NDk1MDYxOSddIg==
# [GET] Seoul National University | page=15 cursor=IlsyNiwgOTIuMCwgMjYsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3NDk1MDYxOSddIg==
# [GET]   -> fetched 200 (rep: 'MRI Findings of <i>Aspergillus</i> Spondylitis...')
# [GET]   -> total accumulated: 3000 | next_cursor=IlsyMywgOTEuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2ODMxNDg5NiddIg==
# [GET] Seoul National University | page=16 cursor=IlsyMywgOTEuMCwgMjMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk2ODMxNDg5NiddIg==
# [GET]   -> fetched 200 (rep: 'The prevalence of testicular adrenal rest tumors and associated factors in postp...')
# [GET]   -> total accumulated: 3200 | next_cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwODkwODI0OSddIg==
# [GET] Seoul National University | page=17 cursor=IlsyMSwgOTEuMCwgMjEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAwODkwODI0OSddIg==
# [GET]   -> fetched 200 (rep: 'Improved Feature Map Merging Using Virtual Supporting Lines for Multi-Robot Syst...')
# [GET]   -> total accumulated: 3400 | next_cursor=IlsxOSwgOTAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3NDQ1NjUzMCddIg==
# [GET] Seoul National University | page=18 cursor=IlsxOSwgOTAuMCwgMTksICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA3NDQ1NjUzMCddIg==
# [GET]   -> fetched 200 (rep: 'Boron and Aluminum Codoped ZnO Transparent Conducting Films with High Electrical...')
# [GET]   -> total accumulated: 3600 | next_cursor=IlsxNywgODkuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyNTU5NTkwMSddIg==
# [GET] Seoul National University | page=19 cursor=IlsxNywgODkuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAyNTU5NTkwMSddIg==
# [GET]   -> fetched 200 (rep: 'The irreversible pan-HER inhibitor PF00299804 alone or combined with gemcitabine...')
# [GET]   -> total accumulated: 3800 | next_cursor=IlsxNSwgODguMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk5MTc4NTE4NSddIg==
# [GET] Seoul National University | page=20 cursor=IlsxNSwgODguMCwgMTUsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTk5MTc4NTE4NSddIg==
# [GET]   -> fetched 200 (rep: 'FAR-INFRARED LUMINOUS SUPERNOVA REMNANT Kes 17...')
# [GET]   -> total accumulated: 4000 | next_cursor=IlsxNCwgODguMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA4ODI5NjQ5MiddIg==
# [GET] Seoul National University | page=21 cursor=IlsxNCwgODguMCwgMTQsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA4ODI5NjQ5MiddIg==
# [GET]   -> fetched 200 (rep: 'Case Report: Multifocal Subchondral Stress Fractures of the Femoral Heads and Ti...')
# [GET]   -> total accumulated: 4200 | next_cursor=IlsxMywgODcuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE1MjM1MzYxMyddIg==
# [GET] Seoul National University | page=22 cursor=IlsxMywgODcuMCwgMTMsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjE1MjM1MzYxMyddIg==
# [GET]   -> fetched 200 (rep: 'REFRACTIVE INDEX AND SNELL'S LAW FOR DIPOLE-EXCHANGE SPIN WAVES IN RESTRICTED GE...')
# [GET]   -> total accumulated: 4400 | next_cursor=IlsxMSwgODYuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxMjU4ODUzMSddIg==
# [GET] Seoul National University | page=23 cursor=IlsxMSwgODYuMCwgMTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjAxMjU4ODUzMSddIg==
# [GET]   -> fetched 200 (rep: 'Nuclear Factor E2–Related Factor 2–Mediated Induction of NAD(P)H:Quinone Oxidore...')
# [GET]   -> total accumulated: 4600 | next_cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA0NTI1Nzk0OSddIg==
# [GET] Seoul National University | page=24 cursor=IlsxMCwgODYuMCwgMTAsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjA0NTI1Nzk0OSddIg==
# [GET]   -> fetched 200 (rep: 'Evaluation of a Fall Risk Assessment Tool to Establish Continuous Quality Improv...')
# [GET]   -> total accumulated: 4800 | next_cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNzg1NzM5MzgnXSI=
# [GET] Seoul National University | page=25 cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNzg1NzM5MzgnXSI=
# [GET]   -> fetched 200 (rep: 'Ionic liquid incorporated polystyrene resin for solid-phase peptide synthesis...')
# [GET]   -> total accumulated: 5000 | next_cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIxNDU5MTE3NzQnXSI=
# [GET] Seoul National University | page=26 cursor=Ils4LCA4NC4wLCA4LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIx
CAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNDc3MjYyNTgnXSI=
# [GET]   -> fetched 200 (rep: 'Environmental risk assessment of genetically modified Herbicide-Tolerant zoysiag...')
# [GET]   -> total accumulated: 600 | next_cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzE1MTQ0MTMzMCddIg==
# [GET] Jeju National University | page=4 cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzE1MTQ0MTMzMCddIg==
# [GET]   -> fetched 93 (rep: 'Performance of Non-coherent Detectors for Ultra Wide Band Short Range Radar in A...')
# [GET]   -> total accumulated: 693 | next_cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk3NjgyNjYyJ10i
# [GET] Jeju National University | page=5 cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk3NjgyNjYyJ10i
# [GET]   -> empty batch (stop).
# [SAVE] Jeju National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2011_with_authors/works_top10000_2011_Jeju_National_University.csv (n=693)
# [RUN] Fetch top-10000 (year=2011) for Chungbuk National University (Chungbuk National University) → institutions.id=I163753206
# [GET] Chungbuk National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'Apparel product attributes, web browsing, and e-impulse buying on shopping websi...')
# [GET]   -> total accumulated: 200 | next_cursor=IlszNywgOTQuMCwgMzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzNDE4NzUzNiddIg==
# [GET] Chungbuk National University | page=2 cursor=IlszNywgOTQuMCwgMzcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMjEzNDE4NzUzNiddIg==
# [GET]   -> fetched 200 (rep: 'A case of rheumatoid meningitis: pathologic and magnetic resonance imaging findi...')
# [GET]   -> total accumulated: 400 | next_cursor=IlsxNywgODkuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU0NjgwMDc5MCddIg==
# [GET] Chungbuk National University | page=3 cursor=IlsxNywgODkuMCwgMTcsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMTU0NjgwMDc5MCddIg==
# [GET]   -> fetched 200 (rep: 'Attraction response of spot clothing wax cicada, Lycorma delicatula (Hemiptera: ...')
# [GET]   -> total accumulated: 600 | next_cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNTI5NjU3OTYnXSI=
# [GET] Chungbuk National University | page=4 cursor=Ils5LCA4NS4wLCA5LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNTI5NjU3OTYnXSI=
# [GET]   -> fetched 200 (rep: 'Novel zirconium complexes containing a bidentate phenoxybenzotriazole ligand...')
# [GET]   -> total accumulated: 800 | next_cursor=Ils0LCA4MC4wLCA0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNTUyMTczNjAnXSI=
# [GET] Chungbuk National University | page=5 cursor=Ils0LCA4MC4wLCA0LCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNTUyMTczNjAnXSI=
# [GET]   -> fetched 200 (rep: 'The effect of flavonoids on the TREK-1 channel...')
# [GET]   -> total accumulated: 1000 | next_cursor=IlsyLCA3Ni4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzc2NTkzMjk4NiddIg==
# [GET] Chungbuk National University | page=6 cursor=IlsyLCA3Ni4wLCAyLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzc2NTkzMjk4NiddIg==
# [GET]   -> fetched 200 (rep: 'Full-scale EFC Study on Oil Recovery and Reuse from Discharge Gas of Tenter Faci...')
# [GET]   -> total accumulated: 1200 | next_cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNDI0NjcyNjcnXSI=
# [GET] Chungbuk National University | page=7 cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzIwNDI0NjcyNjcnXSI=
# [GET]   -> fetched 170 (rep: 'Depth filtering of three-dimensional object using integral imaging...')
# [GET]   -> total accumulated: 1370 | next_cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk0NjE1MzQ0MSddIg==
# [GET] Chungbuk National University | page=8 cursor=IlswLCA2NS4wLCAwLCAnaHR0cHM6Ly9vcGVuYWxleC5vcmcvVzk0NjE1MzQ0MSddIg==
# [GET]   -> empty batch (stop).
# [SAVE] Chungbuk National University -> /content/drive/MyDrive/6. 덕성여자대학교/25학년도 2학기/비정형데이터분석/프로젝트/openalex_top10000_2011_with_authors/works_top10000_2011_Chungbuk_National_University.csv (n=1370)
# [RUN] Fetch top-10000 (year=2011) for Chungnam National University (Chungnam National University) → institutions.id=I196345858
# [GET] Chungnam National University | page=1 cursor=*
# [GET]   -> fetched 200 (rep: 'The genome of the mesopolyploid crop species Brassica rapa...')
# [GET]   -> total accumulated: 200 | next_cursor=Ils1MSwgOTYuMCwgNTEsICdodHRwczovL29wZW5hbGV4Lm9yZy9XMj